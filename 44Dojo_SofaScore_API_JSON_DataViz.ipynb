# %% [markdown]
# # Analyse et comparaison des statistiques des joueurs
# Ce notebook interactif permet de choisir une date, sélectionner un match, et analyser les statistiques des joueurs à travers des visualisations interactives.

# %%
# Importer les bibliothèques
import requests
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Partie 1 : Focus sur ton joueur préféré
# Cette partie nous permettra de séléctionner une date, puis un match, puis un joueur, récupérer et visualiser les statistiques de ce joueur pendant ce match

# %% [markdown]
# ## Étape 1 : Sélectionner une date et récupérer les matchs

# %%
# Saisir une date pour récupérer les données des matchs
# Vous pouvez choisir une date pour trouver un match qui vous anime si vous suivez les matchs de basket
date = input('Entrez une date (YYYY-MM-DD) : ')

# Construire l'URL de l'API
url_events = f'https://api.sofascore.com/api/v1/sport/basketball/scheduled-events/{date}'

# Faire une requête GET
response = requests.get(url_events)

# Vérifier la réponse et récupérer les informations sur les matches
if response.status_code == 200:
    data = response.json()
    matches = data.get('events', [])
else:
    print(f"Erreur: {response.status_code}")

# L'objet qu'on retourne est sous forme JSON, explorez un peu comment il est structuré
matches
# Out:
# Entrez une date (2025-02-04) : 2025-02-04
# [{'officials': [{'official': {'name': 'Jenna Schroeder',
#      'jerseyNumber': '20',
#      'experience': 0,
#      'id': 24},
#     'assignment': 'official'},
#    {'official': {'name': 'Pat Fraher',
#      'jerseyNumber': '26',
#      'experience': 22,
#      'id': 28},
#     'assignment': 'head-official'},
#    {'official': {'name': 'CJ Washington',
#      'jerseyNumber': '12',
#      'experience': 7,
#      'id': 42},
#     'assignment': 'official'}],
#   'tournament': {'name': 'NBA',
#    'slug': 'nba',
#    'category': {'name': 'USA',
#     'slug': 'usa',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'id': 15,
#     'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#     'flag': 'usa',
#     'alpha2': 'US'},
#    'uniqueTournament': {'name': 'NBA',
#     'slug': 'nba',
#     'category': {'name': 'USA',
#      'slug': 'usa',
#      'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#      'id': 15,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'flag': 'usa',
#      'alpha2': 'US'},
#     'userCount': 241344,
#     'id': 132,
#     'hasEventPlayerStatistics': True,
#     'hasBoxScore': True,
#     'displayInverseHomeAwayTeams': False,
#     'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الأميركي للمحترفين',
#       'hi': 'एनबीए',
#       'bn': 'এনবিএ'},
#      'shortNameTranslation': {}}},
#    'priority': 143,
#    'id': 177,
#    'fieldTranslations': {'nameTranslation': {'ar': 'دوري NBA',
#      'hi': 'एनबीए',
#      'bn': 'এনবিএ'},
#     'shortNameTranslation': {}}},
#   'season': {'name': 'NBA 24/25',
#    'year': '24/25',
#    'editor': True,
#    'id': 65360},
#   'customId': 'FtbsLtb',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 2,
#   'homeTeam': {'name': 'Charlotte Hornets',
#    'slug': 'charlotte-hornets',
#    'shortName': 'Hornets',
#    'gender': 'M',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 30220,
#    'nameCode': 'CHA',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 3430,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'entityType': 'team',
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'شارلوت هورنتس',
#      'ru': 'Шарлотт Хорнетс',
#      'hi': 'शार्लोट हॉर्नेट्स',
#      'bn': 'শার্লট হর্নেটস'},
#     'shortNameTranslation': {'ar': 'هورنتس',
#      'hi': 'हॉर्नेट्स',
#      'bn': 'হর্নেটস'}}},
#   'awayTeam': {'name': 'Washington Wizards',
#    'slug': 'washington-wizards',
#    'shortName': 'Wizards',
#    'gender': 'M',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 24132,
#    'nameCode': 'WAS',
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 3431,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'entityType': 'team',
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'واشنطن ويزاردز',
#      'ru': 'Вашингтон Визардз',
#      'hi': 'वॉशिंगटन विजार्ड्स',
#      'bn': 'ওয়াশিংটন উইজার্ডস'},
#     'shortNameTranslation': {'ar': 'ويزاردز',
#      'hi': 'विजार्ड्स',
#      'bn': 'উইজার্ডস'}}},
#   'homeScore': {'current': 115,
#    'display': 114,
#    'period1': 29,
#    'period2': 26,
#    'period3': 34,
#    'period4': 26,
#    'normaltime': 114},
#   'awayScore': {'current': 124,
#    'display': 125,
#    'period1': 31,
#    'period2': 46,
#    'period3': 21,
#    'period4': 28,
#    'normaltime': 124},
#   'time': {'played': 2880,
#    'periodLength': 721,
#    'overtimeLength': 300,
#    'totalPeriodCount': 4,
#    'currentPeriodStartTimestamp': 1738635870},
#   'changes': {'changes': ['time.currentPeriodStart',
#     'status.code',
#     'status.description',
#     'status.type',
#     'homeScore.normaltime',
#     'awayScore.normaltime',
#     'time.played'],
#    'changeTimestamp': 1738635880},
#   'hasGlobalHighlights': True,
#   'hasEventPlayerStatistics': True,
#   'crowdsourcingDataDisplayEnabled': True,
#   'id': 12696916,
#   'periods': {'current': 'Score',
#    'period1': '1st quarter',
#    'period2': '2nd quarter',
#    'period3': '3rd quarter',
#    'period4': '4th quarter',
#    'overtime': 'Overtime'},
#   'startTimestamp': 1738636200,
#   'slug': 'washington-wizards-charlotte-hornets',
#   'finalResultOnly': False,
#   'feedLocked': False,
#   'isEditor': True,
#   'homeTeamSeasonHistoricalForm': {'wins': 12, 'losses': 34},
#   'awayTeamSeasonHistoricalForm': {'wins': 7, 'losses': 41}},
#  {'officials': [{'official': {'name': 'Phenizee Ransom',
#      'jerseyNumber': '70',
#      'experience': 5,
#      'id': 22},
#     'assignment': 'official'},
#    {'official': {'name': 'Tony Brothers',
#      'jerseyNumber': '25',
#      'experience': 29,
#      'id': 60},
#     'assignment': 'head-official'},
#    {'official': {'name': 'Robert Hussey',
#      'jerseyNumber': '85',
#      'experience': 1,
#      'id': 69},
#     'assignment': 'official'}],
#   'tournament': {'name': 'NBA',
#    'slug': 'nba',
#    'category': {'name': 'USA',
#     'slug': 'usa',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'id': 15,
#     'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#     'flag': 'usa',
#     'alpha2': 'US'},
#    'uniqueTournament': {'name': 'NBA',
#     'slug': 'nba',
#     'category': {'name': 'USA',
#      'slug': 'usa',
#      'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#      'id': 15,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'flag': 'usa',
#      'alpha2': 'US'},
#     'userCount': 241344,
#     'id': 132,
#     'hasEventPlayerStatistics': False,
#     'hasBoxScore': True,
#     'displayInverseHomeAwayTeams': False,
#     'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الأميركي للمحترفين',
#       'hi': 'एनबीए',
#       'bn': 'এনবিএ'},
#      'shortNameTranslation': {}}},
#    'priority': 143,
#    'id': 177,
#    'fieldTranslations': {'nameTranslation': {'ar': 'دوري NBA',
#      'hi': 'एनबीए',
#      'bn': 'এনবিএ'},
#     'shortNameTranslation': {}}},
#   'season': {'name': 'NBA 24/25',
#    'year': '24/25',
#    'editor': True,
#    'id': 65360},
#   'customId': 'ytbszmb',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 2,
#   'homeTeam': {'name': 'Detroit Pistons',
#    'slug': 'detroit-pistons',
#    'shortName': 'Pistons',
#    'gender': 'M',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 26378,
#    'nameCode': 'DET',
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 3424,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'entityType': 'team',
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'ديترويت بيستونز',
#      'ru': 'Детройт Пистонс',
#      'hi': 'डेट्रॉयट पिस्टन्स',
#      'bn': 'ডেট্রয়েট পিস্টন'},
#     'shortNameTranslation': {'ar': 'بيستونز',
#      'hi': 'पिस्टन्स',
#      'bn': 'পিস্টন'}}},
#   'awayTeam': {'name': 'Atlanta Hawks',
#    'slug': 'atlanta-hawks',
#    'shortName': 'Hawks',
#    'gender': 'M',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 38820,
#    'nameCode': 'ATL',
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 3423,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'entityType': 'team',
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'اتلانتا هوكس',
#      'ru': 'Атланта Хоукс',
#      'hi': 'अटलांटा हॉक्स',
#      'bn': 'আটলান্টা হকস'},
#     'shortNameTranslation': {'ar': 'هوكس', 'hi': 'हॉक्स', 'bn': 'হকস'}}},
#   'homeScore': {'current': 130,
#    'display': 130,
#    'period1': 35,
#    'period2': 29,
#    'period3': 35,
#    'period4': 32,
#    'normaltime': 130},
#   'awayScore': {'current': 133,
#    'display': 132,
#    'period1': 35,
#    'period2': 39,
#    'period3': 29,
#    'period4': 32,
#    'normaltime': 133},
#   'time': {'played': 2880,
#    'periodLength': 721,
#    'overtimeLength': 300,
#    'totalPeriodCount': 4,
#    'currentPeriodStartTimestamp': 1738636810},
#   'changes': {'changes': ['time.played'], 'changeTimestamp': 1738636834},
#   'hasGlobalHighlights': False,
#   'hasEventPlayerStatistics': True,
#   'crowdsourcingDataDisplayEnabled': True,
#   'id': 12696894,
#   'periods': {'current': 'Score',
#    'period1': '1st quarter',
#    'period2': '2nd quarter',
#    'period3': '3rd quarter',
#    'period4': '4th quarter',
#    'overtime': 'Overtime'},
#   'startTimestamp': 1738628100,
#   'slug': 'detroit-pistons-atlanta-hawks',
#   'finalResultOnly': True,
#   'feedLocked': False,
#   'isEditor': True,
#   'homeTeamSeasonHistoricalForm': {'wins': 25, 'losses': 24},
#   'awayTeamSeasonHistoricalForm': {'wins': 22, 'losses': 27}},
#  {'officials': [{'official': {'name': 'Mitchell Ervin',
#      'jerseyNumber': '27',
#      'experience': 8,
#      'id': 21},
#     'assignment': 'head-official'},
#    {'official': {'name': 'Kevin Cutler',
#      'jerseyNumber': '34',
#      'experience': 13,
#      'id': 33},
#     'assignment': 'official'},
#    {'official': {'name': 'Brandon Schwab',
#      'jerseyNumber': '86',
#      'experience': 2,
#      'id': 52},
#     'assignment': 'official'}],
#   'tournament': {'name': 'NBA',
#    'slug': 'nba',
#    'category': {'name': 'USA',
#     'slug': 'usa',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'id': 15,
#     'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#     'flag': 'usa',
#     'alpha2': 'US'},
#    'uniqueTournament': {'name': 'NBA',
#     'slug': 'nba',
#     'category': {'name': 'USA',
#      'slug': 'usa',
#      'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#      'id': 15,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'flag': 'usa',
#      'alpha2': 'US'},
#     'userCount': 241344,
#     'id': 132,
#     'hasEventPlayerStatistics': False,
#     'hasBoxScore': False,
#     'displayInverseHomeAwayTeams': True,
#     'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الأميركي للمحترفين',
#       'hi': 'एनबीए',
#       'bn': 'এনবিএ'},
#      'shortNameTranslation': {}}},
#    'priority': 143,
#    'id': 177,
#    'fieldTranslations': {'nameTranslation': {'ar': 'دوري NBA',
#      'hi': 'एनबीए',
#      'bn': 'এনবিএ'},
#     'shortNameTranslation': {}}},
#   'season': {'name': 'NBA 24/25',
#    'year': '24/25',
#    'editor': False,
#    'id': 65360},
#   'customId': 'mdbswtb',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 1,
#   'homeTeam': {'name': 'New York Knicks',
#    'slug': 'new-york-knicks',
#    'shortName': 'Knicks',
#    'gender': 'M',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 52663,
#    'nameCode': 'NYK',
#    'disabled': True,
#    'national': False,
#    'type': 0,
#    'id': 3421,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'entityType': 'team',
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'نيويورك نيكس',
#      'ru': 'Нью-Йорк Никс',
#      'hi': 'न्यूयॉर्क निक्स',
#      'bn': 'নিউ ইয়র্ক নিক্স'},
#     'shortNameTranslation': {'ar': 'نيكس', 'hi': 'निक्स', 'bn': 'নিক্স'}}},
#   'awayTeam': {'name': 'Houston Rockets',
#    'slug': 'houston-rockets',
#    'shortName': 'Rockets',
#    'gender': 'M',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 38024,
#    'nameCode': 'HOU',
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 3412,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'entityType': 'team',
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'هيوستن روكتس',
#      'ru': 'Хьюстон Рокетс',
#      'hi': 'ह्यूस्टन रॉकेट्स',
#      'bn': 'হিউস্টন রকেট'},
#     'shortNameTranslation': {'ar': 'روكتس', 'hi': 'रॉकेट्स', 'bn': 'রকেট'}}},
#   'homeScore': {'current': 125,
#    'display': 125,
#    'period1': 26,
#    'period2': 27,
#    'period3': 27,
#    'period4': 46,
#    'normaltime': 125},
#   'awayScore': {'current': 119,
#    'display': 119,
#    'period1': 27,
#    'period2': 30,
#    'period3': 32,
#    'period4': 29,
#    'normaltime': 119},
#   'time': {'played': 2880,
#    'periodLength': 720,
#    'overtimeLength': 300,
#    'totalPeriodCount': 4,
#    'currentPeriodStartTimestamp': 1738638629},
#   'changes': {'changes': ['time.played',
#     'time.currentPeriodStart',
#     'status.code',
#     'status.description',
#     'status.type',
#     'homeScore.normaltime',
#     'awayScore.normaltime'],
#    'changeTimestamp': 1738638641},
#   'hasGlobalHighlights': False,
#   'hasEventPlayerStatistics': True,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12697344,
#   'periods': {'current': 'Score',
#    'period1': '1st quarter',
#    'period2': '2nd quarter',
#    'period3': '3rd quarter',
#    'period4': '4th quarter',
#    'overtime': 'Overtime'},
#   'startTimestamp': 1738631700,
#   'slug': 'new-york-knicks-houston-rockets',
#   'finalResultOnly': True,
#   'feedLocked': False,
#   'isEditor': False,
#   'homeTeamSeasonHistoricalForm': {'wins': 32, 'losses': 17},
#   'awayTeamSeasonHistoricalForm': {'wins': 32, 'losses': 16}},
#  {'officials': [{'official': {'name': 'Brett Nansel',
#      'jerseyNumber': '44',
#      'experience': 7,
#      'id': 17},
#     'assignment': 'official'},
#    {'official': {'name': 'Mark Lindsay',
#      'jerseyNumber': '29',
#      'experience': 16,
#      'id': 56},
#     'assignment': 'head-official'},
#    {'official': {'name': 'Brian Forte',
#      'jerseyNumber': '45',
#      'experience': 16,
#      'id': 68},
#     'assignment': 'official'}],
#   'tournament': {'name': 'NBA',
#    'slug': 'nba',
#    'category': {'name': 'USA',
#     'slug': 'usa',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'id': 15,
#     'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#     'flag': 'usa',
#     'alpha2': 'US'},
#    'uniqueTournament': {'name': 'NBA',
#     'slug': 'nba',
#     'category': {'name': 'USA',
#      'slug': 'usa',
#      'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#      'id': 15,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'flag': 'usa',
#      'alpha2': 'US'},
#     'userCount': 241344,
#     'id': 132,
#     'hasEventPlayerStatistics': False,
#     'hasBoxScore': True,
#     'displayInverseHomeAwayTeams': False,
#     'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الأميركي للمحترفين',
#       'hi': 'एनबीए',
#       'bn': 'এনবিএ'},
#      'shortNameTranslation': {}}},
#    'priority': 143,
#    'id': 177,
#    'fieldTranslations': {'nameTranslation': {'ar': 'دوري NBA',
#      'hi': 'एनबीए',
#      'bn': 'এনবিএ'},
#     'shortNameTranslation': {}}},
#   'season': {'name': 'NBA 24/25',
#    'year': '24/25',
#    'editor': False,
#    'id': 65360},
#   'customId': 'ptbsHtb',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 1,
#   'homeTeam': {'name': 'Memphis Grizzlies',
#    'slug': 'memphis-grizzlies',
#    'shortName': 'Grizzlies',
#    'gender': 'M',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 51352,
#    'nameCode': 'MEM',
#    'disabled': True,
#    'national': True,
#    'type': 0,
#    'id': 3415,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'entityType': 'team',
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'ممفيس جريزليز',
#      'ru': 'Мемфис Гриззлис',
#      'hi': 'मेम्फिस ग्रिजलीज़',
#      'bn': 'মেমফিস গ্রিজলিস'},
#     'shortNameTranslation': {'ar': 'جريزليس',
#      'hi': 'ग्रिज़लीज़',
#      'bn': 'গ্রিজলিস'}}},
#   'awayTeam': {'name': 'San Antonio Spurs',
#    'slug': 'san-antonio-spurs',
#    'shortName': 'Spurs',
#    'gender': 'M',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 53415,
#    'nameCode': 'SAS',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 3429,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'entityType': 'team',
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'سان انطونيو سبيرز',
#      'ru': 'Сан-Антонио Спёрс',
#      'hi': 'सैन एंटोनियो स्पर्स',
#      'bn': 'সান আন্তোনিও স্পার্স'},
#     'shortNameTranslation': {'ar': 'توتنهام',
#      'hi': 'स्पर्स',
#      'bn': 'স্পার্স'}}},
#   'homeScore': {'current': 128,
#    'display': 128,
#    'period1': 34,
#    'period2': 28,
#    'period3': 31,
#    'period4': 38,
#    'normaltime': 129},
#   'awayScore': {'current': 109,
#    'display': 110,
#    'period1': 28,
#    'period2': 21,
#    'period3': 33,
#    'period4': 28,
#    'normaltime': 110},
#   'time': {'played': 2880,
#    'periodLength': 720,
#    'overtimeLength': 300,
#    'totalPeriodCount': 4,
#    'currentPeriodStartTimestamp': 1738641602},
#   'changes': {'changes': ['time.currentPeriodStart',
#     'status.code',
#     'status.description',
#     'status.type',
#     'homeScore.normaltime',
#     'awayScore.normaltime'],
#    'changeTimestamp': 1738641609},
#   'hasGlobalHighlights': False,
#   'hasEventPlayerStatistics': False,
#   'crowdsourcingDataDisplayEnabled': True,
#   'id': 12696754,
#   'periods': {'current': 'Score',
#    'period1': '1st quarter',
#    'period2': '2nd quarter',
#    'period3': '3rd quarter',
#    'period4': '4th quarter',
#    'overtime': 'Overtime'},
#   'startTimestamp': 1738629000,
#   'slug': 'san-antonio-spurs-memphis-grizzlies',
#   'finalResultOnly': True,
#   'feedLocked': False,
#   'isEditor': False,
#   'homeTeamSeasonHistoricalForm': {'wins': 33, 'losses': 16},
#   'awayTeamSeasonHistoricalForm': {'wins': 21, 'losses': 25}},
#  {'officials': [{'official': {'name': 'John Butler',
#      'jerseyNumber': '30',
#      'experience': 4,
#      'id': 13},
#     'assignment': 'official'},
#    {'official': {'name': 'Josh Tiven',
#      'jerseyNumber': '58',
#      'experience': 13,
#      'id': 58},
#     'assignment': 'head-official'},
#    {'official': {'name': 'Matt Boland',
#      'jerseyNumber': '18',
#      'experience': 20,
#      'id': 67},
#     'assignment': 'official'}],
#   'tournament': {'name': 'NBA',
#    'slug': 'nba',
#    'category': {'name': 'USA',
#     'slug': 'usa',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'id': 15,
#     'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#     'flag': 'usa',
#     'alpha2': 'US'},
#    'uniqueTournament': {'name': 'NBA',
#     'slug': 'nba',
#     'category': {'name': 'USA',
#      'slug': 'usa',
#      'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#      'id': 15,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'flag': 'usa',
#      'alpha2': 'US'},
#     'userCount': 241344,
#     'id': 132,
#     'hasEventPlayerStatistics': False,
#     'hasBoxScore': False,
#     'displayInverseHomeAwayTeams': False,
#     'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الأميركي للمحترفين',
#       'hi': 'एनबीए',
#       'bn': 'এনবিএ'},
#      'shortNameTranslation': {}}},
#    'priority': 143,
#    'id': 177,
#    'fieldTranslations': {'nameTranslation': {'ar': 'دوري NBA',
#      'hi': 'एनबीए',
#      'bn': 'এনবিএ'},
#     'shortNameTranslation': {}}},
#   'season': {'name': 'NBA 24/25',
#    'year': '24/25',
#    'editor': False,
#    'id': 65360},
#   'customId': 'jtbsBtb',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 2,
#   'homeTeam': {'name': 'Minnesota Timberwolves',
#    'slug': 'minnesota-timberwolves',
#    'shortName': 'Timberwolves',
#    'gender': 'M',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 56960,
#    'nameCode': 'MIN',
#    'disabled': True,
#    'national': True,
#    'type': 0,
#    'id': 3426,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'entityType': 'team',
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'مينيسوتا تمبروولفز',
#      'ru': 'Миннесота Тимбервулвс',
#      'hi': 'मिनेसोटा टिम्बरवॉल्व्स',
#      'bn': 'মিনেসোটা টিম্বারওলভস'},
#     'shortNameTranslation': {'ar': 'تمبروولفز',
#      'hi': 'टिम्बरवॉल्व्स',
#      'bn': 'টিম্বারওলভস'}}},
#   'awayTeam': {'name': 'Sacramento Kings',
#    'slug': 'sacramento-kings',
#    'shortName': 'Kings',
#    'gender': 'M',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 33569,
#    'nameCode': 'SAC',
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 3413,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'entityType': 'team',
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'سكرامنتو كينغز',
#      'ru': 'Сакраменто Кингз',
#      'hi': 'सैक्रामेंटो किंग्स',
#      'bn': 'স্যাক্রামেন্টো কিংস'},
#     'shortNameTranslation': {'ar': 'كينغز', 'hi': 'किंग्स', 'bn': 'কিংস'}}},
#   'homeScore': {'current': 115,
#    'display': 114,
#    'period1': 34,
#    'period2': 26,
#    'period3': 28,
#    'period4': 29,
#    'normaltime': 114},
#   'awayScore': {'current': 116,
#    'display': 116,
#    'period1': 39,
#    'period2': 30,
#    'period3': 21,
#    'period4': 28,
#    'normaltime': 116},
#   'time': {'played': 2880,
#    'periodLength': 721,
#    'overtimeLength': 300,
#    'totalPeriodCount': 4,
#    'currentPeriodStartTimestamp': 1738639728},
#   'changes': {'changes': ['time.currentPeriodStart',
#     'status.code',
#     'status.description',
#     'status.type',
#     'homeScore.normaltime',
#     'awayScore.normaltime',
#     'homeScore.current',
#     'homeScore.display',
#     'homeScore.period4',
#     'awayScore.current',
#     'awayScore.display',
#     'awayScore.period4',
#     'time.played'],
#    'changeTimestamp': 1738639734},
#   'hasGlobalHighlights': True,
#   'hasEventPlayerStatistics': True,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12696773,
#   'periods': {'current': 'Score',
#    'period1': '1st quarter',
#    'period2': '2nd quarter',
#    'period3': '3rd quarter',
#    'period4': '4th quarter',
#    'overtime': 'Overtime'},
#   'startTimestamp': 1738621800,
#   'slug': 'minnesota-timberwolves-sacramento-kings',
#   'finalResultOnly': True,
#   'feedLocked': True,
#   'isEditor': True,
#   'homeTeamSeasonHistoricalForm': {'wins': 27, 'losses': 22},
#   'awayTeamSeasonHistoricalForm': {'wins': 24, 'losses': 24}},
#  {'officials': [{'official': {'name': 'Matt Myers',
#      'jerseyNumber': '43',
#      'experience': 5,
#      'id': 9},
#     'assignment': 'official'},
#    {'official': {'name': 'Evan Scott',
#      'jerseyNumber': '78',
#      'experience': 4,
#      'id': 12},
#     'assignment': 'official'},
#    {'official': {'name': 'David Guthrie',
#      'jerseyNumber': '16',
#      'experience': 18,
#      'id': 73},
#     'assignment': 'head-official'}],
#   'tournament': {'name': 'NBA',
#    'slug': 'nba',
#    'category': {'name': 'USA',
#     'slug': 'usa',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'id': 15,
#     'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#     'flag': 'usa',
#     'alpha2': 'US'},
#    'uniqueTournament': {'name': 'NBA',
#     'slug': 'nba',
#     'category': {'name': 'USA',
#      'slug': 'usa',
#      'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#      'id': 15,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'flag': 'usa',
#      'alpha2': 'US'},
#     'userCount': 241344,
#     'id': 132,
#     'hasEventPlayerStatistics': True,
#     'hasBoxScore': False,
#     'displayInverseHomeAwayTeams': True,
#     'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الأميركي للمحترفين',
#       'hi': 'एनबीए',
#       'bn': 'এনবিএ'},
#      'shortNameTranslation': {}}},
#    'priority': 143,
#    'id': 177,
#    'fieldTranslations': {'nameTranslation': {'ar': 'دوري NBA',
#      'hi': 'एनबीए',
#      'bn': 'এনবিএ'},
#     'shortNameTranslation': {}}},
#   'season': {'name': 'NBA 24/25',
#    'year': '24/25',
#    'editor': True,
#    'id': 65360},
#   'customId': 'kibsttb',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 1,
#   'homeTeam': {'name': 'Oklahoma City Thunder',
#    'slug': 'oklahoma-city-thunder',
#    'shortName': 'Thunder',
#    'gender': 'M',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 53495,
#    'nameCode': 'OKC',
#    'disabled': True,
#    'national': True,
#    'type': 0,
#    'id': 3418,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'entityType': 'team',
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'أوكلاهوما سيتي ثاندر',
#      'ru': 'Оклахома Сити Тандер',
#      'hi': 'ओकलाहोमा सिटी थंडर',
#      'bn': 'ওকলাহোমা সিটি থান্ডার'},
#     'shortNameTranslation': {'ar': 'ثاندر', 'hi': 'थंडर', 'bn': 'থান্ডার'}}},
#   'awayTeam': {'name': 'Milwaukee Bucks',
#    'slug': 'milwaukee-bucks',
#    'shortName': 'Bucks',
#    'gender': 'M',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 101417,
#    'nameCode': 'MIL',
#    'disabled': True,
#    'national': False,
#    'type': 0,
#    'id': 3410,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'entityType': 'team',
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'ميلووكي باكس',
#      'ru': 'Милуоки Бакс',
#      'hi': 'मिलवॉकी बक्स',
#      'bn': 'মিলওয়াকি বাক্স'},
#     'shortNameTranslation': {'ar': 'باكز', 'hi': 'बक्स', 'bn': 'বাক্স'}}},
#   'homeScore': {'current': 125,
#    'display': 125,
#    'period1': 39,
#    'period2': 40,
#    'period3': 38,
#    'period4': 10,
#    'normaltime': 125},
#   'awayScore': {'current': 97,
#    'display': 96,
#    'period1': 23,
#    'period2': 23,
#    'period3': 32,
#    'period4': 21,
#    'normaltime': 97},
#   'time': {'played': 2880,
#    'periodLength': 721,
#    'overtimeLength': 300,
#    'totalPeriodCount': 4,
#    'currentPeriodStartTimestamp': 1738638637},
#   'changes': {'changes': ['status.code',
#     'status.description',
#     'status.type',
#     'homeScore.normaltime',
#     'awayScore.normaltime',
#     'time.currentPeriodStart'],
#    'changeTimestamp': 1738638641},
#   'hasGlobalHighlights': True,
#   'hasEventPlayerStatistics': False,
#   'crowdsourcingDataDisplayEnabled': True,
#   'id': 12696904,
#   'periods': {'current': 'Score',
#    'period1': '1st quarter',
#    'period2': '2nd quarter',
#    'period3': '3rd quarter',
#    'period4': '4th quarter',
#    'overtime': 'Overtime'},
#   'startTimestamp': 1738638000,
#   'slug': 'oklahoma-city-thunder-milwaukee-bucks',
#   'finalResultOnly': False,
#   'feedLocked': False,
#   'isEditor': False,
#   'homeTeamSeasonHistoricalForm': {'wins': 38, 'losses': 9},
#   'awayTeamSeasonHistoricalForm': {'wins': 26, 'losses': 21}},
#  {'officials': [{'official': {'name': 'Zach Zarba',
#      'jerseyNumber': '15',
#      'experience': 20,
#      'id': 20},
#     'assignment': 'head-official'},
#    {'official': {'name': 'Natalie Sago',
#      'jerseyNumber': '9',
#      'experience': 5,
#      'id': 34},
#     'assignment': 'official'},
#    {'official': {'name': 'Matt Kallio',
#      'jerseyNumber': '53',
#      'experience': 1,
#      'id': 65},
#     'assignment': 'official'}],
#   'tournament': {'name': 'NBA',
#    'slug': 'nba',
#    'category': {'name': 'USA',
#     'slug': 'usa',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'id': 15,
#     'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#     'flag': 'usa',
#     'alpha2': 'US'},
#    'uniqueTournament': {'name': 'NBA',
#     'slug': 'nba',
#     'category': {'name': 'USA',
#      'slug': 'usa',
#      'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#      'id': 15,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'flag': 'usa',
#      'alpha2': 'US'},
#     'userCount': 241344,
#     'id': 132,
#     'hasEventPlayerStatistics': False,
#     'hasBoxScore': False,
#     'displayInverseHomeAwayTeams': True,
#     'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الأميركي للمحترفين',
#       'hi': 'एनबीए',
#       'bn': 'এনবিএ'},
#      'shortNameTranslation': {}}},
#    'priority': 143,
#    'id': 177,
#    'fieldTranslations': {'nameTranslation': {'ar': 'دوري NBA',
#      'hi': 'एनबीए',
#      'bn': 'এনবিএ'},
#     'shortNameTranslation': {}}},
#   'season': {'name': 'NBA 24/25',
#    'year': '24/25',
#    'editor': False,
#    'id': 65360},
#   'customId': 'rtbkOkc',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 1,
#   'homeTeam': {'name': 'Denver Nuggets',
#    'slug': 'denver-nuggets',
#    'shortName': 'Nuggets',
#    'gender': 'M',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 97113,
#    'nameCode': 'DEN',
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 3417,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'entityType': 'team',
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'دنفر ناجتس',
#      'ru': 'Денвер Наггетс',
#      'hi': 'डेनवर नगेट्स',
#      'bn': 'ডেনভার নাগেটস'},
#     'shortNameTranslation': {'ar': 'ناجتس', 'hi': 'नगेट्स', 'bn': 'নাগেটস'}}},
#   'awayTeam': {'name': 'New Orleans Pelicans',
#    'slug': 'new-orleans-pelicans',
#    'shortName': 'Pelicans',
#    'gender': 'M',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 28654,
#    'nameCode': 'NOP',
#    'disabled': True,
#    'national': False,
#    'type': 0,
#    'id': 5539,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'entityType': 'team',
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'نيو اورليانز بيليكانز',
#      'ru': 'Нью-Орлеан Пеликанс',
#      'hi': 'न्यू ऑरलियन्स पेलिकन्स',
#      'bn': 'নিউ অরলিন্স পেলিকান'},
#     'shortNameTranslation': {'ar': 'بيليكانز',
#      'hi': 'पेलिकन्स',
#      'bn': 'পেলিকান'}}},
#   'homeScore': {'current': 125,
#    'display': 125,
#    'period1': 34,
#    'period2': 35,
#    'period3': 25,
#    'period4': 32,
#    'normaltime': 125},
#   'awayScore': {'current': 114,
#    'display': 113,
#    'period1': 23,
#    'period2': 28,
#    'period3': 35,
#    'period4': 28,
#    'normaltime': 114},
#   'time': {'played': 2880,
#    'periodLength': 720,
#    'overtimeLength': 300,
#    'totalPeriodCount': 4,
#    'currentPeriodStartTimestamp': 1738642904},
#   'changes': {'changes': ['time.played',
#     'time.currentPeriodStart',
#     'status.code',
#     'status.description',
#     'status.type',
#     'homeScore.normaltime',
#     'awayScore.normaltime'],
#    'changeTimestamp': 1738642917},
#   'hasGlobalHighlights': False,
#   'hasEventPlayerStatistics': True,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12697250,
#   'periods': {'current': 'Score',
#    'period1': '1st quarter',
#    'period2': '2nd quarter',
#    'period3': '3rd quarter',
#    'period4': '4th quarter',
#    'overtime': 'Overtime'},
#   'startTimestamp': 1738639800,
#   'slug': 'new-orleans-pelicans-denver-nuggets',
#   'finalResultOnly': False,
#   'feedLocked': False,
#   'isEditor': False,
#   'homeTeamSeasonHistoricalForm': {'wins': 30, 'losses': 19},
#   'awayTeamSeasonHistoricalForm': {'wins': 12, 'losses': 37}},
#  {'officials': [{'official': {'name': 'Jacyn Goble',
#      'jerseyNumber': '68',
#      'experience': 7,
#      'id': 7},
#     'assignment': 'head-official'},
#    {'official': {'name': 'Ray Acosta',
#      'jerseyNumber': '54',
#      'experience': 6,
#      'id': 41},
#     'assignment': 'official'},
#    {'official': {'name': 'John Conley',
#      'jerseyNumber': '56',
#      'experience': 2,
#      'id': 61},
#     'assignment': 'official'}],
#   'tournament': {'name': 'NBA',
#    'slug': 'nba',
#    'category': {'name': 'USA',
#     'slug': 'usa',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'id': 15,
#     'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#     'flag': 'usa',
#     'alpha2': 'US'},
#    'uniqueTournament': {'name': 'NBA',
#     'slug': 'nba',
#     'category': {'name': 'USA',
#      'slug': 'usa',
#      'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#      'id': 15,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'flag': 'usa',
#      'alpha2': 'US'},
#     'userCount': 241344,
#     'id': 132,
#     'hasEventPlayerStatistics': False,
#     'hasBoxScore': True,
#     'displayInverseHomeAwayTeams': True,
#     'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الأميركي للمحترفين',
#       'hi': 'एनबीए',
#       'bn': 'এনবিএ'},
#      'shortNameTranslation': {}}},
#    'priority': 143,
#    'id': 177,
#    'fieldTranslations': {'nameTranslation': {'ar': 'دوري NBA',
#      'hi': 'एनबीए',
#      'bn': 'এনবিএ'},
#     'shortNameTranslation': {}}},
#   'season': {'name': 'NBA 24/25',
#    'year': '24/25',
#    'editor': True,
#    'id': 65360},
#   'customId': 'ltbsJtb',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 2,
#   'homeTeam': {'name': 'Utah Jazz',
#    'slug': 'utah-jazz',
#    'shortName': 'Jazz',
#    'gender': 'M',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 25648,
#    'nameCode': 'UTA',
#    'disabled': True,
#    'national': True,
#    'type': 0,
#    'id': 3434,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'entityType': 'team',
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'يوتا جاز',
#      'ru': 'Юта Джаз',
#      'hi': 'यूटा जैज़',
#      'bn': 'উটাহ জ্যাজ'},
#     'shortNameTranslation': {'ar': 'جاز', 'hi': 'जैज़', 'bn': 'উটাহ জ্যাজ'}}},
#   'awayTeam': {'name': 'Indiana Pacers',
#    'slug': 'indiana-pacers',
#    'shortName': 'Pacers',
#    'gender': 'M',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 41311,
#    'nameCode': 'IND',
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 3419,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'entityType': 'team',
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'إنديانا بيسرز',
#      'ru': 'Индиана Пэйсерс',
#      'hi': 'इंडियाना पेसर्स',
#      'bn': 'ইন্ডিয়ানা প্যাকার্স'},
#     'shortNameTranslation': {'ar': 'بيسرز',
#      'hi': 'पेसर्स',
#      'bn': 'প্যাকার্স'}}},
#   'homeScore': {'current': 112,
#    'display': 112,
#    'period1': 32,
#    'period2': 30,
#    'period3': 27,
#    'period4': 24,
#    'normaltime': 111},
#   'awayScore': {'current': 112,
#    'display': 112,
#    'period1': 24,
#    'period2': 33,
#    'period3': 26,
#    'period4': 30,
#    'normaltime': 113},
#   'time': {'played': 2880,
#    'periodLength': 721,
#    'overtimeLength': 300,
#    'totalPeriodCount': 4,
#    'currentPeriodStartTimestamp': 1738643651},
#   'changes': {'changes': ['time.played'], 'changeTimestamp': 1738643699},
#   'hasGlobalHighlights': True,
#   'hasEventPlayerStatistics': False,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12697301,
#   'periods': {'current': 'Score',
#    'period1': '1st quarter',
#    'period2': '2nd quarter',
#    'period3': '3rd quarter',
#    'period4': '4th quarter',
#    'overtime': 'Overtime'},
#   'startTimestamp': 1738630800,
#   'slug': 'utah-jazz-indiana-pacers',
#   'finalResultOnly': False,
#   'feedLocked': True,
#   'isEditor': False,
#   'homeTeamSeasonHistoricalForm': {'wins': 11, 'losses': 36},
#   'awayTeamSeasonHistoricalForm': {'wins': 27, 'losses': 20}},
#  {'officials': [{'official': {'name': 'Marc Davis',
#      'jerseyNumber': '8',
#      'experience': 25,
#      'id': 3},
#     'assignment': 'head-official'},
#    {'official': {'name': "Sha'Rae Mitchell",
#      'jerseyNumber': '98',
#      'experience': 1,
#      'id': 6},
#     'assignment': 'official'},
#    {'official': {'name': 'Jason Goldenberg',
#      'jerseyNumber': '35',
#      'experience': 6,
#      'id': 66},
#     'assignment': 'official'}],
#   'tournament': {'name': 'NBA',
#    'slug': 'nba',
#    'category': {'name': 'USA',
#     'slug': 'usa',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'id': 15,
#     'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#     'flag': 'usa',
#     'alpha2': 'US'},
#    'uniqueTournament': {'name': 'NBA',
#     'slug': 'nba',
#     'category': {'name': 'USA',
#      'slug': 'usa',
#      'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#      'id': 15,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'flag': 'usa',
#      'alpha2': 'US'},
#     'userCount': 241344,
#     'id': 132,
#     'hasEventPlayerStatistics': True,
#     'hasBoxScore': False,
#     'displayInverseHomeAwayTeams': False,
#     'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الأميركي للمحترفين',
#       'hi': 'एनबीए',
#       'bn': 'এনবিএ'},
#      'shortNameTranslation': {}}},
#    'priority': 143,
#    'id': 177,
#    'fieldTranslations': {'nameTranslation': {'ar': 'دوري NBA',
#      'hi': 'एनबीए',
#      'bn': 'এনবিএ'},
#     'shortNameTranslation': {}}},
#   'season': {'name': 'NBA 24/25',
#    'year': '24/25',
#    'editor': False,
#    'id': 65360},
#   'customId': 'DtgsMtb',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 1,
#   'homeTeam': {'name': 'Golden State Warriors',
#    'slug': 'golden-state-warriors',
#    'shortName': 'Warriors',
#    'gender': 'M',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 204647,
#    'nameCode': 'GSW',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 3428,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'entityType': 'team',
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'غولدن ستايت ووريورز',
#      'ru': 'Голден Стэйт Уорриорз',
#      'hi': 'गोल्डन स्टेट वॉरियर्स',
#      'bn': 'গোল্ডেন স্টেট ওয়ারিয়র্স'},
#     'shortNameTranslation': {'ar': 'ووريورز',
#      'hi': 'वॉरियर्स',
#      'bn': 'ওয়ারিয়র্স'}}},
#   'awayTeam': {'name': 'Orlando Magic',
#    'slug': 'orlando-magic',
#    'shortName': 'Magic',
#    'gender': 'M',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 33026,
#    'nameCode': 'ORL',
#    'disabled': True,
#    'national': False,
#    'type': 0,
#    'id': 3437,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'entityType': 'team',
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'أورلاندو ماجيك',
#      'ru': 'Орландо Мэджик',
#      'hi': 'ऑरलैंडो मैजिक',
#      'bn': 'অরল্যান্ডো ম্যাজিক'},
#     'shortNameTranslation': {'ar': 'ماجيك', 'hi': 'मैजिक', 'bn': 'ম্যাজিক'}}},
#   'homeScore': {'current': 105,
#    'display': 105,
#    'period1': 19,
#    'period2': 26,
#    'period3': 40,
#    'period4': 23,
#    'normaltime': 105},
#   'awayScore': {'current': 99,
#    'display': 99,
#    'period1': 27,
#    'period2': 18,
#    'period3': 24,
#    'period4': 32,
#    'normaltime': 100},
#   'time': {'played': 2880,
#    'periodLength': 721,
#    'overtimeLength': 300,
#    'totalPeriodCount': 4,
#    'currentPeriodStartTimestamp': 1738647076},
#   'changes': {'changes': ['time.played'], 'changeTimestamp': 1738647127},
#   'hasGlobalHighlights': True,
#   'hasEventPlayerStatistics': True,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12695367,
#   'periods': {'current': 'Score',
#    'period1': '1st quarter',
#    'period2': '2nd quarter',
#    'period3': '3rd quarter',
#    'period4': '4th quarter',
#    'overtime': 'Overtime'},
#   'startTimestamp': 1738639800,
#   'slug': 'orlando-magic-golden-state-warriors',
#   'finalResultOnly': False,
#   'feedLocked': False,
#   'isEditor': True,
#   'homeTeamSeasonHistoricalForm': {'wins': 24, 'losses': 24},
#   'awayTeamSeasonHistoricalForm': {'wins': 24, 'losses': 26}},
#  {'officials': [{'official': {'name': 'Tyler Ford',
#      'jerseyNumber': '39',
#      'experience': 8,
#      'id': 4},
#     'assignment': 'head-official'},
#    {'official': {'name': 'Che Flores',
#      'jerseyNumber': '91',
#      'experience': 1,
#      'id': 32},
#     'assignment': 'official'},
#    {'official': {'name': 'Mousa Dagher',
#      'jerseyNumber': '28',
#      'experience': 5,
#      'id': 37},
#     'assignment': 'official'}],
#   'tournament': {'name': 'NBA',
#    'slug': 'nba',
#    'category': {'name': 'USA',
#     'slug': 'usa',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'id': 15,
#     'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#     'flag': 'usa',
#     'alpha2': 'US'},
#    'uniqueTournament': {'name': 'NBA',
#     'slug': 'nba',
#     'category': {'name': 'USA',
#      'slug': 'usa',
#      'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#      'id': 15,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'flag': 'usa',
#      'alpha2': 'US'},
#     'userCount': 241344,
#     'id': 132,
#     'hasEventPlayerStatistics': False,
#     'hasBoxScore': True,
#     'displayInverseHomeAwayTeams': False,
#     'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الأميركي للمحترفين',
#       'hi': 'एनबीए',
#       'bn': 'এনবিএ'},
#      'shortNameTranslation': {}}},
#    'priority': 143,
#    'id': 177,
#    'fieldTranslations': {'nameTranslation': {'ar': 'دوري NBA',
#      'hi': 'एनबीए',
#      'bn': 'এনবিএ'},
#     'shortNameTranslation': {}}},
#   'season': {'name': 'NBA 24/25',
#    'year': '24/25',
#    'editor': True,
#    'id': 65360},
#   'customId': 'otfsqtb',
#   'status': {'code': 110, 'description': 'AET', 'type': 'finished'},
#   'winnerCode': 1,
#   'homeTeam': {'name': 'Portland Trail Blazers',
#    'slug': 'portland-trail-blazers',
#    'shortName': 'Trail Blazers',
#    'gender': 'M',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 24626,
#    'nameCode': 'POR',
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 3414,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'entityType': 'team',
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'بورتلاند تريل بليزرز',
#      'ru': 'Портленд Трэйл Блэйзерс',
#      'hi': 'पोर्टलैंड ट्रेल ब्लेज़र्स',
#      'bn': 'পোর্টল্যান্ড ট্রেইল ব্লেজার'},
#     'shortNameTranslation': {'ar': 'تريل بليزرز',
#      'hi': 'ट्रेल ब्लेज़र्स',
#      'bn': 'ট্রেইল ব্লেজার'}}},
#   'awayTeam': {'name': 'Phoenix Suns',
#    'slug': 'phoenix-suns',
#    'shortName': 'Suns',
#    'gender': 'M',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 59530,
#    'nameCode': 'PHX',
#    'disabled': True,
#    'national': True,
#    'type': 0,
#    'id': 3416,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'entityType': 'team',
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'فينيكس صنز',
#      'ru': 'Финикс Санс',
#      'hi': 'फीनिक्स सन्स',
#      'bn': 'ফিনিক্স সানস'},
#     'shortNameTranslation': {'ar': 'صنز', 'hi': 'सन्स', 'bn': 'সানস'}}},
#   'homeScore': {'current': 122,
#    'display': 121,
#    'period1': 31,
#    'period2': 18,
#    'period3': 37,
#    'period4': 21,
#    'normaltime': 107,
#    'overtime': 14},
#   'awayScore': {'current': 120,
#    'display': 120,
#    'period1': 31,
#    'period2': 25,
#    'period3': 25,
#    'period4': 27,
#    'normaltime': 108,
#    'overtime': 12},
#   'time': {'played': 3600,
#    'periodLength': 720,
#    'overtimeLength': 300,
#    'totalPeriodCount': 4,
#    'currentPeriodStartTimestamp': 1738647977},
#   'changes': {'changes': ['time.played'], 'changeTimestamp': 1738648029},
#   'hasGlobalHighlights': False,
#   'hasEventPlayerStatistics': False,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12696688,
#   'periods': {'current': 'Score',
#    'period1': '1st quarter',
#    'period2': '2nd quarter',
#    'period3': '3rd quarter',
#    'period4': '4th quarter',
#    'overtime': 'Overtime'},
#   'startTimestamp': 1738645200,
#   'slug': 'phoenix-suns-portland-trail-blazers',
#   'finalResultOnly': True,
#   'feedLocked': True,
#   'isEditor': False,
#   'homeTeamSeasonHistoricalForm': {'wins': 20, 'losses': 29},
#   'awayTeamSeasonHistoricalForm': {'wins': 25, 'losses': 23}},
#  {'officials': [],
#   'tournament': {'name': 'NBA',
#    'slug': 'nba',
#    'category': {'name': 'USA',
#     'slug': 'usa',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'id': 15,
#     'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#     'flag': 'usa',
#     'alpha2': 'US'},
#    'uniqueTournament': {'name': 'NBA',
#     'slug': 'nba',
#     'category': {'name': 'USA',
#      'slug': 'usa',
#      'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#      'id': 15,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'flag': 'usa',
#      'alpha2': 'US'},
#     'userCount': 241344,
#     'id': 132,
#     'hasEventPlayerStatistics': True,
#     'hasBoxScore': False,
#     'displayInverseHomeAwayTeams': True,
#     'fieldTranslations': {'nameTranslation': {'ar': 'الدوري الأميركي للمحترفين',
#       'hi': 'एनबीए',
#       'bn': 'এনবিএ'},
#      'shortNameTranslation': {}}},
#    'priority': 143,
#    'id': 177,
#    'fieldTranslations': {'nameTranslation': {'ar': 'دوري NBA',
#      'hi': 'एनबीए',
#      'bn': 'এনবিএ'},
#     'shortNameTranslation': {}}},
#   'season': {'name': 'NBA 24/25',
#    'year': '24/25',
#    'editor': True,
#    'id': 65360},
#   'customId': 'ltbdvtb',
#   'status': {'code': 0, 'description': 'Not started', 'type': 'notstarted'},
#   'homeTeam': {'name': 'Philadelphia 76ers',
#    'slug': 'philadelphia-76ers',
#    'shortName': '76ers',
#    'gender': 'M',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 61707,
#    'nameCode': 'PHI',
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 3420,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'entityType': 'team',
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'فيلادلفيا 76ers',
#      'ru': 'Филадельфия  76ерс',
#      'hi': 'फिलाडेल्फिया 76र्स',
#      'bn': 'ফিলাডেলফিয়া 76আরস'},
#     'shortNameTranslation': {'ar': '76ers', 'hi': '76र्स', 'bn': '76আরস'}}},
#   'awayTeam': {'name': 'Dallas Mavericks',
#    'slug': 'dallas-mavericks',
#    'shortName': 'Mavericks',
#    'gender': 'M',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 105688,
#    'nameCode': 'DAL',
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 3411,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'entityType': 'team',
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'دالاس مافريكس',
#      'ru': 'Даллас Маверикс',
#      'hi': 'डलास मावेरिक्स',
#      'bn': 'ডালাস ম্যাভেরিক্স'},
#     'shortNameTranslation': {'ar': 'مافريكس',
#      'hi': 'मावेरिक्स',
#      'bn': 'ম্যাভেরিক্স'}}},
#   'homeScore': {},
#   'awayScore': {},
#   'time': {},
#   'changes': {'changeTimestamp': 0},
#   'hasGlobalHighlights': True,
# ...
#   'status': {'code': 0, 'description': 'Not started', 'type': 'notstarted'},
#   'homeTeam': {'name': 'Bora Kolday',
#    'slug': 'bora-kolday',
#    'shortName': 'Bora Kolday',
#    'gender': 'M',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 0,
#    'nameCode': 'BKO',
#    'national': True,
#    'type': 0,
#    'id': 1055504,
#    'country': {'alpha2': 'TR',
#     'alpha3': 'TUR',
#     'name': 'Türkiye',
#     'slug': 'turkiye'},
#    'entityType': 'team',
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'}},
#   'awayTeam': {'name': 'Luka Lazić',
#    'slug': 'luka-lazic',
#    'shortName': 'Luka Lazić',
#    'gender': 'M',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 2,
#    'nameCode': 'LLA',
#    'national': True,
#    'type': 0,
#    'id': 1043693,
#    'country': {'alpha2': 'RS',
#     'alpha3': 'SRB',
#     'name': 'Serbia',
#     'slug': 'serbia'},
#    'entityType': 'team',
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'}},
#   'homeScore': {},
#   'awayScore': {},
#   'coverage': -1,
#   'time': {},
#   'changes': {'changeTimestamp': 0},
#   'hasGlobalHighlights': False,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 13356940,
#   'periods': {'current': 'Score',
#    'period1': '1st quarter',
#    'period2': '2nd quarter',
#    'period3': '3rd quarter',
#    'period4': '4th quarter',
#    'overtime': 'Overtime'},
#   'startTimestamp': 1738683000,
#   'slug': 'bora-kolday-luka-lazic',
#   'finalResultOnly': False,
#   'feedLocked': False,
#   'isEditor': False},
#  {'officials': [],
#   'tournament': {'name': 'Euroleague 2k, Wildcard, Knockout',
#    'slug': 'euroleague-2k-wildcard-knockout',
#    'category': {'name': 'Virtual Basketball',
#     'slug': 'virtual-basketball',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'id': 1215,
#     'country': {},
#     'flag': 'virtual-basketball'},
#    'uniqueTournament': {'name': 'Euroleague 2K',
#     'slug': 'wallex-euroleague',
#     'category': {'name': 'Virtual Basketball',
#      'slug': 'virtual-basketball',
#      'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#      'id': 1215,
#      'country': {},
#      'flag': 'virtual-basketball'},
#     'userCount': 77,
#     'hasPerformanceGraphFeature': True,
#     'id': 23100,
#     'hasEventPlayerStatistics': False,
#     'displayInverseHomeAwayTeams': False},
#    'priority': 0,
#    'id': 144472},
#   'season': {'name': '2K25 Season 1',
#    'year': '2K25 Season 1',
#    'editor': True,
#    'id': 64630},
#   'roundInfo': {'round': 201, 'name': 'Qualification Round 1'},
#   'customId': 'EjAesjzri',
#   'status': {'code': 0, 'description': 'Not started', 'type': 'notstarted'},
#   'homeTeam': {'name': 'Uroš Rakić',
#    'slug': 'uros-rakic',
#    'shortName': 'Uroš Rakić',
#    'gender': 'M',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 1,
#    'nameCode': 'URA',
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 937979,
#    'country': {'alpha2': 'RS',
#     'alpha3': 'SRB',
#     'name': 'Serbia',
#     'slug': 'serbia'},
#    'entityType': 'team',
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'}},
#   'awayTeam': {'name': 'Pavle Savić',
#    'slug': 'pavle-savic',
#    'shortName': 'Pavle Savić',
#    'gender': 'M',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 0,
#    'nameCode': 'PSA',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 1043709,
#    'country': {'alpha2': 'RS',
#     'alpha3': 'SRB',
#     'name': 'Serbia',
#     'slug': 'serbia'},
#    'entityType': 'team',
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'}},
#   'homeScore': {},
#   'awayScore': {},
#   'coverage': -1,
#   'time': {},
#   'changes': {'changeTimestamp': 0},
#   'hasGlobalHighlights': False,
#   'crowdsourcingDataDisplayEnabled': True,
#   'id': 13356938,
#   'periods': {'current': 'Score',
#    'period1': '1st quarter',
#    'period2': '2nd quarter',
#    'period3': '3rd quarter',
#    'period4': '4th quarter',
#    'overtime': 'Overtime'},
#   'startTimestamp': 1738693800,
#   'slug': 'pavle-savic-uros-rakic',
#   'finalResultOnly': True,
#   'feedLocked': True,
#   'isEditor': False},
#  {'officials': [],
#   'tournament': {'name': 'Eurocup 2K/Virtual EuroCup - Playoffs',
#    'slug': 'amigozzz-eurocup-playoffs',
#    'category': {'name': 'Virtual Basketball',
#     'slug': 'virtual-basketball',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'id': 1215,
#     'country': {},
#     'flag': 'virtual-basketball'},
#    'uniqueTournament': {'name': 'EuroCup 2K',
#     'slug': 'amigozzz-eurocup',
#     'category': {'name': 'Virtual Basketball',
#      'slug': 'virtual-basketball',
#      'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#      'id': 1215,
#      'country': {},
#      'flag': 'virtual-basketball'},
#     'userCount': 21,
#     'hasPerformanceGraphFeature': True,
#     'id': 23101,
#     'hasEventPlayerStatistics': True,
#     'displayInverseHomeAwayTeams': True},
#    'priority': 0,
#    'id': 136482},
#   'season': {'name': '2k25 Season 1',
#    'year': '2k25 Season 1',
#    'editor': False,
#    'id': 64631},
#   'roundInfo': {'round': 5, 'name': 'Round of 16', 'cupRoundType': 8},
#   'customId': 'ekxisEzEi',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 2,
#   'homeTeam': {'name': 'Bora Kolday',
#    'slug': 'bora-kolday',
#    'shortName': 'Bora Kolday',
#    'gender': 'M',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 0,
#    'nameCode': 'BKO',
#    'national': True,
#    'type': 0,
#    'id': 1055504,
#    'country': {'alpha2': 'TR',
#     'alpha3': 'TUR',
#     'name': 'Türkiye',
#     'slug': 'turkiye'},
#    'entityType': 'team',
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'}},
#   'awayTeam': {'name': 'Giannis Moscholios',
#    'slug': 'giannis-moscholios',
#    'shortName': 'Giannis Moscholios',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 1,
#    'nameCode': 'GMO',
#    'national': True,
#    'type': 0,
#    'id': 1073329,
#    'country': {'alpha2': 'GR',
#     'alpha3': 'GRC',
#     'name': 'Greece',
#     'slug': 'greece'},
#    'entityType': 'team',
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'}},
#   'homeScore': {'current': 90, 'display': 90},
#   'awayScore': {'current': 91, 'display': 92},
#   'coverage': -1,
#   'time': {},
#   'changes': {'changeTimestamp': 0},
#   'hasGlobalHighlights': True,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 13422927,
#   'periods': {'current': 'Score',
#    'period1': '1st quarter',
#    'period2': '2nd quarter',
#    'period3': '3rd quarter',
#    'period4': '4th quarter',
#    'overtime': 'Overtime'},
#   'startTimestamp': 1738593000,
#   'slug': 'giannis-moscholios-bora-kolday',
#   'finalResultOnly': True,
#   'feedLocked': False,
#   'isEditor': False},
#  {'officials': [],
#   'tournament': {'name': 'Eurocup 2K/Virtual EuroCup - Playoffs',
#    'slug': 'amigozzz-eurocup-playoffs',
#    'category': {'name': 'Virtual Basketball',
#     'slug': 'virtual-basketball',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'id': 1215,
#     'country': {},
#     'flag': 'virtual-basketball'},
#    'uniqueTournament': {'name': 'EuroCup 2K',
#     'slug': 'amigozzz-eurocup',
#     'category': {'name': 'Virtual Basketball',
#      'slug': 'virtual-basketball',
#      'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#      'id': 1215,
#      'country': {},
#      'flag': 'virtual-basketball'},
#     'userCount': 21,
#     'hasPerformanceGraphFeature': False,
#     'id': 23101,
#     'hasEventPlayerStatistics': True,
#     'displayInverseHomeAwayTeams': False},
#    'priority': 0,
#    'id': 136482},
#   'season': {'name': '2k25 Season 1',
#    'year': '2k25 Season 1',
#    'editor': False,
#    'id': 64631},
#   'roundInfo': {'round': 5, 'name': 'Round of 16', 'cupRoundType': 8},
#   'customId': 'UqEisIrEi',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 1,
#   'homeTeam': {'name': 'Uroš Drasinover',
#    'slug': 'uros-drasinover',
#    'shortName': 'Uroš Drasinover',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 0,
#    'nameCode': 'UDR',
#    'national': True,
#    'type': 0,
#    'id': 1073333,
#    'country': {'alpha2': 'RS',
#     'alpha3': 'SRB',
#     'name': 'Serbia',
#     'slug': 'serbia'},
#    'entityType': 'team',
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'}},
#   'awayTeam': {'name': 'Milan Jović',
#    'slug': 'milan-jovic',
#    'shortName': 'Milan Jović',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 1,
#    'nameCode': 'MJO',
#    'national': True,
#    'type': 0,
#    'id': 1073383,
#    'country': {'alpha2': 'RS',
#     'alpha3': 'SRB',
#     'name': 'Serbia',
#     'slug': 'serbia'},
#    'entityType': 'team',
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'}},
#   'homeScore': {'current': 79,
#    'display': 79,
#    'period1': 15,
#    'period2': 25,
#    'period3': 17,
#    'period4': 25,
#    'normaltime': 79},
#   'awayScore': {'current': 58,
#    'display': 59,
#    'period1': 13,
#    'period2': 13,
#    'period3': 10,
#    'period4': 23,
#    'normaltime': 58},
#   'coverage': -1,
#   'time': {'currentPeriodStartTimestamp': 1738605061},
#   'changes': {'changeTimestamp': 0},
#   'hasGlobalHighlights': True,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 13421501,
#   'periods': {'current': 'Score',
#    'period1': '1st quarter',
#    'period2': '2nd quarter',
#    'period3': '3rd quarter',
#    'period4': '4th quarter',
#    'overtime': 'Overtime'},
#   'startTimestamp': 1738607400,
#   'slug': 'milan-jovic-uros-drasinover',
#   'finalResultOnly': True,
#   'feedLocked': False,
#   'isEditor': True},
#  {'officials': [],
#   'tournament': {'name': 'Eurocup 2K/Virtual EuroCup - Playoffs',
#    'slug': 'amigozzz-eurocup-playoffs',
#    'category': {'name': 'Virtual Basketball',
#     'slug': 'virtual-basketball',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'id': 1215,
#     'country': {},
#     'flag': 'virtual-basketball'},
#    'uniqueTournament': {'name': 'EuroCup 2K',
#     'slug': 'amigozzz-eurocup',
#     'category': {'name': 'Virtual Basketball',
#      'slug': 'virtual-basketball',
#      'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#      'id': 1215,
#      'country': {},
#      'flag': 'virtual-basketball'},
#     'userCount': 21,
#     'hasPerformanceGraphFeature': True,
#     'id': 23101,
#     'hasEventPlayerStatistics': True,
#     'displayInverseHomeAwayTeams': True},
#    'priority': 0,
#    'id': 136482},
#   'season': {'name': '2k25 Season 1',
#    'year': '2k25 Season 1',
#    'editor': True,
#    'id': 64631},
#   'roundInfo': {'round': 5, 'name': 'Round of 16', 'cupRoundType': 8},
#   'customId': 'ekxisEcEi',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 1,
#   'aggregatedWinnerCode': 1,
#   'homeTeam': {'name': 'Giannis Moscholios',
#    'slug': 'giannis-moscholios',
#    'shortName': 'Giannis Moscholios',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 1,
#    'nameCode': 'GMO',
#    'national': False,
#    'type': 0,
#    'id': 1073329,
#    'country': {'alpha2': 'GR',
#     'alpha3': 'GRC',
#     'name': 'Greece',
#     'slug': 'greece'},
#    'entityType': 'team',
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'}},
#   'awayTeam': {'name': 'Bora Kolday',
#    'slug': 'bora-kolday',
#    'shortName': 'Bora Kolday',
#    'gender': 'M',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 0,
#    'nameCode': 'BKO',
#    'national': True,
#    'type': 0,
#    'id': 1055504,
#    'country': {'alpha2': 'TR',
#     'alpha3': 'TUR',
#     'name': 'Türkiye',
#     'slug': 'turkiye'},
#    'entityType': 'team',
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'}},
#   'homeScore': {'current': 101,
#    'display': 102,
#    'period1': 24,
#    'period2': 18,
#    'period3': 25,
#    'period4': 36,
#    'normaltime': 101},
#   'awayScore': {'current': 56,
#    'display': 56,
#    'period1': 19,
#    'period2': 13,
#    'period3': 14,
#    'period4': 12,
#    'normaltime': 57},
#   'coverage': -1,
#   'time': {'currentPeriodStartTimestamp': 1738609876},
#   'changes': {'changeTimestamp': 0},
#   'hasGlobalHighlights': False,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 13421521,
#   'periods': {'current': 'Score',
#    'period1': '1st quarter',
#    'period2': '2nd quarter',
#    'period3': '3rd quarter',
#    'period4': '4th quarter',
#    'overtime': 'Overtime'},
#   'previousLegEventId': 13422927,
#   'startTimestamp': 1738604700,
#   'slug': 'giannis-moscholios-bora-kolday',
#   'finalResultOnly': False,
#   'feedLocked': True,
#   'isEditor': True},
#  {'officials': [],
#   'tournament': {'name': 'Eurocup 2K/Virtual EuroCup - Playoffs',
#    'slug': 'amigozzz-eurocup-playoffs',
#    'category': {'name': 'Virtual Basketball',
#     'slug': 'virtual-basketball',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'id': 1215,
#     'country': {},
#     'flag': 'virtual-basketball'},
#    'uniqueTournament': {'name': 'EuroCup 2K',
#     'slug': 'amigozzz-eurocup',
#     'category': {'name': 'Virtual Basketball',
#      'slug': 'virtual-basketball',
#      'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#      'id': 1215,
#      'country': {},
#      'flag': 'virtual-basketball'},
#     'userCount': 21,
#     'hasPerformanceGraphFeature': True,
#     'id': 23101,
#     'hasEventPlayerStatistics': True,
#     'displayInverseHomeAwayTeams': False},
#    'priority': 0,
#    'id': 136482},
#   'season': {'name': '2k25 Season 1',
#    'year': '2k25 Season 1',
#    'editor': True,
#    'id': 64631},
#   'roundInfo': {'round': 5, 'name': 'Round of 16', 'cupRoundType': 8},
#   'customId': 'IiEisIrEi',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 2,
#   'aggregatedWinnerCode': 2,
#   'homeTeam': {'name': 'Milan Jović',
#    'slug': 'milan-jovic',
#    'shortName': 'Milan Jović',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 1,
#    'nameCode': 'MJO',
#    'national': True,
#    'type': 0,
#    'id': 1073383,
#    'country': {'alpha2': 'RS',
#     'alpha3': 'SRB',
#     'name': 'Serbia',
#     'slug': 'serbia'},
#    'entityType': 'team',
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'}},
#   'awayTeam': {'name': 'Uroš Drasinover',
#    'slug': 'uros-drasinover',
#    'shortName': 'Uroš Drasinover',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 0,
#    'nameCode': 'UDR',
#    'national': True,
#    'type': 0,
#    'id': 1073333,
#    'country': {'alpha2': 'RS',
#     'alpha3': 'SRB',
#     'name': 'Serbia',
#     'slug': 'serbia'},
#    'entityType': 'team',
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'}},
#   'homeScore': {'current': 73,
#    'display': 73,
#    'period1': 19,
#    'period2': 13,
#    'period3': 23,
#    'period4': 19,
#    'normaltime': 74},
#   'awayScore': {'current': 89,
#    'display': 88,
#    'period1': 20,
#    'period2': 30,
#    'period3': 19,
#    'period4': 20,
#    'normaltime': 88},
#   'coverage': -1,
#   'time': {'currentPeriodStartTimestamp': 1738610081},
#   'changes': {'changeTimestamp': 0},
#   'hasGlobalHighlights': False,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 13421505,
#   'periods': {'current': 'Score',
#    'period1': '1st quarter',
#    'period2': '2nd quarter',
#    'period3': '3rd quarter',
#    'period4': '4th quarter',
#    'overtime': 'Overtime'},
#   'previousLegEventId': 13421501,
#   'startTimestamp': 1738597500,
#   'slug': 'milan-jovic-uros-drasinover',
#   'finalResultOnly': False,
#   'feedLocked': True,
#   'isEditor': True}]

# %%
# Ce qui nous intéresse ce sont les matchs disponible pour lesquels on a les informations importantes
# Pour continuer ce DOJO, vous aurez besoin de l'ID du match que vous allez choisir pour analyser
# ICI on vous donne la façon d'accéder aux matchs et trouver les noms des équipes
print("Matchs disponibles :")
for match in matches:
    print(f"Match ID: {match['id']}, {match['homeTeam']['name']} vs {match['awayTeam']['name']}")
# Out:
# Matchs disponibles :
# Match ID: 12696916, Charlotte Hornets vs Washington Wizards
# Match ID: 12696894, Detroit Pistons vs Atlanta Hawks
# Match ID: 12697344, New York Knicks vs Houston Rockets
# Match ID: 12696754, Memphis Grizzlies vs San Antonio Spurs
# Match ID: 13074043, SUNY Cobleskill Fighting Tigers vs Suny ESF Mighty Oaks
# Match ID: 13074038, Covenant Fighting Scots vs Asbury College Eagles
# Match ID: 13074041, Elms Blazers vs Norwich Cadets
# Match ID: 13423127, La Grange Panthers vs PCC Eagles
# Match ID: 13074039, New England Pilgrims vs Regis Pride
# Match ID: 13074040, Pfeiffer Falcons vs Brevard Tornados
# Match ID: 13074042, St. Joseph Blue Jays vs Dean Bulldogs
# Match ID: 13399483, Warren Wilson Owls vs Bob Jones Bruins
# Match ID: 13074020, Albertus Magnus Falcons vs Emmanuel Saints
# Match ID: 13074213, Castleton State Spartans vs Keene State Owls
# Match ID: 13423128, Cortland Red Dragons vs Fredonia State Blue Devils
# Match ID: 13073106, Elmira Soaring Eagles vs Keuka Wolves
# Match ID: 13074046, Johnson AND Wales Wildcats (RI) vs Lasell Lasers
# Match ID: 13074047, St. Joseph´s Monks vs Rivier Raiders
# Match ID: 13074060, George Fox Bruins vs Pacific Boxers
# Match ID: 13305623, Phantom BC vs Mist BC
# Match ID: 13305632, Vinyl BC vs Lunar Owls BC
# Match ID: 13301933, BC Cherkaski Mavpy vs BC Kyiv-Basket
# Match ID: 13342202, Urunday Universitario vs Peñarol
# Match ID: 13342214, Urupan vs Nacional
# Match ID: 13342199, CA Welcome vs Trouville
# Match ID: 13342211, Defensor Sporting vs Malvín
# Match ID: 13342210, Aguada vs Hebraica Macabi
# Match ID: 13342203, Cordón vs Biguá de Villa Biarritz
# Match ID: 13282056, Maccabi Playtika Tel-Aviv (eSport) vs Panathinaikos AKTOR Athens (eSport)
# Match ID: 13282146, Panathinaikos AKTOR Athens (eSport) vs Crvena zvezda Meridianbet Belgrade (eSport)
# Match ID: 13356940, Bora Kolday vs Luka Lazić
# Match ID: 13356938, Uroš Rakić vs Pavle Savić
# Match ID: 13422927, Bora Kolday vs Giannis Moscholios
# Match ID: 13421501, Uroš Drasinover vs Milan Jović
# Match ID: 13421521, Giannis Moscholios vs Bora Kolday
# Match ID: 13421505, Milan Jović vs Uroš Drasinover

# %% [markdown]
# ## Étape 2 : Sélectionner un match et récupérer les id et noms des joueurs

# %%
# Saisir un ID au hasard ou un match qui est intéressant pour vous
match_id = input("Entrez l'ID du match : ")

# On construit l'URL pour les compositions
url_lineups = f'https://api.sofascore.com/api/v1/event/{match_id}/lineups'

# Fais une requête GET
response = requests.get(url_lineups)

# Récupére les données de ta response sous format JSON
data = response.json()
data
# Out:
# Entrez l'ID du match : 12731845
# {'confirmed': True,
#  'home': {'players': [{'player': {'name': 'Bobby Portis',
#      'firstName': 'Bobby',
#      'lastName': 'Portis',
#      'slug': 'portis-bobby',
#      'shortName': 'B. Portis',
#      'position': 'F',
#      'jerseyNumber': '9',
#      'height': 208,
#      'userCount': 1854,
#      'id': 817329,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 792374400,
#      'fieldTranslations': {'nameTranslation': {'ar': 'بورتيس، بوبي',
#        'hi': 'पोर्टिस, बॉबी',
#        'bn': 'পোর্টিস, ববি'},
#       'shortNameTranslation': {'ar': 'ب. بورتيس',
#        'hi': 'बी. पोर्टिस',
#        'bn': 'বি. পোর্টিস'}}},
#     'teamId': 3410,
#     'shirtNumber': 9,
#     'jerseyNumber': '9',
#     'position': 'F',
#     'substitute': False,
#     'statistics': {'secondsPlayed': 532,
#      'points': 22,
#      'twoPointsMade': 4,
#      'twoPointAttempts': 4,
#      'threePointsMade': 6,
#      'threePointAttempts': 4,
#      'freeThrowsMade': 2,
#      'freeThrowAttempts': 0,
#      'fieldGoalsMade': 2,
#      'fieldGoalAttempts': 6,
#      'rebounds': 2,
#      'defensiveRebounds': 0,
#      'offensiveRebounds': 0,
#      'turnovers': 0,
#      'blocks': 0,
#      'personalFouls': 0,
#      'assists': 0,
#      'steals': 0,
#      'plusMinus': 20,
#      'fieldGoalPct': 2}},
#    {'player': {'name': 'Chris Livingston',
#      'slug': 'livingston-chris',
#      'shortName': 'C. Livingston',
#      'position': 'F',
#      'jerseyNumber': '7',
#      'height': 201,
#      'userCount': 70,
#      'id': 1458354,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 1066176000,
#      'fieldTranslations': {'nameTranslation': {'ar': 'ليفينغستون، كريس',
#        'hi': 'लिविंगस्टन, क्रिस',
#        'bn': 'লিভিংস্টন, ক্রিস'},
#       'shortNameTranslation': {'ar': 'ك. ليفينغستون',
#        'hi': 'सी. लिविंगस्टन',
#        'bn': 'সি লিভিংস্টন'}}},
#     'teamId': 3410,
#     'shirtNumber': 7,
#     'jerseyNumber': '7',
#     'position': 'F',
#     'substitute': False,
#     'statistics': {'secondsPlayed': 594,
#      'points': 0,
#      'twoPointsMade': 0,
#      'twoPointAttempts': 2,
#      'threePointsMade': 0,
#      'threePointAttempts': 0,
#      'freeThrowsMade': 2,
#      'freeThrowAttempts': 4,
#      'fieldGoalsMade': 0,
#      'fieldGoalAttempts': 2,
#      'rebounds': 0,
#      'defensiveRebounds': 0,
#      'offensiveRebounds': 0,
#      'turnovers': 0,
#      'blocks': 0,
#      'personalFouls': 2,
#      'assists': 0,
#      'steals': 0,
#      'plusMinus': 0,
#      'fieldGoalPct': 70}},
#    {'player': {'name': 'Andre Jackson Jr.',
#      'slug': 'jackson-andre',
#      'shortName': 'A. Jackson',
#      'position': 'GF',
#      'jerseyNumber': '44',
#      'height': 198,
#      'userCount': 238,
#      'id': 1179050,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 1005609600,
#      'fieldTranslations': {'nameTranslation': {'ar': 'أندريه جاكسون',
#        'hi': 'जैक्सन, आंद्रे',
#        'bn': 'জ্যাকসন, আন্দ্রে'},
#       'shortNameTranslation': {'ar': 'أ. جاكسون',
#        'hi': 'ए. जैक्सन',
#        'bn': 'এ. জ্যাকসন'}}},
#     'teamId': 3410,
#     'shirtNumber': 44,
#     'jerseyNumber': '44',
#     'position': 'GF',
#     'substitute': False,
#     'statistics': {'secondsPlayed': 544,
#      'points': 2,
#      'twoPointsMade': 0,
#      'twoPointAttempts': 4,
#      'threePointsMade': 0,
#      'threePointAttempts': 0,
#      'freeThrowsMade': 0,
#      'freeThrowAttempts': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalAttempts': 2,
#      'rebounds': 0,
#      'defensiveRebounds': 0,
#      'offensiveRebounds': 0,
#      'turnovers': 0,
#      'blocks': 0,
#      'personalFouls': 0,
#      'assists': 0,
#      'steals': 0,
#      'plusMinus': 0,
#      'fieldGoalPct': 12}},
#    {'player': {'name': 'MarJon Beauchamp',
#      'firstName': 'MarJon',
#      'lastName': 'Beauchamp',
#      'slug': 'beauchamp-marjon',
#      'shortName': 'M. Beauchamp',
#      'position': 'F',
#      'jerseyNumber': '3',
#      'height': 201,
#      'userCount': 242,
#      'id': 1206073,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 971308800,
#      'fieldTranslations': {'nameTranslation': {'ar': 'بوشامب، مارجون',
#        'hi': 'ब्यूचैम्प, मार्जोन',
#        'bn': 'বিউচ্যাম্প, মারজন'},
#       'shortNameTranslation': {'ar': 'م. بوشامب',
#        'hi': 'एम. ब्यूचैम्प',
#        'bn': 'এম. বেউচ্যাম্প'}}},
#     'teamId': 3410,
#     'shirtNumber': 3,
#     'jerseyNumber': '3',
#     'position': 'F',
#     'substitute': True,
#     'statistics': {'secondsPlayed': 0,
#      'points': 4,
#      'twoPointsMade': 0,
#      'twoPointAttempts': 0,
#      'threePointsMade': 0,
#      'threePointAttempts': 0,
#      'freeThrowsMade': 0,
#      'freeThrowAttempts': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalAttempts': 2,
#      'rebounds': 2,
#      'defensiveRebounds': 0,
#      'offensiveRebounds': 0,
#      'turnovers': 0,
#      'blocks': 0,
#      'personalFouls': 0,
#      'assists': 4,
#      'steals': 0,
#      'plusMinus': 0,
#      'fieldGoalPct': 128}},
#    {'player': {'name': 'Anzejs Pasecniks',
#      'firstName': 'Anzejs',
#      'lastName': 'Pasecniks',
#      'slug': 'pasecniks-anzejs',
#      'shortName': 'A. Pasecniks',
#      'position': 'C',
#      'jerseyNumber': '18',
#      'height': 218,
#      'userCount': 133,
#      'id': 861688,
#      'country': {'alpha2': 'LV',
#       'alpha3': 'LVA',
#       'name': 'Latvia',
#       'slug': 'latvia'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 819417600,
#      'fieldTranslations': {'nameTranslation': {'ar': 'أنجيهس باسيتسنيكس',
#        'hi': 'पासेकनिक्स, अंजेज',
#        'bn': 'পাসেকনিকস, আনজেজেএস'},
#       'shortNameTranslation': {'ar': 'أ. باسيتسنيكس',
#        'hi': 'ए. पासेकनिक्स',
#        'bn': 'এ. প্যাসেকনিকস'}}},
#     'teamId': 37760,
#     'shirtNumber': 18,
#     'jerseyNumber': '18',
#     'position': 'C',
#     'substitute': False,
#     'statistics': {'secondsPlayed': 664,
#      'points': 0,
#      'twoPointsMade': 0,
#      'twoPointAttempts': 2,
#      'threePointsMade': 0,
#      'threePointAttempts': 0,
#      'freeThrowsMade': 0,
#      'freeThrowAttempts': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalAttempts': 6,
#      'rebounds': 0,
#      'defensiveRebounds': 0,
#      'offensiveRebounds': 0,
#      'turnovers': 0,
#      'blocks': 0,
#      'personalFouls': 4,
#      'assists': 0,
#      'steals': 0,
#      'plusMinus': 0,
#      'fieldGoalPct': 44}},
#    {'player': {'name': 'Liam Robbins',
#      'slug': 'robbins-liam',
#      'shortName': 'L. Robbins',
#      'position': 'C',
#      'jerseyNumber': '15',
#      'height': 213,
#      'userCount': 41,
#      'id': 1178333,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 931737600,
#      'fieldTranslations': {'nameTranslation': {'ar': 'ليام روبينز',
#        'hi': 'रॉबिन्स, लियाम',
#        'bn': 'রবিন্স, লিয়াম'},
#       'shortNameTranslation': {'ar': 'ل. روبينز',
#        'hi': 'एल. रॉबिन्स',
#        'bn': 'এল. রবিনস'}}},
#     'teamId': 3410,
#     'shirtNumber': 15,
#     'jerseyNumber': '15',
#     'position': 'C',
#     'substitute': True,
#     'statistics': {'secondsPlayed': 1238,
#      'points': 2,
#      'twoPointsMade': 2,
#      'twoPointAttempts': 4,
#      'threePointsMade': 0,
#      'threePointAttempts': 0,
#      'freeThrowsMade': 0,
#      'freeThrowAttempts': 0,
#      'fieldGoalsMade': 2,
#      'fieldGoalAttempts': 6,
#      'rebounds': 4,
#      'defensiveRebounds': 4,
#      'offensiveRebounds': 2,
#      'turnovers': 2,
#      'blocks': 0,
#      'personalFouls': 0,
#      'assists': 2,
#      'steals': 0,
#      'plusMinus': 0,
#      'fieldGoalPct': 52}},
#    {'player': {'name': 'Brook Lopez',
#      'firstName': 'Brook',
#      'lastName': 'Lopez',
#      'slug': 'lopez-brook',
#      'shortName': 'B. Lopez',
#      'position': 'C',
#      'jerseyNumber': '11',
#      'height': 216,
#      'userCount': 2791,
#      'id': 817236,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 575856000,
#      'fieldTranslations': {'nameTranslation': {'ar': 'لوبيز، بروك',
#        'hi': 'लोपेज़, ब्रुक',
#        'bn': 'লোপেজ, ব্রুক'},
#       'shortNameTranslation': {'ar': 'ب. لوبيز',
#        'hi': 'बी. लोपेज़',
#        'bn': 'বি. লোপেজ'}}},
#     'teamId': 3410,
#     'shirtNumber': 11,
#     'jerseyNumber': '11',
#     'position': 'C',
#     'substitute': True,
#     'statistics': {'secondsPlayed': 1360,
#      'points': 0,
#      'twoPointsMade': 0,
#      'twoPointAttempts': 0,
#      'threePointsMade': 0,
#      'threePointAttempts': 0,
#      'freeThrowsMade': 0,
#      'freeThrowAttempts': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalAttempts': 0,
#      'rebounds': 0,
#      'defensiveRebounds': 0,
#      'offensiveRebounds': 0,
#      'turnovers': 0,
#      'blocks': 0,
#      'personalFouls': 0,
#      'assists': 2,
#      'steals': 0,
#      'plusMinus': 0,
#      'fieldGoalPct': 0}},
#    {'player': {'name': 'Damian Lillard',
#      'firstName': 'Damian',
#      'lastName': 'Lillard',
#      'slug': 'lillard-damian',
#      'shortName': 'D. Lillard',
#      'position': 'G',
#      'jerseyNumber': '0',
#      'height': 188,
#      'userCount': 19956,
#      'id': 817232,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 648000000,
#      'fieldTranslations': {'nameTranslation': {'ar': 'ليلارد، داميان',
#        'hi': 'लिलार्ड, डेमियन',
#        'bn': 'লিলার্ড, ড্যামিয়ান'},
#       'shortNameTranslation': {'ar': 'د. ليلارد',
#        'hi': 'डी. लिलार्ड',
#        'bn': 'ডি. লিলার্ড'}}},
#     'teamId': 3410,
#     'shirtNumber': 0,
#     'jerseyNumber': '0',
#     'position': 'G',
#     'substitute': False,
#     'statistics': {'secondsPlayed': 1378,
#      'points': 14,
#      'twoPointsMade': 0,
#      'twoPointAttempts': 0,
#      'threePointsMade': 0,
#      'threePointAttempts': 0,
#      'freeThrowsMade': 0,
#      'freeThrowAttempts': 2,
#      'fieldGoalsMade': 0,
#      'fieldGoalAttempts': 10,
#      'rebounds': 6,
#      'defensiveRebounds': 4,
#      'offensiveRebounds': 0,
#      'turnovers': 2,
#      'blocks': 0,
#      'personalFouls': 0,
#      'assists': 0,
#      'steals': 0,
#      'plusMinus': 0,
#      'fieldGoalPct': 12}},
#    {'player': {'name': 'Gary Trent Jr.',
#      'firstName': 'Gary',
#      'lastName': 'Trent Jr.',
#      'slug': 'gary-trent-jr',
#      'shortName': 'G. Trent Jr.',
#      'position': 'GF',
#      'jerseyNumber': '5',
#      'height': 196,
#      'userCount': 1020,
#      'id': 940761,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 916617600,
#      'fieldTranslations': {'nameTranslation': {'ar': 'غاري ترينت جونيور',
#        'hi': 'गैरी ट्रेंट जूनियर.',
#        'bn': 'গ্যারি ট্রেন্ট জুনিয়র'},
#       'shortNameTranslation': {'ar': 'غ. ترينت جونيور',
#        'hi': 'जी. ट्रेंट जूनियर',
#        'bn': 'জি. ট্রেন্ট জুনিয়র'}}},
#     'teamId': 3410,
#     'shirtNumber': 5,
#     'jerseyNumber': '5',
#     'position': 'GF',
#     'substitute': False,
#     'statistics': {'secondsPlayed': 1438,
#      'points': 4,
#      'twoPointsMade': 0,
#      'twoPointAttempts': 0,
#      'threePointsMade': 0,
#      'threePointAttempts': 2,
#      'freeThrowsMade': 0,
#      'freeThrowAttempts': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalAttempts': 0,
#      'rebounds': 2,
#      'defensiveRebounds': 2,
#      'offensiveRebounds': 0,
#      'turnovers': 0,
#      'blocks': 0,
#      'personalFouls': 0,
#      'assists': 0,
#      'steals': 0,
#      'plusMinus': 4,
#      'fieldGoalPct': 22}}],
#   'supportStaff': [],
#   'playerColor': {'primary': '000000',
#    'number': 'eee1c6',
#    'outline': '00471b',
#    'fancyNumber': '222226'},
#   'goalkeeperColor': {'primary': '000000',
#    'number': '000000',
#    'outline': 'fafb00',
#    'fancyNumber': '222226'}},
#  'away': {'players': [{'player': {'name': 'Jaxson Hayes',
#      'firstName': 'Jaxson',
#      'lastName': 'Hayes ',
#      'slug': 'jaxson-hayes',
#      'shortName': 'J. Hayes',
#      'position': 'CF',
#      'jerseyNumber': '11',
#      'height': 213,
#      'userCount': 546,
#      'id': 987100,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 959040000,
#      'fieldTranslations': {'nameTranslation': {'ar': 'جاكسون هايز',
#        'hi': 'जैक्सन हेस',
#        'bn': 'জ্যাকসন হেইস'},
#       'shortNameTranslation': {'ar': 'ج. هايز',
#        'hi': 'जे. हेस',
#        'bn': 'জে. হেইস'}}},
#     'teamId': 3427,
#     'shirtNumber': 11,
#     'jerseyNumber': '11',
#     'position': 'CF',
#     'substitute': True,
#     'statistics': {'secondsPlayed': 674,
#      'points': 4,
#      'twoPointsMade': 2,
#      'twoPointAttempts': 2,
#      'threePointsMade': 0,
#      'threePointAttempts': 0,
#      'freeThrowsMade': 0,
#      'freeThrowAttempts': 0,
#      'fieldGoalsMade': 2,
#      'fieldGoalAttempts': 4,
#      'rebounds': 6,
#      'defensiveRebounds': 2,
#      'offensiveRebounds': 0,
#      'turnovers': 0,
#      'blocks': 0,
#      'personalFouls': 0,
#      'assists': 0,
#      'steals': 0,
#      'plusMinus': 0,
#      'fieldGoalPct': 140}},
#    {'player': {'name': 'Bronny James',
#      'slug': 'james-bronny',
#      'shortName': 'B. James',
#      'position': 'G',
#      'jerseyNumber': '9',
#      'height': 188,
#      'userCount': 8923,
#      'id': 1600531,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 1097020800},
#     'teamId': 3427,
#     'shirtNumber': 9,
#     'jerseyNumber': '9',
#     'position': 'G',
#     'substitute': False,
#     'statistics': {'secondsPlayed': 726,
#      'points': 0,
#      'twoPointsMade': 0,
#      'twoPointAttempts': 0,
#      'threePointsMade': 0,
#      'threePointAttempts': 2,
#      'freeThrowsMade': 0,
#      'freeThrowAttempts': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalAttempts': 6,
#      'rebounds': 0,
#      'defensiveRebounds': 0,
#      'offensiveRebounds': 0,
#      'turnovers': 0,
#      'blocks': 0,
#      'personalFouls': 0,
#      'assists': 0,
#      'steals': 0,
#      'plusMinus': 0,
#      'fieldGoalPct': 0}},
#    {'player': {'name': 'Armel Traore',
#      'firstName': 'Armel',
#      'lastName': 'Traore',
#      'slug': 'traore-armel',
#      'shortName': 'A. Traore',
#      'position': 'F',
#      'jerseyNumber': '94',
#      'height': 205,
#      'userCount': 258,
#      'id': 1144675,
#      'country': {'alpha2': 'FR',
#       'alpha3': 'FRA',
#       'name': 'France',
#       'slug': 'france'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 1043280000,
#      'fieldTranslations': {'nameTranslation': {'ar': 'تراوري، أرمل',
#        'hi': 'ट्राओरे, आर्मेल',
#        'bn': 'ট্রাওরে, আরমেল'},
#       'shortNameTranslation': {'ar': 'أ. تراوري',
#        'hi': 'ए. ट्राओरे',
#        'bn': 'এ. ট্রাওরে'}}},
#     'teamId': 131420,
#     'shirtNumber': 94,
#     'jerseyNumber': '94',
#     'position': 'F',
#     'substitute': False,
#     'statistics': {'secondsPlayed': 912,
#      'points': 6,
#      'twoPointsMade': 2,
#      'twoPointAttempts': 0,
#      'threePointsMade': 0,
#      'threePointAttempts': 2,
#      'freeThrowsMade': 0,
#      'freeThrowAttempts': 0,
#      'fieldGoalsMade': 2,
#      'fieldGoalAttempts': 6,
#      'rebounds': 6,
#      'defensiveRebounds': 2,
#      'offensiveRebounds': 2,
#      'turnovers': 0,
#      'blocks': 0,
#      'personalFouls': 2,
#      'assists': 0,
#      'steals': 0,
#      'plusMinus': 0,
#      'fieldGoalPct': 16}},
#    {'player': {'name': 'Colin Castleton',
#      'slug': 'castleton-colin',
#      'shortName': 'C. Castleton',
#      'position': 'C',
#      'jerseyNumber': '8',
#      'height': 208,
#      'userCount': 130,
#      'id': 1179398,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 959212800,
#      'fieldTranslations': {'nameTranslation': {'ar': 'كولين كاسلتون',
#        'hi': 'कैसलटन, कोलिन',
#        'bn': 'ক্যাসেলটন, কলিন'},
#       'shortNameTranslation': {'ar': 'ك. كاسلتون',
#        'hi': 'सी. कैसलटन',
#        'bn': 'সি. ক্যাসেলটন'}}},
#     'teamId': 270117,
#     'shirtNumber': 14,
#     'jerseyNumber': '14',
#     'position': 'C',
#     'substitute': True,
#     'statistics': {'secondsPlayed': 728,
#      'points': 0,
#      'twoPointsMade': 0,
#      'twoPointAttempts': 0,
#      'threePointsMade': 0,
#      'threePointAttempts': 0,
#      'freeThrowsMade': 0,
#      'freeThrowAttempts': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalAttempts': 0,
#      'rebounds': 4,
#      'defensiveRebounds': 4,
#      'offensiveRebounds': 0,
#      'turnovers': 0,
#      'blocks': 0,
#      'personalFouls': 0,
#      'assists': 6,
#      'steals': 0,
#      'plusMinus': 18,
#      'fieldGoalPct': 108}},
#    {'player': {'name': 'Maxwell Lewis',
#      'firstName': '',
#      'lastName': '',
#      'slug': 'lewis-maxwell',
#      'shortName': 'M. Lewis',
#      'position': 'F',
#      'jerseyNumber': '20',
#      'height': 201,
#      'userCount': 187,
#      'id': 1181769,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 1027728000,
#      'fieldTranslations': {'nameTranslation': {'ar': 'ماكسويل لويس',
#        'hi': 'लुईस, मैक्सवेल',
#        'bn': 'লুইস, ম্যাক্সওয়েল'},
#       'shortNameTranslation': {'ar': 'م. لويس',
#        'hi': 'एम. लुईस',
#        'bn': 'এম. লুইস'}}},
#     'teamId': 3436,
#     'shirtNumber': 20,
#     'jerseyNumber': '20',
#     'position': 'F',
#     'substitute': True,
#     'statistics': {'secondsPlayed': 1122,
#      'points': 6,
#      'twoPointsMade': 2,
#      'twoPointAttempts': 6,
#      'threePointsMade': 0,
#      'threePointAttempts': 0,
#      'freeThrowsMade': 0,
#      'freeThrowAttempts': 0,
#      'fieldGoalsMade': 2,
#      'fieldGoalAttempts': 2,
#      'rebounds': 0,
#      'defensiveRebounds': 0,
#      'offensiveRebounds': 0,
#      'turnovers': 0,
#      'blocks': 0,
#      'personalFouls': 0,
#      'assists': 0,
#      'steals': 0,
#      'plusMinus': 4,
#      'fieldGoalPct': 88}},
#    {'player': {'name': 'Jalen Hood-Schifino',
#      'slug': 'hood-schifino-jalen',
#      'shortName': 'J. Hood-Schifino',
#      'position': 'G',
#      'jerseyNumber': '0',
#      'height': 196,
#      'userCount': 242,
#      'id': 1433947,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 1055980800,
#      'fieldTranslations': {'nameTranslation': {'ar': 'جيلين هوود-شيفينو',
#        'hi': 'हूड शिफिनो, जालेन',
#        'bn': 'হুড শিফিনো, জালেন'},
#       'shortNameTranslation': {'ar': 'ج. هوود-شيفينو',
#        'hi': 'जे. हूड शिफिनो',
#        'bn': 'জে. হুড-শিফিনো'}}},
#     'teamId': 3434,
#     'shirtNumber': 0,
#     'jerseyNumber': '0',
#     'position': 'G',
#     'substitute': False,
#     'statistics': {'secondsPlayed': 336,
#      'points': 0,
#      'twoPointsMade': 0,
#      'twoPointAttempts': 0,
#      'threePointsMade': 0,
#      'threePointAttempts': 0,
#      'freeThrowsMade': 0,
#      'freeThrowAttempts': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalAttempts': 2,
#      'rebounds': 0,
#      'defensiveRebounds': 0,
#      'offensiveRebounds': 0,
#      'turnovers': 0,
#      'blocks': 0,
#      'personalFouls': 0,
#      'assists': 0,
#      'steals': 0,
#      'plusMinus': 0,
#      'fieldGoalPct': 24}},
#    {'player': {'name': 'Dalton Knecht',
#      'slug': 'knecht-dalton',
#      'shortName': 'D. Knecht',
#      'position': 'G',
#      'jerseyNumber': '4',
#      'height': 198,
#      'userCount': 1845,
#      'id': 1181979,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 987638400},
#     'teamId': 3427,
#     'shirtNumber': 4,
#     'jerseyNumber': '4',
#     'position': 'G',
#     'substitute': False,
#     'statistics': {'secondsPlayed': 2628,
#      'points': 14,
#      'twoPointsMade': 0,
#      'twoPointAttempts': 4,
#      'threePointsMade': 0,
#      'threePointAttempts': 0,
#      'freeThrowsMade': 0,
#      'freeThrowAttempts': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalAttempts': 16,
#      'rebounds': 6,
#      'defensiveRebounds': 0,
#      'offensiveRebounds': 0,
#      'turnovers': 0,
#      'blocks': 0,
#      'personalFouls': 8,
#      'assists': 4,
#      'steals': 0,
#      'plusMinus': 0,
#      'fieldGoalPct': 58}},
#    {'player': {'name': 'Rui Hachimura',
#      'firstName': 'Rui',
#      'lastName': 'Hachimura ',
#      'slug': 'rui-hachimura',
#      'shortName': 'R. Hachimura',
#      'position': 'F',
#      'jerseyNumber': '28',
#      'height': 203,
#      'userCount': 2754,
#      'id': 988788,
#      'country': {'alpha2': 'JP',
#       'alpha3': 'JPN',
#       'name': 'Japan',
#       'slug': 'japan'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 886896000,
#      'fieldTranslations': {'nameTranslation': {'ar': 'روي هاتشيمورا',
#        'hi': 'रुई हचिमुरा',
#        'bn': 'রুই হাচিমুরা'},
#       'shortNameTranslation': {'ar': 'ر. هاتشيمورا',
#        'hi': 'आर. हचिमुरा',
#        'bn': 'আর. হাচিমুরা'}}},
#     'teamId': 3427,
#     'shirtNumber': 28,
#     'jerseyNumber': '28',
#     'position': 'F',
#     'substitute': False,
#     'statistics': {'secondsPlayed': 1406,
#      'points': 10,
#      'twoPointsMade': 0,
#      'twoPointAttempts': 12,
#      'threePointsMade': 2,
#      'threePointAttempts': 2,
#      'freeThrowsMade': 0,
#      'freeThrowAttempts': 0,
#      'fieldGoalsMade': 8,
#      'fieldGoalAttempts': 10,
#      'rebounds': 0,
#      'defensiveRebounds': 2,
#      'offensiveRebounds': 0,
#      'turnovers': 0,
#      'blocks': 0,
#      'personalFouls': 0,
#      'assists': 0,
#      'steals': 0,
#      'plusMinus': 4,
#      'fieldGoalPct': 76}}],
#   'supportStaff': [],
#   'playerColor': {'primary': '000000',
#    'number': '222226',
#    'outline': 'fdb927',
#    'fancyNumber': '222226'},
#   'goalkeeperColor': {'primary': '000000',
#    'number': '000000',
#    'outline': 'fafb00',
#    'fancyNumber': '222226'}}}

# %%
(""" # Saisir un ID au hasard ou un match qui est intéressant pour vous
match_id = input("Entrez l'ID du match : ")

# On construit l'URL pour les compositions
url_lineups = f'https://api.sofascore.com/api/v1/event/{match_id}/lineups'

# Fais une requête GET
response = requests.get(url_lineups)


# Récupére les données de ta response sous format JSON
if response.status_code ==200:
  data = response.json()
  joueurTeamHome = data['home']['players']
  joueurTeamAway = data['away']['players']
  print("\n joueurs de l'équipe à domicile")
  for joueur in joueurTeamHome:
    print(f"ID: {joueur['player']['id']}, Nom: {joueur['player']['name']}")
  for joueur in joueurTeamAway:
    print(f"ID: {joueur['player']['id']}, Nom: {joueur['player']['name']}")
else:
  print(f"Erreur: {response.status_code}") """)
# Out:
# Entrez l'ID du match : 12731845
#
#  joueurs de l'équipe à domicile
# ID: 1179862, Nom: AJ Green
# ID: 1178910, Nom: Ryan Rollins
# ID: 1179050, Nom: Andre Jackson Jr.
# ID: 1178570, Nom: Stanley Umude
# ID: 1629480, Nom: Tyler Smith
# ID: 1178333, Nom: Liam Robbins
# ID: 817236, Nom: Brook Lopez
# ID: 817232, Nom: Damian Lillard
# ID: 940761, Nom: Gary Trent Jr.
# ID: 987100, Nom: Jaxson Hayes
# ID: 987931, Nom: Cam Reddish
# ID: 1184925, Nom: Quincy Olivari
# ID: 1600531, Nom: Bronny James
# ID: 1179398, Nom: Colin Castleton
# ID: 1181979, Nom: Dalton Knecht
# ID: 1178651, Nom: Max Christie
# ID: 817181, Nom: LeBron James

# %%
# Sachant que :
              # - data.get('home', {}) : Récupère les données liées à l'équipe à domicile.
              # - .get('players', []) : Récupère la liste des joueurs, ou une liste vide si elle n'existe pas.

# Regarde comment fonctionne la fonction get  dans l'exemple suivant


# Extrais les joueurs de l'équipe à domicile à partir des données récupérées

home_players = data.get('home', {}).get('players', [])

type(home_players)


# Utilise la fonction get pour récupérer les informations qu'on te demande dans la cellule suivante
for player in home_players:
  player_info = player.get('player', {})
  player_name = player_info.get('name', 'N/A')
  player_id = player_info.get('id',"N/A")
  print(f"Nom: {player_name}, ID: {player_id}")
# Out:
# Nom: Bobby Portis, ID: 817329
# Nom: Chris Livingston, ID: 1458354
# Nom: Andre Jackson Jr., ID: 1179050
# Nom: MarJon Beauchamp, ID: 1206073
# Nom: Anzejs Pasecniks, ID: 861688
# Nom: Liam Robbins, ID: 1178333
# Nom: Brook Lopez, ID: 817236
# Nom: Damian Lillard, ID: 817232
# Nom: Gary Trent Jr., ID: 940761

# %%
home_players[0]
# Out:
# {'player': {'name': 'Bobby Portis',
#   'firstName': 'Bobby',
#   'lastName': 'Portis',
#   'slug': 'portis-bobby',
#   'shortName': 'B. Portis',
#   'position': 'F',
#   'jerseyNumber': '9',
#   'height': 208,
#   'userCount': 1854,
#   'id': 817329,
#   'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#   'marketValueCurrency': 'EUR',
#   'dateOfBirthTimestamp': 792374400,
#   'fieldTranslations': {'nameTranslation': {'ar': 'بورتيس، بوبي',
#     'hi': 'पोर्टिस, बॉबी',
#     'bn': 'পোর্টিস, ববি'},
#    'shortNameTranslation': {'ar': 'ب. بورتيس',
#     'hi': 'बी. पोर्टिस',
#     'bn': 'বি. পোর্টিস'}}},
#  'teamId': 3410,
#  'shirtNumber': 9,
#  'jerseyNumber': '9',
#  'position': 'F',
#  'substitute': False,
#  'statistics': {'secondsPlayed': 532,
#   'points': 22,
#   'twoPointsMade': 4,
#   'twoPointAttempts': 4,
#   'threePointsMade': 6,
#   'threePointAttempts': 4,
#   'freeThrowsMade': 2,
#   'freeThrowAttempts': 0,
#   'fieldGoalsMade': 2,
#   'fieldGoalAttempts': 6,
#   'rebounds': 2,
#   'defensiveRebounds': 0,
#   'offensiveRebounds': 0,
#   'turnovers': 0,
#   'blocks': 0,
#   'personalFouls': 0,
#   'assists': 0,
#   'steals': 0,
#   'plusMinus': 20,
#   'fieldGoalPct': 2}}

# %%
# Extrais les joueurs de l'équipe à l'extérieur de manière similaire

away_players = data.get('away', {}).get('players', [])

type(away_players)


# Utilise la fonction get pour récupérer les informations qu'on te demande dans la cellule suivante
for player in away_players:
  player_info = player.get('player', {})
  player_name = player_info.get('name', 'N/A')
  player_id = player_info.get('id',"N/A")
  print(f"Nom: {player_name}, ID: {player_id}")
# revoir part 1
# Out:
# Nom: Tessa Efriana Safitri LAKASENG, ID: 2041483
# Nom: Innocentia HANDANI, ID: 2041481
# Nom: Angelica Natasha Imanuella PIETERSZ, ID: 2041486
# Nom: Jesslyn Angelika LIONARD, ID: 2041488
# Nom: Glady HOKYRUS, ID: 2041476
# Nom: Carmen GUNAWAN, ID: 2041460

# %%
# Afficher les joueurs de l'équipe à domicile
# - Utilisez une boucle pour parcourir la liste des joueurs(away_players).
# - Accédez à chaque joueur pour afficher son ID et son nom.

# Indice : Essaye de faire pour un seul joueur avant de faire ta boucle

print("Joueurs de l'équipe à domicile :")

for player in home_players:
    # f-string pour afficher clairement l'ID et le nom de chaque joueur
    print(f"ID: {player['player']['id']}, Nom: {player['player']['name']}")
# Out:
# Joueurs de l'équipe à domicile :
# ID: 2042061, Nom: Angeliki CHARCHANGELI
# ID: 2042063, Nom: Veronica Kumala RATIH
# ID: 2042064, Nom: Grace Magdalena KARAUWAN
# ID: 2042067, Nom: Nikita URI
# ID: 2042068, Nom: Grachyla MANDAGIE
# ID: 2042071, Nom: Revalina SAPUTERA

# %%
# Afficher les joueurs de l'équipe à l'exterieur
# - Utilisez une boucle pour parcourir la liste des joueurs(home_players).
# - Accédez à chaque joueur pour afficher son ID et son nom.

# Indice : Essaye de faire pour un seul joueur avant de faire ta boucle

print("Joueurs de l'équipe à l'exterieur :")

# Boucle pour afficher les id et le nom de chaque joueur

for player in away_players:
    # f-string pour afficher clairement l'ID et le nom de chaque joueur
    print(f"ID: {player['player']['id']}, Nom: {player['player']['name']}")
# Out:
# Joueurs de l'équipe à l'exterieur :
# ID: 2041483, Nom: Tessa Efriana Safitri LAKASENG
# ID: 2041481, Nom: Innocentia HANDANI
# ID: 2041486, Nom: Angelica Natasha Imanuella PIETERSZ
# ID: 2041488, Nom: Jesslyn Angelika LIONARD
# ID: 2041476, Nom: Glady HOKYRUS
# ID: 2041460, Nom: Carmen GUNAWAN

# %% [markdown]
# ## Étape 3 : Récupérer les statistiques pour un seul joueur

# %%
# Saisir l'ID du joueur sélectionné
player_id = input('Entrez l\'ID du joueur : ')

# Construire l'URL pour les statistiques
url_stats = f'https://api.sofascore.com/api/v1/event/{match_id}/player/{player_id}/statistics'

# Fais une requête GET
response = requests.get(url_stats)

# Récupére les statistiques du joueur pendant le match que t'avait déjà choisi
stats = response.json()

# Récupére les données de ta response sous format JSON
if response.status_code ==200:
  stats = response.json()
  print(stats)
else:
  print(f"Erreur: {response.status_code}")
# Out:
# Entrez l'ID du joueur : 817357
# {'player': {'name': "D'Angelo Russell", 'firstName': "D'Angelo", 'lastName': 'Russell ', 'slug': 'dangelo-russell', 'shortName': 'D. Russell', 'position': 'G', 'jerseyNumber': '1', 'height': 191, 'userCount': 5006, 'id': 817357, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 825033600, 'fieldTranslations': {'nameTranslation': {'ar': 'دانجيلو راسل', 'hi': "डी'एंजेलो रसेल", 'bn': "ডি'অ্যাঞ্জেলো রাসেল"}, 'shortNameTranslation': {'ar': 'د. راسل', 'hi': 'डी. रसेल', 'bn': 'ডি. রাসেল'}}}, 'team': {'name': 'Los Angeles Lakers', 'slug': 'los-angeles-lakers', 'shortName': 'Lakers', 'gender': 'M', 'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2}, 'userCount': 228408, 'nameCode': 'LAL', 'disabled': False, 'national': True, 'type': 0, 'id': 3427, 'entityType': 'team', 'teamColors': {'primary': '#fdb927', 'secondary': '#552582', 'text': '#552582'}, 'fieldTranslations': {'nameTranslation': {'ar': 'لوس أنجلوس ليكرز', 'ru': 'Лос-Анджелес Лейкерс', 'hi': 'लॉस एंजेलिस लेकर्स', 'bn': 'লস এঞ্জেলেস লেকার্স'}, 'shortNameTranslation': {'ar': 'ليكرز', 'hi': 'लेकर्स', 'bn': 'লেকার্স'}}}, 'statistics': {'secondsPlayed': 2770, 'points': 10, 'twoPointsMade': 4, 'twoPointAttempts': 2, 'threePointsMade': 0, 'threePointAttempts': 0, 'freeThrowsMade': 0, 'freeThrowAttempts': 0, 'fieldGoalsMade': 2, 'fieldGoalAttempts': 16, 'rebounds': 0, 'defensiveRebounds': 0, 'offensiveRebounds': 0, 'turnovers': 2, 'blocks': 0, 'personalFouls': 0, 'assists': 10, 'steals': 0, 'plusMinus': 4, 'fieldGoalPct': 14}, 'position': 'G', 'periods': [{'period': '1Q', 'statistics': {'secondsPlayed': 156, 'points': 2, 'twoPointsMade': 0, 'twoPointAttempts': 2, 'threePointsMade': 0, 'threePointAttempts': 0, 'freeThrowsMade': 0, 'freeThrowAttempts': 0, 'fieldGoalsMade': 0, 'fieldGoalAttempts': 0, 'rebounds': 0, 'defensiveRebounds': 0, 'offensiveRebounds': 0, 'turnovers': 2, 'blocks': 0, 'personalFouls': 0, 'assists': 0, 'steals': 0, 'plusMinus': 4, 'fieldGoalPct': 20}}, {'period': '2Q', 'statistics': {'secondsPlayed': 116, 'points': 0, 'twoPointsMade': 0, 'twoPointAttempts': 4, 'threePointsMade': 0, 'threePointAttempts': 0, 'freeThrowsMade': 0, 'freeThrowAttempts': 0, 'fieldGoalsMade': 0, 'fieldGoalAttempts': 6, 'rebounds': 0, 'defensiveRebounds': 0, 'offensiveRebounds': 0, 'turnovers': 0, 'blocks': 0, 'personalFouls': 0, 'assists': 4, 'steals': 0, 'plusMinus': 0, 'fieldGoalPct': 2}}, {'period': '3Q', 'statistics': {'secondsPlayed': 242, 'points': 0, 'twoPointsMade': 0, 'twoPointAttempts': 0, 'threePointsMade': 0, 'threePointAttempts': 0, 'freeThrowsMade': 0, 'freeThrowAttempts': 0, 'fieldGoalsMade': 0, 'fieldGoalAttempts': 2, 'rebounds': 0, 'defensiveRebounds': 0, 'offensiveRebounds': 0, 'turnovers': 0, 'blocks': 0, 'personalFouls': 0, 'assists': 0, 'steals': 0, 'plusMinus': 6, 'fieldGoalPct': 56}}, {'period': '4Q'}]}

# %%
# Utilise json_normalize pour définir ta DataFrame en récupérent les 'statistics'
# On ne veut que charger les données 'statistics' dans le JSON 'stats'
df_stats = pd.json_normalize(stats['statistics'])
print("Statistiques du joueur :")
df_stats
# Out:
# Statistiques du joueur :
#    secondsPlayed  points  twoPointsMade  twoPointAttempts  threePointsMade  \
# 0           1990       0              4                10                0
#
#    threePointAttempts  freeThrowsMade  freeThrowAttempts  fieldGoalsMade  \
# 0                   0               0                  0               4
#
#    fieldGoalAttempts  rebounds  defensiveRebounds  offensiveRebounds  \
# 0                 16         0                  0                  0
#
#    turnovers  blocks  personalFouls  assists  steals  plusMinus  fieldGoalPct
# 0          0       0              0        8       0          8            24

# %%
# Transporse ta dataframe vu qu'elle sur une ligne
df_stats = df_stats.transpose()
df_stats
# Out:
#                        0
# secondsPlayed       1758
# points                 6
# twoPointsMade          0
# twoPointAttempts       2
# threePointsMade        0
# threePointAttempts     0
# freeThrowsMade         0
# freeThrowAttempts      0
# fieldGoalsMade         0
# fieldGoalAttempts      4
# rebounds              20
# defensiveRebounds     12
# offensiveRebounds      0
# turnovers              2
# blocks                 0
# personalFouls          2
# assists                0
# steals                 0
# plusMinus              0
# fieldGoalPct          44

# %% [markdown]
# ## Étape 4 : Visualiser les statistiques du joueur séléctionné pendant le match
# Créez des graphiques pour comparer et analyser les statistiques.

# %%
# Visualisation des statistiques
# Crée un bar plot qui permet de représenter toutes les statistiques présentes dans la df du joueur pendant le match

fig = px.bar(df_stats, x=df_stats.index, y=0, title='Statistiques du joueur', labels={'x': '0', 'y': 'index'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="869ef6d3-b817-4789-96b5-6d393b883caf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("869ef6d3-b817-4789-96b5-6d393b883caf")) {                    Plotly.newPlot(                        "869ef6d3-b817-4789-96b5-6d393b883caf",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}\u003cbr\u003e0=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["secondsPlayed","points","twoPointsMade","twoPointAttempts","threePointsMade","threePointAttempts","freeThrowsMade","freeThrowAttempts","fieldGoalsMade","fieldGoalAttempts","rebounds","defensiveRebounds","offensiveRebounds","turnovers","blocks","personalFouls","assists","steals","plusMinus","fieldGoalPct"],"xaxis":"x","y":[1758,6,0,2,0,0,0,0,0,4,20,12,0,2,0,2,0,0,0,44],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlin ...

# %% [markdown]
# # Partie 2 : Focus sur le match
# Cette partie nous permettra de récupérer, visualiser et comparer les statistiques des joueurs pendant le match que tu as sélectionné au préalable
#
# Rappel :
#
# Tu as déjà stocké les informations des joueurs dans les deux listes `home_players` et `away_players`
#
# Tu sais maintenant comment récupérer les statistiques d'un joueur
#
#
# On aura besoin de faire une boucle pour récupérer l'ID, le nom et les stats de tous les joueurs pendant un match

# %% [markdown]
# ## Étape 1 : Avant de faire ta boucle essaye de récupérer ces informations pour le joueur dont tu as regardé les stats juste avant

# %%
# Récupère l'id et le nom du premier joueur dans la composition home_players

# Regarder le JSON du premier joueur
player = home_players[0]


# Créer des variables pour récupérer ces valeurs pour ce joueur

player_id = player['player']['id']
player_name = player['player']['name']

print(player_id)
print(player_name)
# Out:
# 2042061
# Angeliki CHARCHANGELI

# %%
# Crées une liste players_stats vide

players_stats = []

# Maintenant que tu as récupéré le player_id, récupére les statistics de ce joueur
# Fais une requete GET comme tu as fais en haut pour les statistics
url_stats = f'https://api.sofascore.com/api/v1/event/{match_id}/player/{player_id}/statistics'

response = requests.get(url_stats)
if response.status_code ==200:
  stats = response.json()
  print(stats)
  # Mets tes résultats dans une variables player_stats
  player_stats = stats['statistics']

  # Ajoute la variable player_stats dans ta liste players_stats
  players_stats.append(player_stats)
else:
  print(f"Erreur: {response.status_code}")
# Out:
# {'player': {'name': 'Angeliki CHARCHANGELI', 'firstName': 'Angeliki', 'lastName': 'CHARCHANGELI', 'slug': 'angeliki-charchangeli', 'shortName': 'A. CHARCHANGELI', 'jerseyNumber': '1', 'userCount': 0, 'id': 2042061, 'marketValueCurrency': 'EUR', 'dateOfBirthTimestamp': 1068508800}, 'team': {'name': 'Universitas Kristen Satya Wacana Basketball', 'slug': 'universitas-kristen-satya-wacana-basketball', 'shortName': 'UKSW', 'gender': 'F', 'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2}, 'userCount': 1, 'nameCode': 'UKS', 'disabled': False, 'national': True, 'type': 0, 'id': 1073800, 'entityType': 'team', 'teamColors': {'primary': '#374df5', 'secondary': '#374df5', 'text': '#ffffff'}}, 'statistics': {'secondsPlayed': 846, 'points': 0, 'twoPointsMade': 0, 'twoPointAttempts': 0, 'threePointsMade': 0, 'threePointAttempts': 4, 'freeThrowsMade': 0, 'freeThrowAttempts': 0, 'fieldGoalsMade': 0, 'fieldGoalAttempts': 8, 'rebounds': 0, 'defensiveRebounds': 0, 'offensiveRebounds': 0, 'turnovers': 0, 'blocks': 0, 'personalFouls': 0, 'assists': 0, 'steals': 2, 'plusMinus': 4, 'fieldGoalPct': 10}, 'position': None}

# %%
# Rajoute un élément dictionnaire à la liste 'player_stats' avec la clé 'name' et la valeur qui est le nom de ton joueur 'player_name'

player_stats['name'] = player['player']['name']

# %%
# Rajoute un élément dictionnaire à la liste 'player_stats' avec la clé 'team' et la valeur qui est soit 'Home' soit 'away' selon la présence du joueur dans les listes home_players ou away_players

player_stats['team'] = 'hom' if player in home_players else 'away'

# %%
# On regarde la liste players_stats sous forme de data frame, vérifie que les colonnes (id, name) et les colonnes statistiques sont bien présentes
pd.DataFrame(players_stats)
# Out:
#    secondsPlayed  points  twoPointsMade  twoPointAttempts  threePointsMade  \
# 0            846       0              0                 0                0
#
#    threePointAttempts  freeThrowsMade  freeThrowAttempts  fieldGoalsMade  \
# 0                   4               0                  0               0
#
#    fieldGoalAttempts  ...  offensiveRebounds  turnovers  blocks  \
# 0                  8  ...                  0          0       0
#
#    personalFouls  assists  steals  plusMinus  fieldGoalPct  \
# 0              0        0       2          4            10
#
#                     name  team
# 0  Angeliki CHARCHANGELI   hom
#
# [1 rows x 22 columns]

# %% [markdown]
# ## Étape 2 : Maintenant que tu as fais pour un joueur. On construit notre boucle en se basant sur le même principe

# %%
# Crées ta boucle qui permetteras de récupérer toutes les informations (id, name et statistiques)
# Voici une aide de début

players_stats = []

for player in home_players + away_players:
    player_id = player['player']['id']
    player_name = player['player']['name']

    url_stats = f'https://api.sofascore.com/api/v1/event/{match_id}/player/{player_id}/statistics'

    response = requests.get(url_stats)
    if response.status_code == 200:
      stats = response.json()
      player_stats = stats.get('statistics', [])

      player_stats['name'] = player_name
      player_stats['team'] = 'home' if player in home_players else 'away'
      players_stats.append(player_stats)
    else:
      print(f"Erreur: {response.status_code}")
print(players_stats)
# Out:
# [{'secondsPlayed': 748, 'points': 2, 'twoPointsMade': 0, 'twoPointAttempts': 0, 'threePointsMade': 0, 'threePointAttempts': 6, 'freeThrowsMade': 0, 'freeThrowAttempts': 0, 'fieldGoalsMade': 0, 'fieldGoalAttempts': 6, 'rebounds': 0, 'defensiveRebounds': 0, 'offensiveRebounds': 0, 'turnovers': 0, 'blocks': 0, 'personalFouls': 0, 'assists': 0, 'steals': 0, 'plusMinus': 8, 'fieldGoalPct': 14, 'name': 'Angeliki CHARCHANGELI', 'team': 'home'}, {'secondsPlayed': 1704, 'points': 4, 'twoPointsMade': 2, 'twoPointAttempts': 0, 'threePointsMade': 0, 'threePointAttempts': 0, 'freeThrowsMade': 0, 'freeThrowAttempts': 0, 'fieldGoalsMade': 2, 'fieldGoalAttempts': 6, 'rebounds': 6, 'defensiveRebounds': 4, 'offensiveRebounds': 0, 'turnovers': 0, 'blocks': 0, 'personalFouls': 0, 'assists': 0, 'steals': 2, 'plusMinus': 16, 'fieldGoalPct': 84, 'name': 'Veronica Kumala RATIH', 'team': 'home'}, {'secondsPlayed': 172, 'points': 2, 'twoPointsMade': 2, 'twoPointAttempts': 6, 'threePointsMade': 0, 'threePointAttempts': 4, 'freeThrowsMade': 0, 'freeThrowAttempts': 0, 'fieldGoalsMade': 2, 'fieldGoalAttempts': 4, 'rebounds': 2, 'defensiveRebounds': 2, 'offensiveRebounds': 0, 'turnovers': 0, 'blocks': 0, 'personalFouls': 2, 'assists': 0, 'steals': 0, 'plusMinus': 0, 'fieldGoalPct': 14, 'name': 'Grace Magdalena KARAUWAN', 'team': 'home'}, {'secondsPlayed': 980, 'points': 0, 'twoPointsMade': 0, 'twoPointAttempts': 0, 'threePointsMade': 0, 'threePointAttempts': 0, 'freeThrowsMade': 0, 'freeThrowAttempts': 2, 'fieldGoalsMade': 0, 'fieldGoalAttempts': 0, 'rebounds': 4, 'defensiveRebounds': 2, 'offensiveRebounds': 0, 'turnovers': 0, 'blocks': 0, 'personalFouls': 0, 'assists': 0, 'steals': 0, 'plusMinus': 0, 'fieldGoalPct': 0, 'name': 'Nikita URI', 'team': 'home'}, {'secondsPlayed': 3108, 'points': 8, 'twoPointsMade': 0, 'twoPointAttempts': 2, 'threePointsMade': 0, 'threePointAttempts': 2, 'freeThrowsMade': 0, 'freeThrowAttempts': 0, 'fieldGoalsMade': 0, 'fieldGoalAttempts': 4, 'rebounds': 0, 'defensiveRebounds': 0, 'offensiveRebounds': 0, 'turnovers': 2, 'blocks': 0, 'personalFouls': 4, 'assists': 2, 'steals': 4, 'plusMinus': 0, 'fieldGoalPct': 14, 'name': 'Grachyla MANDAGIE', 'team': 'home'}, {'secondsPlayed': 1522, 'points': 4, 'twoPointsMade': 0, 'twoPointAttempts': 6, 'threePointsMade': 0, 'threePointAttempts': 6, 'freeThrowsMade': 0, 'freeThrowAttempts': 0, 'fieldGoalsMade': 0, 'fieldGoalAttempts': 6, 'rebounds': 2, 'defensiveRebounds': 2, 'offensiveRebounds': 0, 'turnovers': 2, 'blocks': 0, 'personalFouls': 0, 'assists': 0, 'steals': 2, 'plusMinus': 0, 'fieldGoalPct': 32, 'name': 'Revalina SAPUTERA', 'team': 'home'}, {'secondsPlayed': 86, 'points': 6, 'twoPointsMade': 0, 'twoPointAttempts': 0, 'threePointsMade': 0, 'threePointAttempts': 0, 'freeThrowsMade': 0, 'freeThrowAttempts': 4, 'fieldGoalsMade': 0, 'fieldGoalAttempts': 2, 'rebounds': 4, 'defensiveRebounds': 6, 'offensiveRebounds': 0, 'turnovers': 4, 'blocks': 0, 'personalFouls': 0, 'assists': 0, 'steals': 4, 'plusMinus': 2, 'fieldGoalPct': 34, 'name': 'Tessa Efriana Safitri LAKASENG', 'team': 'away'}, {'secondsPlayed': 148, 'points': 0, 'twoPointsMade': 0, 'twoPointAttempts': 0, 'threePointsMade': 0, 'threePointAttempts': 0, 'freeThrowsMade': 0, 'freeThrowAttempts': 0, 'fieldGoalsMade': 0, 'fieldGoalAttempts': 0, 'rebounds': 2, 'defensiveRebounds': 2, 'offensiveRebounds': 0, 'turnovers': 0, 'blocks': 0, 'personalFouls': 0, 'assists': 0, 'steals': 0, 'plusMinus': 0, 'fieldGoalPct': 0, 'name': 'Innocentia HANDANI', 'team': 'away'}, {'secondsPlayed': 0, 'points': 0, 'twoPointsMade': 0, 'twoPointAttempts': 0, 'threePointsMade': 0, 'threePointAttempts': 0, 'freeThrowsMade': 0, 'freeThrowAttempts': 0, 'fieldGoalsMade': 0, 'fieldGoalAttempts': 0, 'rebounds': 0, 'defensiveRebounds': 0, 'offensiveRebounds': 0, 'turnovers': 0, 'blocks': 0, 'personalFouls': 0, 'assists': 0, 'steals': 0, 'plusMinus': 0, 'name': 'Angelica Natasha Imanuella PIETERSZ', 'team': 'away'}, {'secondsPlayed': 838, 'points': 12, 'twoPoints ...

# %%
# avec Valentine on s'arrête içi .
# Étape 2 : Créer un DataFrame pour comparer les joueurs
df_players = pd.DataFrame(players_stats)

# Afficher le tableau des statistiques
df_players
# Out:
#     secondsPlayed  points  twoPointsMade  twoPointAttempts  threePointsMade  \
# 0             748       2              0                 0                0
# 1            1704       4              2                 0                0
# 2             172       2              2                 6                0
# 3             980       0              0                 0                0
# 4            3108       8              0                 2                0
# 5            1522       4              0                 6                0
# 6              86       6              0                 0                0
# 7             148       0              0                 0                0
# 8               0       0              0                 0                0
# 9             838      12              4                 6                0
# 10              0       0              0                 0                0
# 11             34       0              0                 0                0
#
#     threePointAttempts  freeThrowsMade  freeThrowAttempts  fieldGoalsMade  \
# 0                    6               0                  0               0
# 1                    0               0                  0               2
# 2                    4               0                  0               2
# 3                    0               0                  2               0
# 4                    2               0                  0               0
# 5                    6               0                  0               0
# 6                    0               0                  4               0
# 7                    0               0                  0               0
# 8                    0               0                  0               0
# 9                    0               0                  0               0
# 10                   0               0                  0               0
# 11                   0               0                  0               0
#
#     fieldGoalAttempts  ...  offensiveRebounds  turnovers  blocks  \
# 0                   6  ...                  0          0       0
# 1                   6  ...                  0          0       0
# 2                   4  ...                  0          0       0
# 3                   0  ...                  0          0       0
# 4                   4  ...                  0          2       0
# 5                   6  ...                  0          2       0
# 6                   2  ...                  0          4       0
# 7                   0  ...                  0          0       0
# 8                   0  ...                  0          0       0
# 9                   6  ...                  0          0       0
# 10                  0  ...                  0          0       0
# 11                  0  ...                  0          0       0
#
#     personalFouls  assists  steals  plusMinus  fieldGoalPct  \
# 0               0        0       0          8          14.0
# 1               0        0       2         16          84.0
# 2               2        0       0          0          14.0
# 3               0        0       0          0           0.0
# 4               4        2       4          0          14.0
# 5               0        0       2          0          32.0
# 6               0        0       4          2          34.0
# 7               0        0       0          0           0.0
# 8               0        0       0          0           NaN
# 9               2        0       2          0          36.0
# 10              0        0       0          0           NaN
# 11              0        0       0          0           NaN
#
#                                    name  team
# 0                 Angeliki CHARCHANGELI  home
# 1                 Veronica Kumala RATIH  home
# 2              Grace Magdalena KARAUWAN  home
# 3                            Nikita URI  home
# 4                     Grachyla MANDAGIE  home
# 5                     Revalina SAPUTERA  home
# 6        Tessa Efriana Safitri LAKASENG  away
# 7                    Innocentia HANDANI  away
# 8   Angelica Natasha Imanuella PIETERSZ  away
# 9              Jesslyn Angelika LIONARD  away
# 10                        Glady HOKYRUS  away
# 11                       Carmen GUNAWAN  away
#
# [12 rows x 22 columns]

# %% [markdown]
# ## Étape 3 : Créer des graphiques distincts pour les statistiques

# %% [markdown]
# ### Créer un graphe pour comparer les points par joueurs dans les deux équipes

# %%
# Graphique des points par équipe
fig_points = px.bar(
    df_players,
    x='name',
    y='points',
    color='team',
    title='Comparaison des points par joueur',
    labels ={'name': 'Joueur', 'points': 'Points'},
    barmode='group'
)
fig_points.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5cdb4533-81fb-4c19-b286-80b1cd024a1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5cdb4533-81fb-4c19-b286-80b1cd024a1e")) {                    Plotly.newPlot(                        "5cdb4533-81fb-4c19-b286-80b1cd024a1e",                        [{"alignmentgroup":"True","hovertemplate":"team=home\u003cbr\u003eJoueur=%{x}\u003cbr\u003ePoints=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"home","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"home","offsetgroup":"home","orientation":"v","showlegend":true,"textposition":"auto","x":["Angeliki CHARCHANGELI","Veronica Kumala RATIH","Grace Magdalena KARAUWAN","Nikita URI","Grachyla MANDAGIE","Revalina SAPUTERA"],"xaxis":"x","y":[2,4,2,0,8,4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"team=away\u003cbr\u003eJoueur=%{x}\u003cbr\u003ePoints=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"away","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"away","offsetgroup":"away","orientation":"v","showlegend":true,"textposition":"auto","x":["Tessa Efriana Safitri LAKASENG","Innocentia HANDANI","Angelica Natasha Imanuella PIETERSZ","Jesslyn Angelika LIONARD","Glady HOKYRUS","Carmen GUNAWAN"],"xaxis":"x","y":[6,0,0,12,0,0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888 ...

# %% [markdown]
# ### Créer un graphe pour comparer les rebonds par joueurs dans les deux équipes

# %%
# Graphique des rebonds par équipe
fig_rebounds = px.bar(
    df_players,
    x = 'name',
    y = 'rebounds',
    color = 'team',
    title = 'Comparaison des rebonds par joueur',
    labels={'name': 'Joueur', 'rebounds': 'Rebonds'},
    barmode='group'
)
fig_rebounds.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e75885e4-7105-4f09-91ca-44b01fb975c8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e75885e4-7105-4f09-91ca-44b01fb975c8")) {                    Plotly.newPlot(                        "e75885e4-7105-4f09-91ca-44b01fb975c8",                        [{"alignmentgroup":"True","hovertemplate":"team=home\u003cbr\u003eJoueur=%{x}\u003cbr\u003eRebonds=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"home","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"home","offsetgroup":"home","orientation":"v","showlegend":true,"textposition":"auto","x":["Angeliki CHARCHANGELI","Veronica Kumala RATIH","Grace Magdalena KARAUWAN","Nikita URI","Grachyla MANDAGIE","Revalina SAPUTERA"],"xaxis":"x","y":[0,6,2,4,0,2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"team=away\u003cbr\u003eJoueur=%{x}\u003cbr\u003eRebonds=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"away","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"away","offsetgroup":"away","orientation":"v","showlegend":true,"textposition":"auto","x":["Tessa Efriana Safitri LAKASENG","Innocentia HANDANI","Angelica Natasha Imanuella PIETERSZ","Jesslyn Angelika LIONARD","Glady HOKYRUS","Carmen GUNAWAN"],"xaxis":"x","y":[4,2,0,2,0,0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.888888888888888 ...

# %% [markdown]
# ### (Bonus) Créer le même graphe en triant les nombres des rebonds par équipe

# %%
# Trier le DataFrame par la colonne 'rebounds' en ordre décroissant
df_players_sorted = df_players.sort_values(by='rebounds', ascending=False)


# Créer le graphique avec le DataFrame trié
fig_rebounds = px.bar(
    df_players_sorted,
    x='name',
    y='rebounds',
    color='team',
    title='Comparaison des rebonds par joueur (trié)',
    labels={'name': 'Joueur', 'rebounds': 'Rebonds'},
    barmode='group'
)
fig_rebounds.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b3b80d71-624b-47a4-ac11-1b0b56e3b840" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b3b80d71-624b-47a4-ac11-1b0b56e3b840")) {                    Plotly.newPlot(                        "b3b80d71-624b-47a4-ac11-1b0b56e3b840",                        [{"alignmentgroup":"True","hovertemplate":"team=home\u003cbr\u003eJoueur=%{x}\u003cbr\u003eRebonds=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"home","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"home","offsetgroup":"home","orientation":"v","showlegend":true,"textposition":"auto","x":["Veronica Kumala RATIH","Nikita URI","Grace Magdalena KARAUWAN","Revalina SAPUTERA","Angeliki CHARCHANGELI","Grachyla MANDAGIE"],"xaxis":"x","y":[6,4,2,2,0,0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"team=away\u003cbr\u003eJoueur=%{x}\u003cbr\u003eRebonds=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"away","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"away","offsetgroup":"away","orientation":"v","showlegend":true,"textposition":"auto","x":["Tessa Efriana Safitri LAKASENG","Innocentia HANDANI","Jesslyn Angelika LIONARD","Angelica Natasha Imanuella PIETERSZ","Glady HOKYRUS","Carmen GUNAWAN"],"xaxis":"x","y":[4,2,2,0,0,0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.888888888888888 ...

# %% [markdown]
# ### (Bonus) Créer le même graphe en triant les nombres des rebonds globalement

# %%
# Trier le DataFrame par 'rebounds' en ordre décroissant
df_players_sorted2 = df_players.sort_values(by='rebounds', ascending=False)

# Créer un graphique tout en forçant l'ordre global par 'rebounds'
fig_rebounds = px.bar(
    df_players_sorted2,
    x='name',
    y='rebounds',
    color='team',  # Garder la couleur par équipe
    title='Comparaison des rebonds par joueur (tri global avec couleurs)',
    labels={'name': 'Joueur', 'rebounds': 'Rebonds'},
    barmode='group',
    category_orders={'name': df_players_sorted2['name'].tolist()}  # Forcer l'ordre des joueurs
)
fig_rebounds.update_layout(xaxis_title="Joueur") # Change the x-axis label
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3ffa63c3-b11f-4871-8fab-f4cbb9de5c30" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ffa63c3-b11f-4871-8fab-f4cbb9de5c30")) {                    Plotly.newPlot(                        "3ffa63c3-b11f-4871-8fab-f4cbb9de5c30",                        [{"alignmentgroup":"True","hovertemplate":"team=home\u003cbr\u003eJoueur=%{x}\u003cbr\u003eRebonds=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"home","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"home","offsetgroup":"home","orientation":"v","showlegend":true,"textposition":"auto","x":["Veronica Kumala RATIH","Nikita URI","Grace Magdalena KARAUWAN","Revalina SAPUTERA","Angeliki CHARCHANGELI","Grachyla MANDAGIE"],"xaxis":"x","y":[6,4,2,2,0,0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"team=away\u003cbr\u003eJoueur=%{x}\u003cbr\u003eRebonds=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"away","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"away","offsetgroup":"away","orientation":"v","showlegend":true,"textposition":"auto","x":["Tessa Efriana Safitri LAKASENG","Innocentia HANDANI","Jesslyn Angelika LIONARD","Angelica Natasha Imanuella PIETERSZ","Glady HOKYRUS","Carmen GUNAWAN"],"xaxis":"x","y":[4,2,2,0,0,0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.888888888888888 ...

# %% [markdown]
# ### (Bonus) Faire le même graphe pour les points

# %%
# Trier le DataFrame par 'rebounds' en ordre décroissant
df_players_sorted3 = df_players.sort_values(by='points', ascending=False)

# Créer un graphique tout en forçant l'ordre global par 'rebounds'
fig_rebounds = px.bar(
    df_players_sorted3,
    x='name',
    y='points',
    color='team',  # Garder la couleur par équipe
    title='Comparaison des points par joueur (tri global avec couleurs)',
    labels={'name': 'Joueur', 'points': 'Points'},
    barmode='group',
    category_orders={'name': df_players_sorted3['name'].tolist()}  # Forcer l'ordre des joueurs
)
fig_rebounds.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="848f416c-d4cc-4f50-8376-9323d2edd7fd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("848f416c-d4cc-4f50-8376-9323d2edd7fd")) {                    Plotly.newPlot(                        "848f416c-d4cc-4f50-8376-9323d2edd7fd",                        [{"alignmentgroup":"True","hovertemplate":"team=away\u003cbr\u003eJoueur=%{x}\u003cbr\u003ePoints=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"away","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"away","offsetgroup":"away","orientation":"v","showlegend":true,"textposition":"auto","x":["Jesslyn Angelika LIONARD","Tessa Efriana Safitri LAKASENG","Innocentia HANDANI","Angelica Natasha Imanuella PIETERSZ","Glady HOKYRUS","Carmen GUNAWAN"],"xaxis":"x","y":[12,6,0,0,0,0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"team=home\u003cbr\u003eJoueur=%{x}\u003cbr\u003ePoints=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"home","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"home","offsetgroup":"home","orientation":"v","showlegend":true,"textposition":"auto","x":["Grachyla MANDAGIE","Veronica Kumala RATIH","Revalina SAPUTERA","Angeliki CHARCHANGELI","Grace Magdalena KARAUWAN","Nikita URI"],"xaxis":"x","y":[8,4,4,2,2,0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888 ...

# %% [markdown]
# # WCS Pandas Complete tutorial for data analysis 2024 - Student Version
#
# Thanks for Norochalise-medium for providing the dataset ^^
#
# WCS

# %% [markdown]
# ## 1. Setup

# %% [markdown]
# ### Import
#
# Before moving on to learn pandas first we need to install it and import it. If you install [Anaconda distributions](https://www.anaconda.com/) on your local machine or using [Google Colab](https://research.google.com/colaboratory) then pandas will already be available there, otherwise, you follow this installation process from [pandas official's website](https://pandas.pydata.org/docs/getting_started/install.html).

# %%
# Importing libraries
import numpy as np
import pandas as pd

# %%
# we can set numbers for how many rows and columns will be displayed
pd.set_option('display.min_rows', 10) #default will be 10
pd.set_option('display.max_columns', 20)

# %% [markdown]
# ## 2. Loading Different Data Formats Into a Pandas Data Frame

# %% [markdown]
# ### Read CSV file from URL

# %%
# Read csv file from url
url="https://github.com/MaskiVal/Html/raw/main/online_store_customer_data.csv"
df = pd.read_csv( url )
df.head(3)
# Out:
#   Transaction_date  Transaction_ID  Gender   Age Marital_status State_names  \
# 0         1/1/2019          151200  Female  19.0         Single      Kansas
# 1         1/1/2019          151201    Male  49.0         Single    Illinois
# 2         1/1/2019          151202    Male  63.0        Married  New Mexico
#
#   Segment Employees_status Payment_method  Referal  Amount_spent
# 0   Basic     Unemployment          Other      1.0       2051.36
# 1   Basic    self-employed           Card      0.0        544.04
# 2   Basic          workers         PayPal      1.0       1572.60

# %% [markdown]
# ## 3. Data preprocessing
# Data preprocessing is the process of making raw data to clean data. This is the most crucial part of data the science. In this section, we will explore data first then we remove unwanted columns, remove duplicates, handle missing data, etc. After this step, we get clean data from raw data.

# %% [markdown]
# ### 3.1 Data Exploring

# %% [markdown]
# #### Retrieving rows from data frame.

# %%
# display first 3 rows
print(df.head(3)) #affiche les 3 premiere ligne !
# Out:
#   Transaction_date  Transaction_ID  Gender   Age Marital_status State_names  \
# 0         1/1/2019          151200  Female  19.0         Single      Kansas
# 1         1/1/2019          151201    Male  49.0         Single    Illinois
# 2         1/1/2019          151202    Male  63.0        Married  New Mexico
#
#   Segment Employees_status Payment_method  Referal  Amount_spent
# 0   Basic     Unemployment          Other      1.0       2051.36
# 1   Basic    self-employed           Card      0.0        544.04
# 2   Basic          workers         PayPal      1.0       1572.60

# %%
# display last 6 rows
df.tail(6)
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 2506        4/30/2021          153694    Male  34.0         Single
# 2507         5/1/2021          153695  Female  57.0         Single
# 2508         5/1/2021          153696  Female  36.0        Married
# 2509         5/1/2021          153697    Male  22.0         Single
# 2510         5/1/2021          153698     NaN  44.0         Single
# 2511         5/1/2021          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 2506         Florida   Missing        Employees          Other      1.0
# 2507  South Carolina  Platinum    self-employed           Card      0.0
# 2508          Hawaii    Silver    self-employed         PayPal      1.0
# 2509  South Carolina     Basic          workers         PayPal      1.0
# 2510        New York     Basic        Employees         PayPal      0.0
# 2511      California    Silver          workers         PayPal      1.0
#
#       Amount_spent
# 2506        286.82
# 2507        150.10
# 2508        708.88
# 2509       2030.07
# 2510       1909.77
# 2511       1073.15

# %% [markdown]
# #### Retrieving sample rows from data frame.

# %%
# Display random 7 sample rows
df.sample(7)
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 1158        1/12/2020          152346  Female  76.0        Married
# 1871        9/20/2020          153059  Female  78.0         Single
# 2264        2/10/2021          153452    Male  76.0        Married
# 2366        3/15/2021          153554  Female  17.0        Married
# 1396         4/7/2020          152584  Female  16.0         Single
# 1505        5/20/2020          152693  Female  18.0        Married
# 2429         4/5/2021          153617  Female  40.0        Married
#
#        State_names   Segment Employees_status Payment_method  Referal  \
# 1158  Pennsylvania     Basic        Employees         PayPal      0.0
# 1871      Oklahoma     Basic          workers           Card      0.0
# 2264         Texas  Platinum        Employees          Other      1.0
# 2366  Pennsylvania    Silver        Employees         PayPal      0.0
# 1396         Idaho     Basic          workers          Other      0.0
# 1505       Georgia     Basic          workers          Other      1.0
# 2429     Tennessee    Silver     Unemployment         PayPal      1.0
#
#       Amount_spent
# 1158       1501.44
# 1871           NaN
# 2264       2637.00
# 2366        147.48
# 1396       1794.19
# 1505       2926.09
# 2429       1796.43

# %% [markdown]
# #### Retrieving information about dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2512 entries, 0 to 2511
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_date  2512 non-null   object
#  1   Transaction_ID    2512 non-null   int64
#  2   Gender            2484 non-null   object
#  3   Age               2470 non-null   float64
#  4   Marital_status    2512 non-null   object
#  5   State_names       2512 non-null   object
#  6   Segment           2512 non-null   object
#  7   Employees_status  2486 non-null   object
#  8   Payment_method    2512 non-null   object
#  9   Referal           2357 non-null   float64
#  10  Amount_spent      2270 non-null   float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 216.0+ KB

# %%
# display datatypes
print(df.dtypes)
# Out:
# Transaction_date     object
# Transaction_ID        int64
# Gender               object
# Age                 float64
# Marital_status       object
# State_names          object
# Segment              object
# Employees_status     object
# Payment_method       object
# Referal             float64
# Amount_spent        float64
# dtype: object

# %%
print(df.dtypes.value_counts())
# Out:
# object     7
# float64    3
# int64      1
# Name: count, dtype: int64

# %% [markdown]
# #### Display number of rows and columns.

# %%
print("nombre de ligne et columns ", df.shape)

print(f"Number of rows : {df.shape[0]}")
print(f"Number of columns : {df.shape[1]}")
# Out:
# nombre de ligne et columns  (2512, 11)
# Number of rows : 2512
# Number of columns : 11

# %%
print(df.columns)
# Out:
# Index(['Transaction_date', 'Transaction_ID', 'Gender', 'Age', 'Marital_status',
#        'State_names', 'Segment', 'Employees_status', 'Payment_method',
#        'Referal', 'Amount_spent'],
#       dtype='object')

# %%
# display Age columns first 3 rows data
print(df.Age.head(3))
# Out:
# 0    19.0
# 1    49.0
# 2    63.0
# Name: Age, dtype: float64

# %%
# display first 4 rows of Age, Transaction_date and Gender columns
print(df[['Age', 'Transaction_date', 'Gender' ]].head(4))
# Out:
#     Age Transaction_date  Gender
# 0  19.0         1/1/2019  Female
# 1  49.0         1/1/2019    Male
# 2  63.0         1/1/2019    Male
# 3  18.0         1/1/2019     NaN

# %% [markdown]
# ```
# # Ce texte est au format code
# ```
#
# #### Retrieving a Range of Rows

# %%
# for display 2nd to 6th rows
print(df.iloc[1:6])
print("-----------------------------------------------------------------------")
print()
print("-----------------------------------------------------------------------")
# for display starting to 10th
print(df.iloc[10:])
print("-----------------------------------------------------------------------")
print()
print("-----------------------------------------------------------------------")
# for display last two rows
print(df.iloc[-2:])
# Out:
#   Transaction_date  Transaction_ID Gender   Age Marital_status  State_names  \
# 1         1/1/2019          151201   Male  49.0         Single     Illinois
# 2         1/1/2019          151202   Male  63.0        Married   New Mexico
# 3         1/1/2019          151203    NaN  18.0         Single     Virginia
# 4         1/1/2019          151204   Male  27.0         Single  Connecticut
# 5         1/3/2019          151205   Male  71.0         Single       Hawaii
#
#     Segment Employees_status Payment_method  Referal  Amount_spent
# 1     Basic    self-employed           Card      0.0        544.04
# 2     Basic          workers         PayPal      1.0       1572.60
# 3  Platinum          workers           Card      1.0       1199.79
# 4     Basic    self-employed           Card      0.0           NaN
# 5     Basic        Employees         PayPal      1.0       2922.66
# -----------------------------------------------------------------------
#
# -----------------------------------------------------------------------
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 10           1/4/2019          151210  Female  56.0        Married
# 11           1/5/2019          151211  Female  63.0        Married
# 12           1/5/2019          151212  Female  60.0        Married
# 13           1/5/2019          151213    Male  47.0         Single
# 14           1/5/2019          151214    Male  24.0        Married
# ...               ...             ...     ...   ...            ...
# 2507         5/1/2021          153695  Female  57.0         Single
# 2508         5/1/2021          153696  Female  36.0        Married
# 2509         5/1/2021          153697    Male  22.0         Single
# 2510         5/1/2021          153698     NaN  44.0         Single
# 2511         5/1/2021          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 10        California     Basic        Employees         PayPal      0.0
# 11          Colorado     Basic          workers          Other      1.0
# 12              Iowa     Basic    self-employed           Card      1.0
# 13    South Carolina     Basic        Employees         PayPal      1.0
# 14          Colorado  Platinum    self-employed          Other      1.0
# ...              ...       ...              ...            ...      ...
# 2507  South Carolina  Platinum    self-employed           Card      0.0
# 2508          Hawaii    Silver    self-employed         PayPal      1.0
# 2509  South Carolina     Basic          workers         PayPal      1.0
# 2510        New York     Basic        Employees         PayPal      0.0
# 2511      California    Silver          workers         PayPal      1.0
#
#       Amount_spent
# 10         1712.82
# 11          154.31
# 12          819.08
# 13         1719.83
# 14          954.12
# ...            ...
# 2507        150.10
# 2508        708.88
# 2509       2030.07
# 2510       1909.77
# 2511       1073.15
#
# [2502 rows x 11 columns]
# -----------------------------------------------------------------------
#
# -----------------------------------------------------------------------
#      Transaction_date  Transaction_ID Gender   Age Marital_status State_names  \
# 2510         5/1/2021          153698    NaN  44.0         Single    New York
# 2511         5/1/2021          153699   Male  48.0         Single  California
#
#      Segment Employees_status Payment_method  Referal  Amount_spent
# 2510   Basic        Employees         PayPal      0.0       1909.77
# 2511  Silver          workers         PayPal      1.0       1073.15

# %% [markdown]
#  ### 3.2 Data Cleaning
# After the explore our datasets may need to clean them for better analysis. Data coming in from multiple sources so It's possible to have an error in some values. This is where data cleaning becomes extremely important. In this section, we will delete unwanted columns, rename columns, correct appropriate data types, etc.

# %% [markdown]
# #### Delete Columns name

# %%
# Drop unwanted columns 'Transaction_ID'
df.drop("Transaction_ID",axis = 1, inplace = True) # inplace --> modification direct sur le data frame
#                     suppr une colonne , axis  = 0 pour ligne
# Out:
#      Transaction_date  Gender   Age Marital_status     State_names   Segment  \
# 0            1/1/2019  Female  19.0         Single          Kansas     Basic
# 1            1/1/2019    Male  49.0         Single        Illinois     Basic
# 2            1/1/2019    Male  63.0        Married      New Mexico     Basic
# 3            1/1/2019     NaN  18.0         Single        Virginia  Platinum
# 4            1/1/2019    Male  27.0         Single     Connecticut     Basic
# ...               ...     ...   ...            ...             ...       ...
# 2507         5/1/2021  Female  57.0         Single  South Carolina  Platinum
# 2508         5/1/2021  Female  36.0        Married          Hawaii    Silver
# 2509         5/1/2021    Male  22.0         Single  South Carolina     Basic
# 2510         5/1/2021     NaN  44.0         Single        New York     Basic
# 2511         5/1/2021    Male  48.0         Single      California    Silver
#
#      Employees_status Payment_method  Referal  Amount_spent
# 0        Unemployment          Other      1.0       2051.36
# 1       self-employed           Card      0.0        544.04
# 2             workers         PayPal      1.0       1572.60
# 3             workers           Card      1.0       1199.79
# 4       self-employed           Card      0.0           NaN
# ...               ...            ...      ...           ...
# 2507    self-employed           Card      0.0        150.10
# 2508    self-employed         PayPal      1.0        708.88
# 2509          workers         PayPal      1.0       2030.07
# 2510        Employees         PayPal      0.0       1909.77
# 2511          workers         PayPal      1.0       1073.15
#
# [2512 rows x 10 columns]

# %% [markdown]
# #### Change Columns name

# %%
# create new df_col dataframe from df.copy() method.
df_col = df.copy()

# rename columns name
df_col.rename(columns={"Transaction_date": "Date", "Gender": "Sex"}, inplace = True)

df_col.head(3)
# Out:
#        Date     Sex   Age Marital_status State_names Segment Employees_status  \
# 0  1/1/2019  Female  19.0         Single      Kansas   Basic     Unemployment
# 1  1/1/2019    Male  49.0         Single    Illinois   Basic    self-employed
# 2  1/1/2019    Male  63.0        Married  New Mexico   Basic          workers
#
#   Payment_method  Referal  Amount_spent
# 0          Other      1.0       2051.36
# 1           Card      0.0        544.04
# 2         PayPal      1.0       1572.60

# %% [markdown]
# #### Adding a new column to a DataFrame

# %%
# Add a new ajusted column which value will be Amount_spent * 100
df_col["New_col"] = df_col.Amount_spent * 100

# %%
df_col.head(3)
# Out:
#        Date     Sex   Age Marital_status State_names Segment Employees_status  \
# 0  1/1/2019  Female  19.0         Single      Kansas   Basic     Unemployment
# 1  1/1/2019    Male  49.0         Single    Illinois   Basic    self-employed
# 2  1/1/2019    Male  63.0        Married  New Mexico   Basic          workers
#
#   Payment_method  Referal  Amount_spent   New_col
# 0          Other      1.0       2051.36  205136.0
# 1           Card      0.0        544.04   54404.0
# 2         PayPal      1.0       1572.60  157260.0

# %% [markdown]
# #### String value change or replace

# %%
df_col.head(3)
# Out:
#        Date     Sex   Age Marital_status State_names Segment Employees_status  \
# 0  1/1/2019  Female  19.0         Single      Kansas   Basic     Unemployment
# 1  1/1/2019    Male  49.0         Single    Illinois   Basic    self-employed
# 2  1/1/2019    Male  63.0        Married  New Mexico   Basic          workers
#
#   Payment_method  Referal  Amount_spent   New_col
# 0          Other      1.0       2051.36  205136.0
# 1           Card      0.0        544.04   54404.0
# 2         PayPal      1.0       1572.60  157260.0

# %%
# changing Female to Woman and Male to Man in Sex column.
#first argument in loc function is condition and second one is columns name.
df_col.replace("Female","Woman", inplace = True)
df_col.replace("Male","Man", inplace = True)

df_col
# Out:
#           Date    Sex   Age Marital_status     State_names   Segment  \
# 0     1/1/2019  Woman  19.0         Single          Kansas     Basic
# 1     1/1/2019    Man  49.0         Single        Illinois     Basic
# 2     1/1/2019    Man  63.0        Married      New Mexico     Basic
# 3     1/1/2019    NaN  18.0         Single        Virginia  Platinum
# 4     1/1/2019    Man  27.0         Single     Connecticut     Basic
# ...        ...    ...   ...            ...             ...       ...
# 2507  5/1/2021  Woman  57.0         Single  South Carolina  Platinum
# 2508  5/1/2021  Woman  36.0        Married          Hawaii    Silver
# 2509  5/1/2021    Man  22.0         Single  South Carolina     Basic
# 2510  5/1/2021    NaN  44.0         Single        New York     Basic
# 2511  5/1/2021    Man  48.0         Single      California    Silver
#
#      Employees_status Payment_method  Referal  Amount_spent   New_col
# 0        Unemployment          Other      1.0       2051.36  205136.0
# 1       self-employed           Card      0.0        544.04   54404.0
# 2             workers         PayPal      1.0       1572.60  157260.0
# 3             workers           Card      1.0       1199.79  119979.0
# 4       self-employed           Card      0.0           NaN       NaN
# ...               ...            ...      ...           ...       ...
# 2507    self-employed           Card      0.0        150.10   15010.0
# 2508    self-employed         PayPal      1.0        708.88   70888.0
# 2509          workers         PayPal      1.0       2030.07  203007.0
# 2510        Employees         PayPal      0.0       1909.77  190977.0
# 2511          workers         PayPal      1.0       1073.15  107315.0
#
# [2512 rows x 11 columns]

# %%
df_col.head(3)
# Out:
#        Date    Sex   Age Marital_status State_names Segment Employees_status  \
# 0  1/1/2019  Woman  19.0         Single      Kansas   Basic     Unemployment
# 1  1/1/2019    Man  49.0         Single    Illinois   Basic    self-employed
# 2  1/1/2019    Man  63.0        Married  New Mexico   Basic          workers
#
#   Payment_method  Referal  Amount_spent   New_col
# 0          Other      1.0       2051.36  205136.0
# 1           Card      0.0        544.04   54404.0
# 2         PayPal      1.0       1572.60  157260.0

# %% [markdown]
# Now Sex columns values are changed Female to Woman and Male to Man.

# %% [markdown]
# #### Datatypes change

# %%
df_col.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2512 entries, 0 to 2511
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              2512 non-null   object
#  1   Sex               2484 non-null   object
#  2   Age               2470 non-null   float64
#  3   Marital_status    2512 non-null   object
#  4   State_names       2512 non-null   object
#  5   Segment           2512 non-null   object
#  6   Employees_status  2486 non-null   object
#  7   Payment_method    2512 non-null   object
#  8   Referal           2357 non-null   float64
#  9   Amount_spent      2270 non-null   float64
#  10  New_col           2270 non-null   float64
# dtypes: float64(4), object(7)
# memory usage: 216.0+ KB

# %% [markdown]
# In our `Date` columns, it's object type so now we will convert this to date types, and also we will convert `Referal` columns float64 to float32.

# %%
# change object type to datetime64 format
df_col["Date"] = df_col["Date"].astype("datetime64[ns]")

# change float64 to float32 of Referal columns
df_col["Referal"] = df_col["Referal"].astype("float32")

# %%
df_col.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2512 entries, 0 to 2511
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              2512 non-null   datetime64[ns]
#  1   Sex               2484 non-null   object
#  2   Age               2470 non-null   float64
#  3   Marital_status    2512 non-null   object
#  4   State_names       2512 non-null   object
#  5   Segment           2512 non-null   object
#  6   Employees_status  2486 non-null   object
#  7   Payment_method    2512 non-null   object
#  8   Referal           2357 non-null   float32
#  9   Amount_spent      2270 non-null   float64
#  10  New_col           2270 non-null   float64
# dtypes: datetime64[ns](1), float32(1), float64(3), object(6)
# memory usage: 206.2+ KB

# %% [markdown]
# ### 3.3 Remove duplicate

# %%
# Display duplicated entries
df_col.duplicated().value_counts()
# Out:
# False    2500
# True       12
# Name: count, dtype: int64

# %%
# duplicate rows dispaly, keep arguments will--- 'first', 'last' and False
duplicate_value = df_col.duplicated(keep="first")

df_col.loc[duplicate_value, :]
# Out:
#           Date    Sex   Age Marital_status     State_names   Segment  \
# 64  2019-01-25    Man  73.0        Married   West Virginia     Basic
# 65  2019-01-26    Man  55.0        Married          Kansas     Basic
# 66  2019-01-26  Woman  72.0        Married            Iowa    Silver
# 67  2019-01-26    Man  15.0        Married  South Carolina     Basic
# 68  2019-01-27  Woman  63.0         Single           Texas      Gold
# 109 2019-02-06    Man  60.0        Married            Utah    Silver
# 110 2019-02-07  Woman  45.0        Married        Missouri  Platinum
# 111 2019-02-08    Man  33.0         Single         Arizona    Silver
# 112 2019-02-08    Man  24.0        Married  South Carolina     Basic
# 113 2019-02-08  Woman  53.0         Single        Colorado     Basic
# 114 2019-02-08  Woman  70.0        Married   New Hampshire   Missing
# 115 2019-02-08    Man  16.0        Married        Nebraska     Basic
#
#     Employees_status Payment_method  Referal  Amount_spent   New_col
# 64         Employees         PayPal      0.0       1397.09  139709.0
# 65         Employees          Other      1.0       1277.64  127764.0
# 66      Unemployment         PayPal      NaN        515.77   51577.0
# 67     self-employed          Other      1.0        790.10   79010.0
# 68         Employees           Card      1.0       1218.56  121856.0
# 109     Unemployment          Other      1.0        433.20   43320.0
# 110          workers          Other      1.0        929.89   92989.0
# 111          workers         PayPal      0.0       2560.26  256026.0
# 112     Unemployment          Other      0.0           NaN       NaN
# 113    self-employed          Other      1.0       1888.69  188869.0
# 114        Employees           Card      1.0        685.49   68549.0
# 115          workers         PayPal      1.0       1264.73  126473.0

# %%
# dropping ALL duplicate values
# pour ça on fait avec drop_duplicated
df_col.drop_duplicates(keep = "first", inplace = True)

df_col
# Out:
#            Date    Sex   Age Marital_status     State_names   Segment  \
# 0    2019-01-01  Woman  19.0         Single          Kansas     Basic
# 1    2019-01-01    Man  49.0         Single        Illinois     Basic
# 2    2019-01-01    Man  63.0        Married      New Mexico     Basic
# 3    2019-01-01    NaN  18.0         Single        Virginia  Platinum
# 4    2019-01-01    Man  27.0         Single     Connecticut     Basic
# ...         ...    ...   ...            ...             ...       ...
# 2507 2021-05-01  Woman  57.0         Single  South Carolina  Platinum
# 2508 2021-05-01  Woman  36.0        Married          Hawaii    Silver
# 2509 2021-05-01    Man  22.0         Single  South Carolina     Basic
# 2510 2021-05-01    NaN  44.0         Single        New York     Basic
# 2511 2021-05-01    Man  48.0         Single      California    Silver
#
#      Employees_status Payment_method  Referal  Amount_spent   New_col
# 0        Unemployment          Other      1.0       2051.36  205136.0
# 1       self-employed           Card      0.0        544.04   54404.0
# 2             workers         PayPal      1.0       1572.60  157260.0
# 3             workers           Card      1.0       1199.79  119979.0
# 4       self-employed           Card      0.0           NaN       NaN
# ...               ...            ...      ...           ...       ...
# 2507    self-employed           Card      0.0        150.10   15010.0
# 2508    self-employed         PayPal      1.0        708.88   70888.0
# 2509          workers         PayPal      1.0       2030.07  203007.0
# 2510        Employees         PayPal      0.0       1909.77  190977.0
# 2511          workers         PayPal      1.0       1073.15  107315.0
#
# [2500 rows x 11 columns]

# %% [markdown]
# ### 3.4 Handling missing values

# %% [markdown]
# Handling missing values in the common task in the data pre-processing part. For many reasons most of the time we will encounter missing values. Without dealing with this we can't do the proper model building. For this section first, we will find out missing values then we decided how to handle them. We can handle this by removing affected columns or rows or replacing appropriate values there.

# %% [markdown]
# #### Display missing values information

# %%
df_col.isna().sum().sort_values(ascending = False)
# detecte les valeures manquante
#compte les True => VM
#sort_.... =>trie DESC
# Out:
# Amount_spent        241
# New_col             241
# Referal             154
# Age                  42
# Sex                  28
# Employees_status     26
# Date                  0
# Marital_status        0
# State_names           0
# Segment               0
# Payment_method        0
# dtype: int64

# %% [markdown]
# #### Delete Nan rows

# %% [markdown]
# If we have less Nan value then we can delete entire rows by `dropna()` function. For this function, we will add columns name in subset parameter.

# %%
# df copy to df_copy
df_col_copy = df_col.copy()

# %%
#Delete Nan rows of Job Columns
df_col_copy.dropna(subset = ["Employees_status"], axis = 0, inplace = True)
df_col_copy.isna().sum().sort_values(ascending = False)
#comme ça on supprime les valeurs manquantes dans VM dans une colonnes (ici Empoyees sattus)
# Out:
# Amount_spent        240
# New_col             240
# Referal             153
# Age                  42
# Sex                  27
# Date                  0
# Marital_status        0
# State_names           0
# Segment               0
# Employees_status      0
# Payment_method        0
# dtype: int64

# %% [markdown]
# #### Delete entire columns

# %% [markdown]
# If we have a large number of nan values in particular columns then dropping those columns might be a good decision rather than imputing.

# %%
df_col_copy.drop(columns = ["Amount_spent"], inplace = True)
df_col_copy.drop(columns = ["New_col"], inplace = True)

# %%
df_col_copy.isna().sum().sort_values(ascending = False)
# Out:
# Referal             153
# Age                  42
# Sex                  27
# Date                  0
# Marital_status        0
# State_names           0
# Segment               0
# Employees_status      0
# Payment_method        0
# dtype: int64

# %% [markdown]
# #### Impute missing values

# %% [markdown]
# Sometimes if we delete entire columns that will be not the appropriate approach. Delete columns can affect our model building because we will lose our main features. For imputing we have many approaches so here are some of the most popular techniques.

# %% [markdown]
# **Method 1** - Impute fixed value like 0, 'Unknown' or 'Missing' etc. We inpute Unknown in Gender columns

# %%
df_col["Sex"].fillna("Unknow", inplace  =True)
# Out:
# <ipython-input-93-ad3337625ed4>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_col["Sex"].fillna("Unknow", inplace  =True)

# %%
df_col.Sex.value_counts()
# Out:
# Sex
# Woman     1351
# Man       1121
# Unknow      28
# Name: count, dtype: int64

# %% [markdown]
# **Method 2** - Impute Mean, Median and Mode

# %%
# Impute Mean in Amount_spent columns
df_col_mean_Am_S = df_col.Amount_spent.mean()
df_col["Amount_spent"].fillna(df_col_mean_Am_S, inplace = True)

#Impute Median in Age column

df_col_median_age = df_col.Age.median()
df_col["Age"].fillna(df_col_median_age, inplace = True)


# Impute Mode in Employees_status column

df_col_mode_emp_status = df_col.Employees_status.mode()
df_col["Employees_status"].fillna(df_col_mode_emp_status, inplace = True)
# Out:
# <ipython-input-96-64f0e3a991bb>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_col["Amount_spent"].fillna(df_col_mean_Am_S, inplace = True)
# <ipython-input-96-64f0e3a991bb>:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_col["Age"].fillna(df_col_median_age, inplace = True)

# %%
df_col
# Out:
#            Date     Sex   Age Marital_status     State_names   Segment  \
# 0    2019-01-01   Woman  19.0         Single          Kansas     Basic
# 1    2019-01-01     Man  49.0         Single        Illinois     Basic
# 2    2019-01-01     Man  63.0        Married      New Mexico     Basic
# 3    2019-01-01  Unknow  18.0         Single        Virginia  Platinum
# 4    2019-01-01     Man  27.0         Single     Connecticut     Basic
# ...         ...     ...   ...            ...             ...       ...
# 2507 2021-05-01   Woman  57.0         Single  South Carolina  Platinum
# 2508 2021-05-01   Woman  36.0        Married          Hawaii    Silver
# 2509 2021-05-01     Man  22.0         Single  South Carolina     Basic
# 2510 2021-05-01  Unknow  44.0         Single        New York     Basic
# 2511 2021-05-01     Man  48.0         Single      California    Silver
#
#      Employees_status Payment_method  Referal  Amount_spent   New_col
# 0        Unemployment          Other      1.0    2051.36000  205136.0
# 1       self-employed           Card      0.0     544.04000   54404.0
# 2             workers         PayPal      1.0    1572.60000  157260.0
# 3             workers           Card      1.0    1199.79000  119979.0
# 4       self-employed           Card      0.0    1419.59178       NaN
# ...               ...            ...      ...           ...       ...
# 2507    self-employed           Card      0.0     150.10000   15010.0
# 2508    self-employed         PayPal      1.0     708.88000   70888.0
# 2509          workers         PayPal      1.0    2030.07000  203007.0
# 2510        Employees         PayPal      0.0    1909.77000  190977.0
# 2511          workers         PayPal      1.0    1073.15000  107315.0
#
# [2500 rows x 11 columns]

# %% [markdown]
# **Method 3** - Imputing forward fill or backfill by `ffill` and `bfill`. In `ffill` missing value impute from the value of the above row and for `bfill` it's taken from the below rows value.

# %%
df_col.Referal.fillna(method = "ffill", inplace = True)
# Out:
# <ipython-input-98-db504130c3a4>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_col.Referal.fillna(method = "ffill", inplace = True)
# <ipython-input-98-db504130c3a4>:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_col.Referal.fillna(method = "ffill", inplace = True)

# %%
df_col.drop(columns = "New_col", inplace = True)
df_col.isna().sum().sum()
# Out:
# 26

# %% [markdown]
# Now we deal with all missing values with different methods. So now we haven't any null values.

# %% [markdown]
# ## 4. Memory management

# %% [markdown]
# When we work on large datasets, There we get one big issue is a memory problem. We need too large resources for dealing with this. But there are some methods in pandas to deal with this. Here are some methods or strategies to deal with this problem with help of pandas.

# %% [markdown]
# ### Change datatypes

# %%
df_memory = df_col.copy()

# %%
memory_usage = df_memory.memory_usage(deep=True)
memory_usage_in_mbs = round(np.sum(memory_usage / 1024 ** 2), 3)
print(f" Total memory taking df_memory dataframe is : {memory_usage_in_mbs:.2f} MB ")
# Out:
#  Total memory taking df_memory dataframe is : 0.99 MB

# %% [markdown]
# #### Change object to category datatypes

# %% [markdown]
# Our data frame is small in size. Which is 1 MB. Now We will convert our object datatype to category.

# %%
# Object datatype to category convert
df_memory[df_memory.select_dtypes(["object"]).columns]
# Out:
#          Sex Marital_status     State_names   Segment Employees_status  \
# 0      Woman         Single          Kansas     Basic     Unemployment
# 1        Man         Single        Illinois     Basic    self-employed
# 2        Man        Married      New Mexico     Basic          workers
# 3     Unknow         Single        Virginia  Platinum          workers
# 4        Man         Single     Connecticut     Basic    self-employed
# ...      ...            ...             ...       ...              ...
# 2507   Woman         Single  South Carolina  Platinum    self-employed
# 2508   Woman        Married          Hawaii    Silver    self-employed
# 2509     Man         Single  South Carolina     Basic          workers
# 2510  Unknow         Single        New York     Basic        Employees
# 2511     Man         Single      California    Silver          workers
#
#      Payment_method
# 0             Other
# 1              Card
# 2            PayPal
# 3              Card
# 4              Card
# ...             ...
# 2507           Card
# 2508         PayPal
# 2509         PayPal
# 2510         PayPal
# 2511         PayPal
#
# [2500 rows x 6 columns]

# %%
# convert object to category
df_memory.info(memory_usage = "deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2500 entries, 0 to 2511
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              2500 non-null   datetime64[ns]
#  1   Sex               2500 non-null   object
#  2   Age               2500 non-null   float64
#  3   Marital_status    2500 non-null   object
#  4   State_names       2500 non-null   object
#  5   Segment           2500 non-null   object
#  6   Employees_status  2474 non-null   object
#  7   Payment_method    2500 non-null   object
#  8   Referal           2500 non-null   float32
#  9   Amount_spent      2500 non-null   float64
# dtypes: datetime64[ns](1), float32(1), float64(2), object(6)
# memory usage: 1018.5 KB

# %% [markdown]
# Now its reduce 1.15 megabytes to 216.6 kb. It's almost reduced 5.5 times.

# %% [markdown]
# #### Change int64 or float64 to int 32, 16, or 8

# %% [markdown]
# By default, pandas store numeric values to int64 or float64. Which takes more memory. If we have to store small numbers then we can change to 64 to 32, 16, and so on. For example, our Referal columns have only 0 and 1 values so for that we don't need to store at float64. so now we change it to float16.

# %%
# Change Referal column datatypes
df_memory['Age'] = df_memory['Age'].astype('float32')

# %%
# convert object to category
df_memory.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2500 entries, 0 to 2511
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              2500 non-null   datetime64[ns]
#  1   Sex               2500 non-null   object
#  2   Age               2500 non-null   float32
#  3   Marital_status    2500 non-null   object
#  4   State_names       2500 non-null   object
#  5   Segment           2500 non-null   object
#  6   Employees_status  2474 non-null   object
#  7   Payment_method    2500 non-null   object
#  8   Referal           2500 non-null   float32
#  9   Amount_spent      2500 non-null   float64
# dtypes: datetime64[ns](1), float32(2), float64(1), object(6)
# memory usage: 1008.8 KB

# %% [markdown]
# After changing only one column's data types we reduce 216 kb to 179 kb.

# %% [markdown]
# **Note: Before changing datatypes please make sure it's consequences.**

# %% [markdown]
# ## 5. Data Analysis

# %% [markdown]
# ### 5.1. Calculating Basic statistical measurement

# %%
df_col.describe().T
# Out:
#                count                        mean                  min  \
# Date            2500  2020-02-27 02:55:40.800000  2019-01-01 00:00:00
# Age           2500.0                      46.636                 15.0
# Referal       2500.0                      0.6548                  0.0
# Amount_spent  2500.0                  1419.59178                 2.09
#
#                               25%                  50%                  75%  \
# Date          2019-07-26 18:00:00  2020-02-17 12:00:00  2020-09-24 00:00:00
# Age                          32.0                 47.0                 62.0
# Referal                       0.0                  1.0                  1.0
# Amount_spent             734.8625           1419.59178             1957.025
#
#                               max         std
# Date          2021-05-01 00:00:00         NaN
# Age                          78.0   18.020516
# Referal                       1.0     0.47553
# Amount_spent              2999.98  836.011771

# %% [markdown]
# We know already above code will display only numeric columns basic statistical information. for object or category columns we can use `describe(include=object)` .

# %%
df_col.describe(include = object).T
# Out:
#                  count unique        top  freq
# Sex               2500      3      Woman  1351
# Marital_status    2500      2    Married  1464
# State_names       2500     50   Illinois    67
# Segment           2500      5      Basic  1130
# Employees_status  2474      4  Employees   942
# Payment_method    2500      3     PayPal  1164

# %% [markdown]
# We can calculate the mean, median, mode, maximum values, minimum values of individual columns we simply use these functions.

# %%
# Calculate Mean
mean = df_col.Age.mean()

# Calculate Median
median = df_col.Age.median()

#Calculate Mode
mode = df_col.Age.mode()

# Calculate standard deviation
std = df_col.Age.std()

# Calculate Minimum values
min_val = df_col.Age.min()

# Calculate Maximum values
max_cal = df_col.Age.max()

print(f" Mean of Age : {mean}")
print(f" Median of Age : {median}")
print(f" Mode of Age : {mode}")
print(f" Standard deviation of Age : {std:.2f}")
print(f" Maximum of Age : {max_cal}")
print(f" Menimum of Age : {min_val}")
# Out:
#  Mean of Age : 46.636
#  Median of Age : 47.0
#  Mode of Age : 0    47.0
# Name: Age, dtype: float64
#  Standard deviation of Age : 18.02
#  Maximum of Age : 78.0
#  Menimum of Age : 15.0

# %% [markdown]
# In pandas we can display the correlation of different numeric columns. For this we can use `.corr()` function.

# %%
# calculate correlation
df_col.select_dtypes("number").corr()
# Out:
#                    Age   Referal  Amount_spent
# Age           1.000000  0.012042     -0.021030
# Referal       0.012042  1.000000      0.002344
# Amount_spent -0.021030  0.002344      1.000000

# %% [markdown]
# ### 5.2 Basic built in function for data analysis

# %% [markdown]
# #### Number of uniqe values in category column

# %%
# for display how many unique values are there in State_names column
df_col.State_names.nunique()
# Out:
# 50

# %% [markdown]
# #### Shows all unique values

# %%
# for display uniqe values of State_names column
df_col.State_names.unique()
# Out:
# array(['Kansas', 'Illinois', 'New Mexico', 'Virginia', 'Connecticut',
#        'Hawaii', 'Florida', 'Vermont', 'California', 'Colorado', 'Iowa',
#        'South Carolina', 'New York', 'Maine', 'Maryland', 'Missouri',
#        'North Dakota', 'Ohio', 'Nebraska', 'Montana', 'Indiana',
#        'Wisconsin', 'Alabama', 'Arkansas', 'Pennsylvania',
#        'New Hampshire', 'Washington', 'Texas', 'Kentucky',
#        'Massachusetts', 'Wyoming', 'Louisiana', 'North Carolina',
#        'Rhode Island', 'West Virginia', 'Tennessee', 'Oregon', 'Alaska',
#        'Oklahoma', 'Nevada', 'New Jersey', 'Michigan', 'Utah', 'Arizona',
#        'South Dakota', 'Georgia', 'Idaho', 'Mississippi', 'Minnesota',
#        'Delaware'], dtype=object)

# %% [markdown]
# #### Counts of unique values

# %%
df_col.Sex.value_counts()
# Out:
# Sex
# Woman     1351
# Man       1121
# Unknow      28
# Name: count, dtype: int64

# %% [markdown]
# If we want to show with the percentage of occurrence rather number than we use `normalize=True` argument in `value_counts()` function

# %%
# Calculate percentage of each category
df_col.Sex.value_counts(normalize= True) # pourcentage utile pour le projet 2
# Out:
# Sex
# Woman     0.5404
# Man       0.4484
# Unknow    0.0112
# Name: proportion, dtype: float64

# %%
df_col.State_names.value_counts()
# Out:
# State_names
# Illinois          67
# Georgia           64
# Massachusetts     63
# Maine             62
# Kentucky          59
# Minnesota         59
# Delaware          56
# Missouri          56
# New York          55
# Arkansas          55
# Arizona           55
# California        55
# Nevada            55
# New Mexico        55
# Vermont           54
# Oregon            53
# Florida           53
# New Jersey        53
# West Virginia     53
# South Dakota      52
# Washington        52
# Pennsylvania      52
# Michigan          52
# Connecticut       52
# Rhode Island      51
# Colorado          51
# Iowa              50
# Louisiana         49
# Montana           48
# Texas             48
# North Carolina    46
# Virginia          46
# Hawaii            46
# Idaho             45
# Maryland          45
# Wisconsin         45
# Wyoming           44
# Oklahoma          44
# Mississippi       44
# South Carolina    43
# Indiana           43
# Ohio              43
# New Hampshire     42
# Utah              42
# Alabama           42
# Alaska            41
# North Dakota      41
# Nebraska          40
# Kansas            40
# Tennessee         39
# Name: count, dtype: int64

# %%
# Sort Values by State_names
df_col.sort_values(by =["State_names"]).head(10)
# Out:
#            Date    Sex   Age Marital_status State_names   Segment  \
# 1639 2020-07-06  Woman  28.0         Single     Alabama      Gold
# 28   2019-01-12    Man  75.0        Married     Alabama     Basic
# 2001 2020-11-02  Woman  47.0        Married     Alabama      Gold
# 2218 2021-01-24  Woman  29.0        Married     Alabama     Basic
# 1876 2020-09-21  Woman  26.0        Married     Alabama    Silver
# 1369 2020-03-27  Woman  17.0         Single     Alabama  Platinum
# 193  2019-03-11    Man  47.0         Single     Alabama     Basic
# 2443 2021-04-09    Man  60.0        Married     Alabama  Platinum
# 1856 2020-09-15  Woman  18.0        Married     Alabama    Silver
# 2441 2021-04-09    Man  18.0         Single     Alabama  Platinum
#
#      Employees_status Payment_method  Referal  Amount_spent
# 1639        Employees         PayPal      0.0    1706.13000
# 28      self-employed         PayPal      1.0     233.05000
# 2001        Employees          Other      0.0    1954.13000
# 2218          workers           Card      1.0    1728.28000
# 1876          workers           Card      0.0    2520.87000
# 1369          workers          Other      1.0    1578.58000
# 193         Employees         PayPal      1.0    1500.59000
# 2443        Employees         PayPal      1.0    1419.59178
# 1856          workers         PayPal      0.0    2091.73000
# 2441        Employees           Card      0.0     289.85000

# %% [markdown]
# For sorting our dataframe by Amount_spent with ascending order:

# %%
# Sort Values Amount_spent with ascending order
df_col.sort_values(by =["Amount_spent","State_names"], ascending = True)
# Out:
#            Date    Sex   Age Marital_status     State_names   Segment  \
# 2468 2021-04-18  Woman  73.0        Married        Michigan      Gold
# 568  2019-07-04    Man  46.0         Single  South Carolina      Gold
# 2401 2021-03-25  Woman  60.0         Single        Maryland    Silver
# 962  2019-11-13  Woman  56.0        Married          Nevada     Basic
# 860  2019-10-10    Man  26.0         Single        Maryland    Silver
# ...         ...    ...   ...            ...             ...       ...
# 743  2019-08-30    Man  44.0         Single        Illinois     Basic
# 589  2019-07-13    Man  51.0         Single  North Carolina   Missing
# 2279 2021-02-15  Woman  78.0         Single         Arizona    Silver
# 485  2019-06-07    Man  65.0        Married         Arizona      Gold
# 17   2019-01-07  Woman  77.0        Married      New Mexico  Platinum
#
#      Employees_status Payment_method  Referal  Amount_spent
# 2468        Employees         PayPal      1.0          2.09
# 568           workers         PayPal      0.0          2.16
# 2401        Employees         PayPal      1.0          2.84
# 962           workers          Other      1.0          5.31
# 860      Unemployment         PayPal      1.0          5.55
# ...               ...            ...      ...           ...
# 743         Employees           Card      1.0       2996.82
# 589         Employees         PayPal      1.0       2997.15
# 2279        Employees         PayPal      1.0       2997.21
# 485     self-employed         PayPal      1.0       2998.62
# 17            workers           Card      0.0       2999.98
#
# [2500 rows x 10 columns]

# %% [markdown]
# For sorting our dataframe by Amount_spent with descending order:

# %%
# Sort Values Amount_spent with descending order
df_col.sort_values(by =["Amount_spent","State_names"], ascending = False)
# Out:
#            Date    Sex   Age Marital_status     State_names   Segment  \
# 17   2019-01-07  Woman  77.0        Married      New Mexico  Platinum
# 485  2019-06-07    Man  65.0        Married         Arizona      Gold
# 2279 2021-02-15  Woman  78.0         Single         Arizona    Silver
# 589  2019-07-13    Man  51.0         Single  North Carolina   Missing
# 743  2019-08-30    Man  44.0         Single        Illinois     Basic
# ...         ...    ...   ...            ...             ...       ...
# 860  2019-10-10    Man  26.0         Single        Maryland    Silver
# 962  2019-11-13  Woman  56.0        Married          Nevada     Basic
# 2401 2021-03-25  Woman  60.0         Single        Maryland    Silver
# 568  2019-07-04    Man  46.0         Single  South Carolina      Gold
# 2468 2021-04-18  Woman  73.0        Married        Michigan      Gold
#
#      Employees_status Payment_method  Referal  Amount_spent
# 17            workers           Card      0.0       2999.98
# 485     self-employed         PayPal      1.0       2998.62
# 2279        Employees         PayPal      1.0       2997.21
# 589         Employees         PayPal      1.0       2997.15
# 743         Employees           Card      1.0       2996.82
# ...               ...            ...      ...           ...
# 860      Unemployment         PayPal      1.0          5.55
# 962           workers          Other      1.0          5.31
# 2401        Employees         PayPal      1.0          2.84
# 568           workers         PayPal      0.0          2.16
# 2468        Employees         PayPal      1.0          2.09
#
# [2500 rows x 10 columns]

# %% [markdown]
# Alternatively, We can use `nlargest()` and `nsmallest()` functions for displaying largest and smallest values with desired numbers. for example, If we want to display 4 largest Amount_spent rows then we use this:

# %%
# nlargest
df_col.nlargest(4,"Amount_spent")
# first argument is how many rows you want to disply and second one is
#columns name
# Out:
#            Date    Sex   Age Marital_status     State_names   Segment  \
# 17   2019-01-07  Woman  77.0        Married      New Mexico  Platinum
# 485  2019-06-07    Man  65.0        Married         Arizona      Gold
# 2279 2021-02-15  Woman  78.0         Single         Arizona    Silver
# 589  2019-07-13    Man  51.0         Single  North Carolina   Missing
#
#      Employees_status Payment_method  Referal  Amount_spent
# 17            workers           Card      0.0       2999.98
# 485     self-employed         PayPal      1.0       2998.62
# 2279        Employees         PayPal      1.0       2997.21
# 589         Employees         PayPal      1.0       2997.15

# %% [markdown]
# For 3 smallest Amount_spent rows

# %%
# nsmallest
df_col.nsmallest(3, 'Amount_spent')
# Out:
#            Date    Sex   Age Marital_status     State_names Segment  \
# 2468 2021-04-18  Woman  73.0        Married        Michigan    Gold
# 568  2019-07-04    Man  46.0         Single  South Carolina    Gold
# 2401 2021-03-25  Woman  60.0         Single        Maryland  Silver
#
#      Employees_status Payment_method  Referal  Amount_spent
# 2468        Employees         PayPal      1.0          2.09
# 568           workers         PayPal      0.0          2.16
# 2401        Employees         PayPal      1.0          2.84

# %% [markdown]
# #### Conditional queries on Data

# %%
# filtering - Only show Paypal users
condition_paypal = df_col.Payment_method == "PayPal"
df_col[condition_paypal].head(4)
# Out:
#         Date    Sex   Age Marital_status  State_names   Segment  \
# 2 2019-01-01    Man  63.0        Married   New Mexico     Basic
# 5 2019-01-03    Man  71.0         Single       Hawaii     Basic
# 6 2019-01-03  Woman  34.0        Married   New Mexico  Platinum
# 7 2019-01-03    Man  37.0        Married  Connecticut     Basic
#
#   Employees_status Payment_method  Referal  Amount_spent
# 2          workers         PayPal      1.0       1572.60
# 5        Employees         PayPal      1.0       2922.66
# 6        Employees         PayPal      1.0       1481.42
# 7          workers         PayPal      1.0       1149.55

# %% [markdown]
# We can apply multiple conditional queries like before. For example, if we want to display all Married female people who lived in New York then we use the following:

# %%
# first create 3 condition
female_person = df_col.Sex == "Woman"
married_person = df_col.Marital_status == "Married"
loc_newyork = df_col.State_names == "New York"

# we passing condition on our dataframe
df_col[female_person & married_person & loc_newyork]
# Out:
#            Date    Sex   Age Marital_status State_names   Segment  \
# 164  2019-03-01  Woman  64.0        Married    New York     Basic
# 180  2019-03-07  Woman  20.0        Married    New York     Basic
# 254  2019-03-31  Woman  78.0        Married    New York   Missing
# 282  2019-04-08  Woman  32.0        Married    New York      Gold
# 827  2019-09-30  Woman  77.0        Married    New York  Platinum
# 978  2019-11-19  Woman  19.0        Married    New York     Basic
# 1011 2019-11-29  Woman  18.0        Married    New York     Basic
# 1468 2020-05-07  Woman  37.0        Married    New York     Basic
# 1648 2020-07-09  Woman  70.0        Married    New York     Basic
# 1654 2020-07-12  Woman  32.0        Married    New York      Gold
# 1711 2020-08-04  Woman  46.0        Married    New York  Platinum
# 1846 2020-09-12  Woman  57.0        Married    New York     Basic
# 2145 2020-12-27  Woman  31.0        Married    New York    Silver
# 2192 2021-01-13  Woman  77.0        Married    New York     Basic
# 2456 2021-04-14  Woman  30.0        Married    New York     Basic
#
#      Employees_status Payment_method  Referal  Amount_spent
# 164         Employees         PayPal      1.0    1581.77000
# 180           workers         PayPal      1.0    2694.20000
# 254         Employees         PayPal      1.0    2959.54000
# 282      Unemployment          Other      1.0     522.24000
# 827           workers           Card      1.0    1419.59178
# 978         Employees           Card      0.0    2473.87000
# 1011    self-employed         PayPal      1.0    1340.65000
# 1468        Employees           Card      0.0    2003.85000
# 1648    self-employed         PayPal      1.0    1631.46000
# 1654        Employees         PayPal      1.0     270.43000
# 1711        Employees           Card      1.0    1419.59178
# 1846          workers           Card      0.0    1890.94000
# 2145        Employees          Other      1.0     191.21000
# 2192     Unemployment         PayPal      1.0     388.48000
# 2456        Employees          Other      0.0     666.29000

# %% [markdown]
# ### 5.3 Summarizing or grouping data

# %% [markdown]
# #### Groupby

# %% [markdown]
# **Grouping by one column:** For example, if we want to find `maximum` values of `Age` and `Amount_spent` by `Gender` then we can use this:

# %%
df_col[["Age","Amount_spent"]].groupby(df_col["Sex"]).max()
# Out:
#          Age  Amount_spent
# Sex
# Man     78.0       2998.62
# Unknow  72.0       2909.85
# Woman   78.0       2999.98

# %% [markdown]
# To find `mean`, `count`, and `max` values of `Age` and `Amount_spent` by `Gender` then we can use `agg()` function with `groupby()` .

# %%
# Group by one columns
state_gender_res = df[['Age','Gender','Amount_spent']].groupby(['Gender']).agg(['count', 'mean', 'max'])
state_gender_res
# Out:
#          Age                  Amount_spent
#        count       mean   max        count         mean      max
# Gender
# Female  1326  46.864253  78.0         1217  1429.031627  2999.98
# Male    1116  46.475806  78.0         1027  1407.716397  2998.62

# %% [markdown]
# **Grouping by multiple columns:** To find total count, maximum and minimum values of Amount_spent by State_names, Gender, and Payment_method then we can pass these columns names under `groupby()` function and add `.agg()` with `count`, `mean`, `max` argument.

# %%
#Group By multiple columns
state_gender_res = df[['State_names','Gender','Payment_method','Amount_spent']].groupby([ 'State_names','Gender', 'Payment_method']).agg(['count', 'min', 'max'])
state_gender_res.head(12)
# Out:
#                                   Amount_spent
#                                          count      min      max
# State_names Gender Payment_method
# Alabama     Female Card                      6   413.11  2749.37
#                    Other                     5   851.25  2789.52
#                    PayPal                    5    77.90  2520.85
#             Male   Card                      6   221.17  2735.65
#                    Other                     3   459.47  1691.62
#                    PayPal                   10    87.88  2876.36
# Alaska      Female Card                      6   141.50  1988.38
#                    Other                     7   489.16  2970.00
#                    PayPal                    8   462.96  2615.89
#             Male   Card                      1  2497.31  2497.31
#                    Other                     8   588.88  2977.82
#                    PayPal                    8    91.32  1834.95

# %% [markdown]
# #### Cross Tabulation (Crosstab)

# %% [markdown]
# For creating a simple crosstab between Maritatal_status and Payment_method columns we just use `crosstab()` with both column names.

# %%
pd.crosstab(df.Marital_status, df.Payment_method)
# Out:
# Payment_method  Card  Other  PayPal
# Marital_status
# Married          441    362     670
# Single           308    233     498

# %% [markdown]
# We can include subtotals by `margins` parameter:

# %%
pd.crosstab(df.Marital_status, df.Payment_method, margins=True, margins_name="Total")
# Out:
# Payment_method  Card  Other  PayPal  Total
# Marital_status
# Married          441    362     670   1473
# Single           308    233     498   1039
# Total            749    595    1168   2512

# %% [markdown]
# If We want a display with percentage than `normalize=True` parameter help

# %%
pd.crosstab(df.Marital_status, df.Payment_method, normalize=True, margins=True, margins_name="Total")
# Out:
# Payment_method      Card     Other    PayPal     Total
# Marital_status
# Married         0.175557  0.144108  0.266720  0.586385
# Single          0.122611  0.092755  0.198248  0.413615
# Total           0.298169  0.236863  0.464968  1.000000

# %% [markdown]
# In this crosstab features, we can pass multiple columns names for grouping and analyzing data. For instance, If we want to see how the `Payment_method` and `Employees_status` are distributed by `Marital_status` then we will pass these columns' names in `crosstab()` function and it will show below.

# %%
pd.crosstab(df.Marital_status, [df.Payment_method, df.Employees_status])
# Out:
# Payment_method        Card                                        Other  \
# Employees_status Employees Unemployment self-employed workers Employees
# Marital_status
# Married                179           38            81     136       127
# Single                 115           37            57      96        95
#
# Payment_method                                         PayPal               \
# Employees_status Unemployment self-employed workers Employees Unemployment
# Marital_status
# Married                    41            79     114       260           67
# Single                     17            44      76       170           55
#
# Payment_method
# Employees_status self-employed workers
# Marital_status
# Married                    120     217
# Single                     106     159

# %% [markdown]
# ## 6. Data Visualization

# %% [markdown]
# Visualization is the key to data analysis. The most popular python package for visualization are matplotlib and seaborn but sometimes pandas will be handy for you. Pandas also provide some visualization plots easily. For the basic analysis part, it will be easy to use. For this section, we are exploring some different types of plots using pandas. Here are the plots.

# %% [markdown]
# ### 6.1 Line plot

# %% [markdown]
# For creating a line plot in pandas we use `.plot()` with two columns name for the argument. For example, we create a line plot from one dummy dataset.

# %%
dict_line = {
    'year': [2016, 2017, 2018, 2019, 2020, 2021],
    'price': [200, 250, 260, 220, 280, 300]
}
df_line = pd.DataFrame(dict_line)

# %%
# use plot() method on the dataframe
df_line.plot('year', 'price')
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# The above line chart shows prices over a different time. It shows like price trend.

# %% [markdown]
# ### 6.2 Bar plot
#
# A bar plot is also known as a bar chart shows quantitative or qualitative values for different category items. In a bar plot data are represented in the form of bars. Bars length or height are used to represent the quantitative value for each item. Bar plot can be plotted horizontally or vertically. For creating these plots look below.

# %% [markdown]
# **For horizontal bar:**

# %%
df['Employees_status'].value_counts().plot(kind='bar');

# %% [markdown]
# **For vertical bar:**

# %%
df['Employees_status'].value_counts().plot(kind='barh');

# %% [markdown]
# ### 6.3 Pie plot

# %% [markdown]
# A pie plot is also known as a pie chart. A pie plot is a circular graph that represents the total value with its components. The area of a circle represents the total value and the different sectors of the circle represent the different parts. In this plot, the data are expressed as percentages. Each component is expressed as a percentage of the total value.

# %% [markdown]
# In pandas for creating pie plot. We use `kind=pie` in `plot()` function in dataframes columns or series.

# %%
df['Segment'].value_counts().plot(
    kind='pie');

# %% [markdown]
# ### 6.4 Box Plot
# A box plot is also known as a box and whisker plot. This plot is used to show the distribution of a variable based on its quartiles. Box plot displays the five-number summary of a set of data. The five-number summary is the minimum, first quartile, median, third quartile, and maximum. It will also be popular to identify outliers.

# %% [markdown]
# We can plot this by one column or multiple columns. For multiple columns, we need to pass columns name in `y` variable as a list.

# %%
df.plot(y=['Amount_spent'], kind='box');

# %% [markdown]
# In a boxplot, we can plot the distribution of categorical variables against a numerical variable and compare them. Let's plot it with the Employees_status and Amount_spent columns with pandas `boxplot()` method:

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(6,6))

df.boxplot(by ='Employees_status', column =['Amount_spent'],ax=ax, grid = False);

# %% [markdown]
# ### 6.5 Histogram
#
# A histogram shows the frequency and distribution of quantitative measurement across grouped values for data items. It is commonly used in statistics to show how many of a certain type of variable occurs within a specific range or bucket. Below we will plot a histogram for looking Age distribution.

# %%
df.plot(
    y='Age',
    kind='hist',
    bins=10
);

# %% [markdown]
# ### 6.6 KDE plot

# %% [markdown]
# A kernel density estimate (KDE) plot is a method for visualizing the distribution of observations in a dataset, analogous to a histogram. KDE represents the data using a continuous probability density curve in one or more dimensions.

# %%
df.plot(
    y='Age',
    xlim=(0, 100),
    kind='kde'
);

# %% [markdown]
# ### 6.7 Scatterplot
# A scatterplot is used to observe and show relationships between two quantitative variables for different category items. Each member of the dataset gets plotted as a point whose x-y coordinates relate to its values for the two variables. Below we will plot a scatterplot to display relationships between Age and Amount_spent columns.

# %%
df.plot(
    x='Age',
    y='Amount_spent',
    kind='scatter'
);

# %% [markdown]
# ## 7. Reference
#
#
# 1. [Pandas user guide](https://pandas.pydata.org/docs/user_guide/index.html)
# 2. [Pandas 1.x Cookbook](https://www.packtpub.com/product/pandas-1-x-cookbook-second-edition/9781839213106)
# 3. [The Data Wrangling Workshop](https://www.packtpub.com/product/the-data-wrangling-workshop-second-edition/9781839215001)
# 4. [Python for Data Analysis](https://www.oreilly.com/library/view/python-for-data/9781449323592/)
# 5. [Data Analysis with Python: Zero to Pandas - Jovian YouTube Channel](https://www.youtube.com/watch?v=BaV4PRXYNIY&list=PLyMom0n-MBrpzC91Uo560S4VbsiLYtCwo)
# 6. [Best practices with pandas - Data School YouTube Channel](https://www.youtube.com/watch?v=hl-TGI4550M&list=PL5-da3qGB5IBITZj_dYSFqnd_15JgqwA6)
# 7. [Pandas Tutorials - Corey Schafer YouTube Channel](https://www.youtube.com/watch?v=ZyhVh-qRZPA&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS)
# 8. [Pandas Crosstab Explained](https://pbpython.com/pandas-crosstab.html)

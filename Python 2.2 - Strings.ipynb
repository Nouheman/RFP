# %% [markdown]
# # Mission 1

# %% [markdown]
# What's the lenght of the following string ?

# %%
s = "Taumata whakatangihanga koauau o tamatea turi pukaka piki maungah oronuku pokai whenuaki tanatahu "
# len() = taille de.
# len(s) taille de string s.

print(len(s))
# Out:
# 98

# %% [markdown]
# Now, count only non-space characters and display how many there is.
# Remember, using a for loop on a string will browse all the individual characters of it!

# %%
s = "Taumata whakatangihanga koauau o tamatea turi pukaka piki maungah oronuku pokai whenuaki tanatahu "
# une variable compteur
count = 0
# on a besoin d'un for car c'est le plus simple pour itéré
for i in s:
    if i != " ": # tout caractere != " "
      count += 1 # ajout au compteur
print(count)
# Out:
# 85

# %% [markdown]
# ***PARENTHESE ceci est une parti du cours qui ne fait pas partie de l'exo ;) ***

# %%
personnages = [
    {"nom": "Luke Skywalker", "espece": "Humain", "genre": "Homme", "planete": "Tatooine"},
    {"nom": "Leia Organa", "espece": "Humain", "genre": "Femme", "planete": "Alderaan"},
    {"nom": "Han Solo", "espece": "Humain", "genre": "Homme", "planete": "Corellia"},
    {"nom": "Chewbacca", "espece": "Wookie", "genre": "Homme", "planete": "Kashyyyk"},
    {"nom": "Yoda", "espece": "Yoda", "genre": "Homme", "planete": "Inconnue"},
]

import pandas as pd
df = pd.DataFrame(personnages)
hommes_df = df[df['genre'] == 'Homme']




df = pd.DataFrame(personnages)
hommes_df = df[df['genre'] == 'Homme']
#print(hommes_df)

#imad version ==>
hms = []
for p in personnages:
    if p["genre"] == "Homme" :
      hms.append(p["nom"])
print(hms)
print("\n")
hms

#imad version ==>
persoT = []
for es in personnages:
    if es["planete"] == "Tatooine" :
      persoT.append(es["nom"])
print(persoT)



# combien de peros sont de sexe masculin ?

cpt = 0

for perso in personnages:
    if perso["genre"] == "Homme" :
      cpt += 1
print(cpt)

print("\n")
print("suite exo")
print("\n")
# créez un prog qui affiche le nom  et la planète  d'origine de chaque perso de Star wars dont l'espèce est humaine .
# si l'éspèce est autre que "humaine", affichez le nom et lespece du perso .
#Si l'èspéce est " Wookie", ajoputez un message spécial en plus de l'affichage.
popo = []
for perso in personnages:
    if perso["espece"] == "Humain":
      #popo.append(perso["nom"])
      #popo.append(perso["planete"])
      print("NOM : ", perso["nom"], " | Planète : ", perso["planete"])
    elif perso["espece"] != "Humain" and perso["espece"] != "Wookie":
      print("NOM : ", perso["nom"], " | Espèce : ", perso["espece"])
    else:
      print("NOM : ", perso["nom"]," | Faucon Millénium")
# Out:
# ['Luke Skywalker']
# 4
#
#
# suite exo
#
#
# NOM :  Luke Skywalker  | Planète :  Tatooine
# NOM :  Leia Organa  | Planète :  Alderaan
# NOM :  Han Solo  | Planète :  Corellia
# NOM :  Chewbacca  | Faucon Millénium
# NOM :  Yoda  | Espèce :  Yoda

# %% [markdown]
# # Mission 2
#
# Ask the user for a string, then for a character (we assume user input follows the rules). Then, display the positions, **starting with 1**, of all occurrences of the character within the string.
#
# For example, for the word "welcome" and for the character "e", the script will display:
# ```
# position: 2
# position: 7
# ```

# %%
mot = input("Entrez votre chaine de caractère . ")
lettre = input(" donnez votre lettre . ")

#on assure le faite que certain pourrez mettre une majuscule .
mot = mot.lower()
lettre = lettre.lower()

for i in range(0,len(mot)): # pareil que range (len(mon_mot))
    if mot[i] == lettre:
      print("position: ", i+1)
# Out:
# Entrez votre chaine de caractère . vousVOus
#  donnez votre lettre . v
# position:  1
# position:  5

# %% [markdown]
# # Mission 3
#
# Ask the user for a string, then for an integer. Then, display the string repeated as many times as the given integer.
#
# For example, `badger` and `4` will display `badgerbadgerbadgerbadger`

# %%
mot = input("donnez un mot ")
nombre = int(input("donnez un nombre "))

#for i in range(nombre):
#    print(mot)
#donne le mot en colonne

print(mot * nombre)
#donne bien l'affichage qui est demandé.
# Out:
# donnez un mot trois
# donnez un nombre 3
# troistroistrois

# %% [markdown]
# # Mission 4
#
# Display the following string without including the spaces at the beginning and end. There's a `string` method that does exactly that, look at the documentation!

# %%
s = "   Data Analyst  "
#d'après la documentation la fonction qui marche le mieux içi est  :

ss = s.strip()

print(ss)
# Out:
# Data Analyst
#    Data Analyst

# %% [markdown]
# # Mission 5
#
# Ask the user for a string, then for a character, then for another character.
#
# Then, display the string where the occurences of the first character are replaced by the second one.
# For example:
# * string = `"Boulgour"`
# * 1st_char = `"g"`
# * 2nd_char = `"v"`
#
# Result : `"Boulvour"`

# %%
mot = input("donnez un mot:  ")
lettre1 = input("donnez une lettre: ")
lettre2 = input("donnez une 2 ieme lettre: ")

mot= mot.lower()
lettre1 = lettre1.lower()
lettre2 = lettre2.lower() # cette ligne peut être optionel si on fait choisit de laisser le choix à l'utilisateur.


for i in range(len(mot)):
  if mot[i] == lettre1:
    mot= mot.replace(lettre1, lettre2)
print(mot)
# Out:
# donnez un mot:  Nouheman
# donnez une lettre: n
# donnez une 2 ieme lettre: G
# gouhemag

# %% [markdown]
# # Mission 6
#
# Ask the user for a string. Then, display the same string with all vowels converted to uppercase, and all consonants converted to lowercase.
# For example:
# * string = `"Papa's got a brand new bag"`
# Result : `"pApA's gOt A brAnd nEw bAg"`

# %%
mot = input("donnez un mot:  ")

for i in range(len(mot)):
  if mot[i] in "aeiouyAEIOUY":
    mot = mot.replace(mot[i],mot[i].upper())
  elif mot[i] in "bcdfghjklmnpqrstvwxzBCDFGHJKLMNPQRSTVWXZ" :
    mot = mot.replace(mot[i],mot[i].lower())
print(mot)
# Out:
# donnez un mot:  TesTpaR8
# tEstpAr8

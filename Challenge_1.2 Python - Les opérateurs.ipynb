# %% [markdown]
# # 1. Calcul d'un prix

# %% [markdown]
# Ecrivez un programme faisant saisir à l’utilisateur un prix unitaire HT, un taux de TVA et un nombre d’articles, et qui calcule le montant TTC de l’achat.<br>
# Affichez le montant TTC.

# %%
prixHT = float(input("entrez un prix HT "))
taux_TVA = float(input("entrez un taux de TVA "))
nbA = int(input("entrez un nombre d'articles "))
prixTTC = prixHT * (1+taux_TVA/100) * nbA
print(prixTTC)
# Out:
# entrez un prix HT 20
# entrez un taux de TVA 15.6
# entrez un nombre d'articles 3
# 69.35999999999999

# %% [markdown]
# # 2. Conversion de durées (1)

# %% [markdown]
# Ecrivez un programme demandant une durée en secondes à l’utilisateur, et qui la convertit en heures, minutes, secondes.<br>
# Affichez le résultat.<br>
# Par exemple 12334 deviendra 3 heures, 25 minutes et 34 secondes.

# %%
temps = int(input("entrez un temps en secondes "))
heures = temps // 3600
min = temps % 3600 // 60
secondes = temps % 60
print(heures, "heures", min, "minutes", secondes, "secondes")
# Out:
# entrez un temps en secondes 7284
# 2 heures 1 minutes 24 secondes

# %% [markdown]
# # 3. Conversion de durées (2)

# %% [markdown]
# Ecrivez un programme demandant une durée en heures, minutes, secondes à l’utilisateur et qui la convertit en secondes.<br>
# Affichez le résultat.<br>
# Par exemple 3 heures, 25 minutes et 34 secondes deviendra 12334 secondes.

# %%
tempsH = int(input("Entrez dabord les heures "))
tempsM = int(input("Entrez dabord les minutes "))
tempsS = int(input("Entrez dabord les secondes "))

Newtemps = tempsH*3600 + tempsM * 60 + tempsS
print("Le nouveau temps en secondes est  : ", Newtemps)
# Out:
# Entrez dabord les heures 1
# Entrez dabord les minutes 1
# Entrez dabord les secondes 1
# Le nouveau temps en secondes est  :  3661

# %% [markdown]
# # Analyse et comparaison des statistiques des joueurs
# Ce notebook interactif permet de choisir une date, sélectionner un match, et analyser les statistiques des joueurs à travers des visualisations interactives.

# %%
# Importer les bibliothèques
import requests
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Partie 1 : Focus sur ton joueur préféré
# Cette partie nous permettra de séléctionner une date, puis un match, puis un joueur, récupérer et visualiser les statistiques de ce joueur pendant ce match

# %% [markdown]
# ## Étape 1 : Sélectionner une date et récupérer les matchs

# %%
# Saisir une date pour récupérer les données des matchs
# Vous pouvez choisir une date pour trouver un match qui vous anime si vous suivez les matchs de basket
date = input('Entrez une date (YYYY-MM-DD) : ')

# Construire l'URL de l'API
url_events = f'https://api.sofascore.com/api/v1/sport/basketball/scheduled-events/{date}'

# Faire une requête GET
response = requests.get(url_events)

# Vérifier la réponse et récupérer les informations sur les matches
if response.status_code == 200:
    data = response.json()
    matches = data.get('events', [])
else:
    print(f"Erreur: {response.status_code}")

# L'objet qu'on retourne est sous forme JSON, explorez un peu comment il est structuré
matches
# Out:
# Entrez une date (YYYY-MM-DD) : 2024-10-11
# [{'officials': [],
#   'tournament': {'name': 'NBA Preseason',
#    'slug': 'nba-preseason',
#    'category': {'name': 'USA',
#     'slug': 'usa',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'id': 15,
#     'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#     'flag': 'usa',
#     'alpha2': 'US'},
#    'uniqueTournament': {'name': 'NBA Preseason',
#     'slug': 'nba-preseason',
#     'category': {'name': 'USA',
#      'slug': 'usa',
#      'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#      'id': 15,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'flag': 'usa',
#      'alpha2': 'US'},
#     'userCount': 34624,
#     'hasPerformanceGraphFeature': True,
#     'id': 2329,
#     'hasEventPlayerStatistics': True,
#     'hasBoxScore': False,
#     'displayInverseHomeAwayTeams': True},
#    'priority': 131,
#    'id': 9154},
#   'season': {'name': 'NBA Preseason 2024',
#    'year': '2024',
#    'editor': False,
#    'id': 65812},
#   'customId': 'utbsHib',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 2,
#   'homeTeam': {'name': 'Cleveland Cavaliers',
#    'slug': 'cleveland-cavaliers',
#    'shortName': 'Cavaliers',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 47112,
#    'nameCode': 'CLE',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 3432,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'كليڢلاند كاڢالييرس',
#      'ru': 'Кливленд Кавальерс'},
#     'shortNameTranslation': {}}},
#   'awayTeam': {'name': 'Indiana Pacers',
#    'slug': 'indiana-pacers',
#    'shortName': 'Pacers',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 37232,
#    'nameCode': 'IND',
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 3419,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'اينديانا پايسيرس',
#      'ru': 'Индиана Пэйсерс'},
#     'shortNameTranslation': {}}},
#   'homeScore': {'current': 118,
#    'display': 118,
#    'period1': 31,
#    'period2': 39,
#    'period3': 18,
#    'period4': 29,
#    'normaltime': 117},
#   'awayScore': {'current': 129,
#    'display': 129,
#    'period1': 29,
#    'period2': 41,
#    'period3': 32,
#    'period4': 29,
#    'normaltime': 129},
#   'time': {'played': 720,
#    'periodLength': 721,
#    'overtimeLength': 300,
#    'totalPeriodCount': 4,
#    'currentPeriodStartTimestamp': 1728609467},
#   'changes': {'changes': ['time.currentPeriodStart', 'time.played'],
#    'changeTimestamp': 1728609475},
#   'hasGlobalHighlights': True,
#   'hasEventPlayerStatistics': False,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12731839,
#   'periods': {'current': 'Score',
#    'period1': '1st quarter',
#    'period2': '2nd quarter',
#    'period3': '3rd quarter',
#    'period4': '4th quarter',
#    'overtime': 'Overtime'},
#   'startTimestamp': 1728605700,
#   'slug': 'cleveland-cavaliers-indiana-pacers',
#   'finalResultOnly': True,
#   'feedLocked': False,
#   'isEditor': False},
#  {'officials': [],
#   'tournament': {'name': 'NBA Preseason',
#    'slug': 'nba-preseason',
#    'category': {'name': 'USA',
#     'slug': 'usa',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'id': 15,
#     'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#     'flag': 'usa',
#     'alpha2': 'US'},
#    'uniqueTournament': {'name': 'NBA Preseason',
#     'slug': 'nba-preseason',
#     'category': {'name': 'USA',
#      'slug': 'usa',
#      'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#      'id': 15,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'flag': 'usa',
#      'alpha2': 'US'},
#     'userCount': 34624,
#     'hasPerformanceGraphFeature': True,
#     'id': 2329,
#     'hasEventPlayerStatistics': True,
#     'hasBoxScore': True,
#     'displayInverseHomeAwayTeams': False},
#    'priority': 131,
#    'id': 9154},
#   'season': {'name': 'NBA Preseason 2024',
#    'year': '2024',
#    'editor': True,
#    'id': 65812},
#   'customId': 'ltfsJtb',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 2,
#   'homeTeam': {'name': 'Dallas Mavericks',
#    'slug': 'dallas-mavericks',
#    'shortName': 'Mavericks',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 102671,
#    'nameCode': 'DAL',
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 3411,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'دالاس ماڢريكس',
#      'ru': 'Даллас Маверикс'},
#     'shortNameTranslation': {}}},
#   'awayTeam': {'name': 'Utah Jazz',
#    'slug': 'utah-jazz',
#    'shortName': 'Jazz',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 24302,
#    'nameCode': 'UTA',
#    'disabled': True,
#    'national': False,
#    'type': 0,
#    'id': 3434,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'يوتا دجاز',
#      'ru': 'Юта Джаз'},
#     'shortNameTranslation': {}}},
#   'homeScore': {'current': 103,
#    'display': 103,
#    'period1': 19,
#    'period2': 30,
#    'period3': 33,
#    'period4': 23,
#    'normaltime': 103},
#   'awayScore': {'current': 107,
#    'display': 108,
#    'period1': 24,
#    'period2': 37,
#    'period3': 33,
#    'period4': 15,
#    'normaltime': 107},
#   'time': {'played': 720,
#    'periodLength': 721,
#    'overtimeLength': 300,
#    'totalPeriodCount': 4,
#    'currentPeriodStartTimestamp': 1728613502},
#   'changes': {'changes': ['time.played'], 'changeTimestamp': 1728613561},
#   'hasGlobalHighlights': True,
#   'hasEventPlayerStatistics': False,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12731844,
#   'periods': {'current': 'Score',
#    'period1': '1st quarter',
#    'period2': '2nd quarter',
#    'period3': '3rd quarter',
#    'period4': '4th quarter',
#    'overtime': 'Overtime'},
#   'startTimestamp': 1728603000,
#   'slug': 'utah-jazz-dallas-mavericks',
#   'finalResultOnly': True,
#   'feedLocked': False,
#   'isEditor': True},
#  {'officials': [],
#   'tournament': {'name': 'NBA Preseason',
#    'slug': 'nba-preseason',
#    'category': {'name': 'USA',
#     'slug': 'usa',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'id': 15,
#     'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#     'flag': 'usa',
#     'alpha2': 'US'},
#    'uniqueTournament': {'name': 'NBA Preseason',
#     'slug': 'nba-preseason',
#     'category': {'name': 'USA',
#      'slug': 'usa',
#      'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#      'id': 15,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'flag': 'usa',
#      'alpha2': 'US'},
#     'userCount': 34624,
#     'hasPerformanceGraphFeature': False,
#     'id': 2329,
#     'hasEventPlayerStatistics': True,
#     'hasBoxScore': True,
#     'displayInverseHomeAwayTeams': True},
#    'priority': 131,
#    'id': 9154},
#   'season': {'name': 'NBA Preseason 2024',
#    'year': '2024',
#    'editor': False,
#    'id': 65812},
#   'customId': 'btbsFtb',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 2,
#   'homeTeam': {'name': 'Memphis Grizzlies',
#    'slug': 'memphis-grizzlies',
#    'shortName': 'Grizzlies',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 43825,
#    'nameCode': 'MEM',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 3415,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'ميمفيس جريزليس',
#      'ru': 'Мемфис Гриззлис'},
#     'shortNameTranslation': {}}},
#   'awayTeam': {'name': 'Charlotte Hornets',
#    'slug': 'charlotte-hornets',
#    'shortName': 'Hornets',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 26103,
#    'nameCode': 'CHA',
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 3430,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'تشارلوت هورنيتس',
#      'ru': 'Шарлотт Хорнетс'},
#     'shortNameTranslation': {}}},
#   'homeScore': {'current': 94,
#    'display': 94,
#    'period1': 32,
#    'period2': 18,
#    'period3': 22,
#    'period4': 24,
#    'normaltime': 95},
#   'awayScore': {'current': 119,
#    'display': 119,
#    'period1': 36,
#    'period2': 27,
#    'period3': 21,
#    'period4': 38,
#    'normaltime': 120},
#   'time': {'played': 720,
#    'periodLength': 721,
#    'overtimeLength': 300,
#    'totalPeriodCount': 4,
#    'currentPeriodStartTimestamp': 1728613506},
#   'changes': {'changes': ['time.played'], 'changeTimestamp': 1728613562},
#   'hasGlobalHighlights': True,
#   'hasEventPlayerStatistics': True,
#   'crowdsourcingDataDisplayEnabled': True,
#   'id': 12731842,
#   'periods': {'current': 'Score',
#    'period1': '1st quarter',
#    'period2': '2nd quarter',
#    'period3': '3rd quarter',
#    'period4': '4th quarter',
#    'overtime': 'Overtime'},
#   'startTimestamp': 1728611100,
#   'slug': 'charlotte-hornets-memphis-grizzlies',
#   'finalResultOnly': True,
#   'feedLocked': True,
#   'isEditor': False},
#  {'officials': [],
#   'tournament': {'name': 'NBA Preseason',
#    'slug': 'nba-preseason',
#    'category': {'name': 'USA',
#     'slug': 'usa',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'id': 15,
#     'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#     'flag': 'usa',
#     'alpha2': 'US'},
#    'uniqueTournament': {'name': 'NBA Preseason',
#     'slug': 'nba-preseason',
#     'category': {'name': 'USA',
#      'slug': 'usa',
#      'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#      'id': 15,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'flag': 'usa',
#      'alpha2': 'US'},
#     'userCount': 34624,
#     'hasPerformanceGraphFeature': False,
#     'id': 2329,
#     'hasEventPlayerStatistics': True,
#     'hasBoxScore': True,
#     'displayInverseHomeAwayTeams': True},
#    'priority': 131,
#    'id': 9154},
#   'season': {'name': 'NBA Preseason 2024',
#    'year': '2024',
#    'editor': True,
#    'id': 65812},
#   'customId': 'kybsCtb',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 2,
#   'homeTeam': {'name': 'Milwaukee Bucks',
#    'slug': 'milwaukee-bucks',
#    'shortName': 'Bucks',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 93928,
#    'nameCode': 'MIL',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 3410,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'ميلواكي باكس',
#      'ru': 'Милуоки Бакс'},
#     'shortNameTranslation': {}}},
#   'awayTeam': {'name': 'Los Angeles Lakers',
#    'slug': 'los-angeles-lakers',
#    'shortName': 'Lakers',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 211333,
#    'nameCode': 'LAL',
#    'disabled': True,
#    'national': True,
#    'type': 0,
#    'id': 3427,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'لوس انجلس لايكرس',
#      'ru': 'Лос-Анджелес Лейкерс'},
#     'shortNameTranslation': {}}},
#   'homeScore': {'current': 103,
#    'display': 103,
#    'period1': 23,
#    'period2': 36,
#    'period3': 24,
#    'period4': 20,
#    'normaltime': 103},
#   'awayScore': {'current': 107,
#    'display': 107,
#    'period1': 27,
#    'period2': 27,
#    'period3': 23,
#    'period4': 33,
#    'normaltime': 108},
#   'time': {'played': 720,
#    'periodLength': 721,
#    'overtimeLength': 300,
#    'totalPeriodCount': 4,
#    'currentPeriodStartTimestamp': 1728613475},
#   'changes': {'changes': ['time.played'], 'changeTimestamp': 1728613501},
#   'hasGlobalHighlights': True,
#   'hasEventPlayerStatistics': True,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12731845,
#   'periods': {'current': 'Score',
#    'period1': '1st quarter',
#    'period2': '2nd quarter',
#    'period3': '3rd quarter',
#    'period4': '4th quarter',
#    'overtime': 'Overtime'},
#   'startTimestamp': 1728613800,
#   'slug': 'los-angeles-lakers-milwaukee-bucks',
#   'finalResultOnly': True,
#   'feedLocked': True,
#   'isEditor': False},
#  {'officials': [],
#   'tournament': {'name': 'NBA Preseason',
#    'slug': 'nba-preseason',
#    'category': {'name': 'USA',
#     'slug': 'usa',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'id': 15,
#     'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#     'flag': 'usa',
#     'alpha2': 'US'},
#    'uniqueTournament': {'name': 'NBA Preseason',
#     'slug': 'nba-preseason',
#     'category': {'name': 'USA',
#      'slug': 'usa',
#      'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#      'id': 15,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'flag': 'usa',
#      'alpha2': 'US'},
#     'userCount': 34624,
#     'hasPerformanceGraphFeature': True,
#     'id': 2329,
#     'hasEventPlayerStatistics': False,
#     'hasBoxScore': False,
#     'displayInverseHomeAwayTeams': False},
#    'priority': 131,
#    'id': 9154},
#   'season': {'name': 'NBA Preseason 2024',
#    'year': '2024',
#    'editor': False,
#    'id': 65812},
#   'customId': 'tthsPQY',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 1,
#   'homeTeam': {'name': 'Oklahoma City Thunder',
#    'slug': 'oklahoma-city-thunder',
#    'shortName': 'Thunder',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 43043,
#    'nameCode': 'OKC',
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 3418,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'اوكلاهوما سيتي تاندر',
#      'ru': 'Оклахома Сити Тандер'},
#     'shortNameTranslation': {}}},
#   'awayTeam': {'name': 'New Zealand Breakers',
#    'slug': 'new-zealand-breakers',
#    'shortName': 'New Zealand',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 1661,
#    'nameCode': 'NZB',
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 122090,
#    'country': {'alpha2': 'NZ',
#     'alpha3': 'NZL',
#     'name': 'New Zealand',
#     'slug': 'new-zealand'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'نيوزيلاند بريكرس',
#      'ru': 'Нью-Зиланд Брейкерс'},
#     'shortNameTranslation': {}}},
#   'homeScore': {'current': 118,
#    'display': 118,
#    'period1': 35,
#    'period2': 27,
#    'period3': 24,
#    'period4': 33,
#    'normaltime': 118},
#   'awayScore': {'current': 89,
#    'display': 90,
#    'period1': 36,
#    'period2': 24,
#    'period3': 17,
#    'period4': 13,
#    'normaltime': 89},
#   'time': {'played': 720,
#    'periodLength': 720,
#    'overtimeLength': 300,
#    'totalPeriodCount': 4,
#    'currentPeriodStartTimestamp': 1728612590},
#   'changes': {'changes': ['time.played',
#     'time.currentPeriodStart',
#     'status.code',
#     'status.description',
#     'status.type',
#     'homeScore.normaltime',
#     'awayScore.normaltime'],
#    'changeTimestamp': 1728612600},
#   'hasGlobalHighlights': False,
#   'hasEventPlayerStatistics': False,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12731843,
#   'periods': {'current': 'Score',
#    'period1': '1st quarter',
#    'period2': '2nd quarter',
#    'period3': '3rd quarter',
#    'period4': '4th quarter',
#    'overtime': 'Overtime'},
#   'startTimestamp': 1728610200,
#   'slug': 'new-zealand-breakers-oklahoma-city-thunder',
#   'finalResultOnly': False,
#   'feedLocked': False,
#   'isEditor': False},
#  {'officials': [],
#   'tournament': {'name': 'NBA Preseason',
#    'slug': 'nba-preseason',
#    'category': {'name': 'USA',
#     'slug': 'usa',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'id': 15,
#     'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#     'flag': 'usa',
#     'alpha2': 'US'},
#    'uniqueTournament': {'name': 'NBA Preseason',
#     'slug': 'nba-preseason',
#     'category': {'name': 'USA',
#      'slug': 'usa',
#      'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#      'id': 15,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'flag': 'usa',
#      'alpha2': 'US'},
#     'userCount': 34624,
#     'hasPerformanceGraphFeature': False,
#     'id': 2329,
#     'hasEventPlayerStatistics': True,
#     'hasBoxScore': True,
#     'displayInverseHomeAwayTeams': False},
#    'priority': 131,
#    'id': 9154},
#   'season': {'name': 'NBA Preseason 2024',
#    'year': '2024',
#    'editor': True,
#    'id': 65812},
#   'customId': 'vtpsBtb',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 1,
#   'homeTeam': {'name': 'Minnesota Timberwolves',
#    'slug': 'minnesota-timberwolves',
#    'shortName': 'Timberwolves',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 50173,
#    'nameCode': 'MIN',
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 3426,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'مينيسوتا تيمبرولڢس',
#      'ru': 'Миннесота Тимбервулвс'},
#     'shortNameTranslation': {}}},
#   'awayTeam': {'name': 'Philadelphia 76ers',
#    'slug': 'philadelphia-76ers',
#    'shortName': '76ers',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 57498,
#    'nameCode': 'PHI',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 3420,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'فيلاديلفيا  ERS 76',
#      'ru': 'Филадельфия  76ерс'},
#     'shortNameTranslation': {}}},
#   'homeScore': {'current': 122,
#    'display': 121,
#    'period1': 31,
#    'period2': 41,
#    'period3': 25,
#    'period4': 27,
#    'normaltime': 121},
#   'awayScore': {'current': 111,
#    'display': 112,
#    'period1': 23,
#    'period2': 31,
#    'period3': 34,
#    'period4': 24,
#    'normaltime': 112},
#   'time': {'played': 720,
#    'periodLength': 720,
#    'overtimeLength': 300,
#    'totalPeriodCount': 4,
#    'currentPeriodStartTimestamp': 1728696102},
#   'changes': {'changes': ['time.played'], 'changeTimestamp': 1728696158},
#   'hasGlobalHighlights': True,
#   'hasEventPlayerStatistics': True,
#   'crowdsourcingDataDisplayEnabled': True,
#   'id': 12731848,
#   'periods': {'current': 'Score',
#    'period1': '1st quarter',
#    'period2': '2nd quarter',
#    'period3': '3rd quarter',
#    'period4': '4th quarter',
#    'overtime': 'Overtime'},
#   'startTimestamp': 1728682200,
#   'slug': 'minnesota-timberwolves-philadelphia-76ers',
#   'finalResultOnly': True,
#   'feedLocked': False,
#   'isEditor': False},
#  {'officials': [],
#   'tournament': {'name': 'NBA Preseason',
#    'slug': 'nba-preseason',
#    'category': {'name': 'USA',
#     'slug': 'usa',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'id': 15,
#     'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#     'flag': 'usa',
#     'alpha2': 'US'},
#    'uniqueTournament': {'name': 'NBA Preseason',
#     'slug': 'nba-preseason',
#     'category': {'name': 'USA',
#      'slug': 'usa',
#      'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#      'id': 15,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'flag': 'usa',
#      'alpha2': 'US'},
#     'userCount': 34624,
#     'hasPerformanceGraphFeature': False,
#     'id': 2329,
#     'hasEventPlayerStatistics': False,
#     'hasBoxScore': True,
#     'displayInverseHomeAwayTeams': True},
#    'priority': 131,
#    'id': 9154},
#   'season': {'name': 'NBA Preseason 2024',
#    'year': '2024',
#    'editor': False,
#    'id': 65812},
#   'customId': 'MtbpOkc',
#   'status': {'code': 70, 'description': 'Canceled', 'type': 'canceled'},
#   'homeTeam': {'name': 'Orlando Magic',
#    'slug': 'orlando-magic',
#    'shortName': 'Magic',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 27936,
#    'nameCode': 'ORL',
#    'disabled': True,
#    'national': True,
#    'type': 0,
#    'id': 3437,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'اورلاندو ماجيك',
#      'ru': 'Орландо Мэджик'},
#     'shortNameTranslation': {}}},
#   'awayTeam': {'name': 'New Orleans Pelicans',
#    'slug': 'new-orleans-pelicans',
#    'shortName': 'Pelicans',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 26723,
#    'nameCode': 'NOP',
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 5539,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'نيو أورليانز پيليكانس',
#      'ru': 'Нью-Орлеан Пеликанс'},
#     'shortNameTranslation': {}}},
#   'homeScore': {},
#   'awayScore': {},
#   'time': {},
#   'changes': {'changes': ['status.code', 'status.description', 'status.type'],
#    'changeTimestamp': 1728501392},
#   'hasGlobalHighlights': False,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12731846,
#   'periods': {'current': 'Score',
#    'period1': '1st quarter',
#    'period2': '2nd quarter',
#    'period3': '3rd quarter',
#    'period4': '4th quarter',
#    'overtime': 'Overtime'},
#   'startTimestamp': 1728681300,
#   'slug': 'new-orleans-pelicans-orlando-magic',
#   'finalResultOnly': False,
#   'feedLocked': False,
#   'isEditor': True},
#  {'officials': [],
#   'tournament': {'name': 'NBA Preseason',
#    'slug': 'nba-preseason',
#    'category': {'name': 'USA',
#     'slug': 'usa',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'id': 15,
#     'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#     'flag': 'usa',
#     'alpha2': 'US'},
#    'uniqueTournament': {'name': 'NBA Preseason',
#     'slug': 'nba-preseason',
#     'category': {'name': 'USA',
#      'slug': 'usa',
#      'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#      'id': 15,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'flag': 'usa',
#      'alpha2': 'US'},
#     'userCount': 34624,
#     'hasPerformanceGraphFeature': True,
#     'id': 2329,
#     'hasEventPlayerStatistics': False,
#     'hasBoxScore': True,
#     'displayInverseHomeAwayTeams': True},
#    'priority': 131,
#    'id': 9154},
#   'season': {'name': 'NBA Preseason 2024',
#    'year': '2024',
#    'editor': True,
#    'id': 65812},
#   'customId': 'GtbsItg',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 1,
#   'homeTeam': {'name': 'Washington Wizards',
#    'slug': 'washington-wizards',
#    'shortName': 'Wizards',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 20767,
#    'nameCode': 'WAS',
#    'disabled': True,
#    'national': False,
#    'type': 0,
#    'id': 3431,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'واشنطن ويزاردس',
#      'ru': 'Вашингтон Визардз'},
#     'shortNameTranslation': {}}},
#   'awayTeam': {'name': 'Toronto Raptors',
#    'slug': 'toronto-raptors',
#    'shortName': 'Raptors',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 32146,
#    'nameCode': 'TOR',
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 3433,
#    'country': {'alpha2': 'CA',
#     'alpha3': 'CAN',
#     'name': 'Canada',
#     'slug': 'canada'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'تورونتو راپتورس',
#      'ru': 'Торонто Рапторс'},
#     'shortNameTranslation': {}}},
#   'homeScore': {'current': 113,
#    'display': 113,
#    'period1': 18,
#    'period2': 31,
#    'period3': 35,
#    'period4': 32,
#    'normaltime': 114},
#   'awayScore': {'current': 95,
#    'display': 95,
#    'period1': 25,
#    'period2': 22,
#    'period3': 33,
#    'period4': 17,
#    'normaltime': 96},
#   'time': {'played': 720,
#    'periodLength': 721,
#    'overtimeLength': 300,
#    'totalPeriodCount': 4,
#    'currentPeriodStartTimestamp': 1728697003},
#   'changes': {'changes': ['time.played'], 'changeTimestamp': 1728697059},
#   'hasGlobalHighlights': False,
#   'hasEventPlayerStatistics': False,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12731847,
#   'periods': {'current': 'Score',
#    'period1': '1st quarter',
#    'period2': '2nd quarter',
#    'period3': '3rd quarter',
#    'period4': '4th quarter',
#    'overtime': 'Overtime'},
#   'startTimestamp': 1728695700,
#   'slug': 'toronto-raptors-washington-wizards',
#   'finalResultOnly': True,
#   'feedLocked': True,
#   'isEditor': False},
#  {'officials': [],
#   'tournament': {'name': 'NBA Preseason',
#    'slug': 'nba-preseason',
#    'category': {'name': 'USA',
#     'slug': 'usa',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'id': 15,
#     'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#     'flag': 'usa',
#     'alpha2': 'US'},
#    'uniqueTournament': {'name': 'NBA Preseason',
#     'slug': 'nba-preseason',
#     'category': {'name': 'USA',
#      'slug': 'usa',
#      'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#      'id': 15,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'flag': 'usa',
#      'alpha2': 'US'},
#     'userCount': 34624,
#     'hasPerformanceGraphFeature': True,
#     'id': 2329,
#     'hasEventPlayerStatistics': False,
#     'hasBoxScore': False,
#     'displayInverseHomeAwayTeams': True},
#    'priority': 131,
#    'id': 9154},
#   'season': {'name': 'NBA Preseason 2024',
#    'year': '2024',
#    'editor': False,
#    'id': 65812},
#   'customId': 'nrbsDtb',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 1,
#   'homeTeam': {'name': 'Golden State Warriors',
#    'slug': 'golden-state-warriors',
#    'shortName': 'Warriors',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 192529,
#    'nameCode': 'GSW',
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 3428,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'جولدن ستايت وورييرس',
#      'ru': 'Голден Стэйт Уорриорз'},
#     'shortNameTranslation': {}}},
#   'awayTeam': {'name': 'Sacramento Kings',
#    'slug': 'sacramento-kings',
#    'shortName': 'Kings',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 29898,
#    'nameCode': 'SAC',
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 3413,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'ساكرامينتو كينغس',
#      'ru': 'Сакраменто Кингз'},
#     'shortNameTranslation': {}}},
#   'homeScore': {'current': 110,
#    'display': 109,
#    'period1': 35,
#    'period2': 22,
#    'period3': 26,
#    'period4': 29,
#    'normaltime': 110},
#   'awayScore': {'current': 106,
#    'display': 107,
#    'period1': 31,
#    'period2': 28,
#    'period3': 26,
#    'period4': 23,
#    'normaltime': 107},
#   'time': {'played': 720,
#    'periodLength': 720,
#    'overtimeLength': 300,
#    'totalPeriodCount': 4,
#    'currentPeriodStartTimestamp': 1728708038},
#   'changes': {'changes': ['time.played'], 'changeTimestamp': 1728708054},
#   'hasGlobalHighlights': False,
#   'hasEventPlayerStatistics': False,
#   'crowdsourcingDataDisplayEnabled': True,
#   'id': 12731852,
#   'periods': {'current': 'Score',
#    'period1': '1st quarter',
#    'period2': '2nd quarter',
#    'period3': '3rd quarter',
#    'period4': '4th quarter',
#    'overtime': 'Overtime'},
#   'startTimestamp': 1728696600,
#   'slug': 'golden-state-warriors-sacramento-kings',
#   'finalResultOnly': True,
#   'feedLocked': True,
#   'isEditor': False},
#  {'officials': [],
#   'tournament': {'name': 'NBA Preseason',
#    'slug': 'nba-preseason',
#    'category': {'name': 'USA',
#     'slug': 'usa',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'id': 15,
#     'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#     'flag': 'usa',
#     'alpha2': 'US'},
#    'uniqueTournament': {'name': 'NBA Preseason',
#     'slug': 'nba-preseason',
#     'category': {'name': 'USA',
#      'slug': 'usa',
#      'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#      'id': 15,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'flag': 'usa',
#      'alpha2': 'US'},
#     'userCount': 34624,
#     'hasPerformanceGraphFeature': True,
#     'id': 2329,
#     'hasEventPlayerStatistics': False,
#     'hasBoxScore': False,
#     'displayInverseHomeAwayTeams': False},
#    'priority': 131,
#    'id': 9154},
#   'season': {'name': 'NBA Preseason 2024',
#    'year': '2024',
#    'editor': False,
#    'id': 65812},
#   'customId': 'utbsztb',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 2,
#   'homeTeam': {'name': 'Phoenix Suns',
#    'slug': 'phoenix-suns',
#    'shortName': 'Suns',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 56078,
#    'nameCode': 'PHX',
#    'disabled': True,
#    'national': False,
#    'type': 0,
#    'id': 3416,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'فونيكس سانز',
#      'ru': 'Финикс Санс'},
#     'shortNameTranslation': {}}},
#   'awayTeam': {'name': 'Detroit Pistons',
#    'slug': 'detroit-pistons',
#    'shortName': 'Pistons',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 21933,
#    'nameCode': 'DET',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 3424,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'ديترويت پيستونس',
#      'ru': 'Детройт Пистонс'},
#     'shortNameTranslation': {}}},
#   'homeScore': {'current': 91,
#    'display': 92,
#    'period1': 30,
#    'period2': 22,
#    'period3': 24,
#    'period4': 17,
#    'normaltime': 92},
#   'awayScore': {'current': 109,
#    'display': 109,
#    'period1': 41,
#    'period2': 26,
#    'period3': 24,
#    'period4': 21,
#    'normaltime': 110},
#   'time': {'played': 720,
#    'periodLength': 721,
#    'overtimeLength': 300,
#    'totalPeriodCount': 4,
#    'currentPeriodStartTimestamp': 1728706496},
#   'changes': {'changes': ['time.played'], 'changeTimestamp': 1728706553},
#   'hasGlobalHighlights': True,
#   'hasEventPlayerStatistics': False,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12731849,
#   'periods': {'current': 'Score',
#    'period1': '1st quarter',
#    'period2': '2nd quarter',
#    'period3': '3rd quarter',
#    'period4': '4th quarter',
#    'overtime': 'Overtime'},
#   'startTimestamp': 1728693000,
#   'slug': 'detroit-pistons-phoenix-suns',
#   'finalResultOnly': True,
#   'feedLocked': True,
#   'isEditor': True},
#  {'officials': [],
#   'tournament': {'name': 'NBA Preseason',
#    'slug': 'nba-preseason',
#    'category': {'name': 'USA',
#     'slug': 'usa',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'id': 15,
#     'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#     'flag': 'usa',
#     'alpha2': 'US'},
#    'uniqueTournament': {'name': 'NBA Preseason',
#     'slug': 'nba-preseason',
#     'category': {'name': 'USA',
#      'slug': 'usa',
#      'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#      'id': 15,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'flag': 'usa',
#      'alpha2': 'US'},
#     'userCount': 34624,
#     'hasPerformanceGraphFeature': True,
#     'id': 2329,
#     'hasEventPlayerStatistics': False,
#     'hasBoxScore': True,
#     'displayInverseHomeAwayTeams': False},
#    'priority': 131,
#    'id': 9154},
#   'season': {'name': 'NBA Preseason 2024',
#    'year': '2024',
#    'editor': True,
#    'id': 65812},
#   'customId': 'otbsLtb',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 1,
#   'homeTeam': {'name': 'Los Angeles Clippers',
#    'slug': 'los-angeles-clippers',
#    'shortName': 'Clippers',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 53283,
#    'nameCode': 'LAC',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 3425,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ru': 'ЛА Клипперс'},
#     'shortNameTranslation': {}}},
#   'awayTeam': {'name': 'Portland Trail Blazers',
#    'slug': 'portland-trail-blazers',
#    'shortName': 'Trail Blazers',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 22049,
#    'nameCode': 'POR',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 3414,
#    'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'پورتلاند ترايل بلايزرس',
#      'ru': 'Портленд Трэйл Блэйзерс'},
#     'shortNameTranslation': {}}},
#   'homeScore': {'current': 101,
#    'display': 102,
#    'period1': 23,
#    'period2': 27,
#    'period3': 28,
#    'period4': 26,
#    'normaltime': 102},
#   'awayScore': {'current': 99,
#    'display': 100,
#    'period1': 25,
#    'period2': 26,
#    'period3': 28,
#    'period4': 22,
#    'normaltime': 99},
#   'time': {'played': 720,
#    'periodLength': 721,
#    'overtimeLength': 300,
#    'totalPeriodCount': 4,
#    'currentPeriodStartTimestamp': 1728709372},
#   'changes': {'changes': ['time.currentPeriodStart',
#     'status.code',
#     'status.description',
#     'status.type',
#     'homeScore.normaltime',
#     'awayScore.normaltime'],
#    'changeTimestamp': 1728709379},
#   'hasGlobalHighlights': False,
#   'hasEventPlayerStatistics': False,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12731851,
#   'periods': {'current': 'Score',
#    'period1': '1st quarter',
#    'period2': '2nd quarter',
#    'period3': '3rd quarter',
#    'period4': '4th quarter',
#    'overtime': 'Overtime'},
#   'startTimestamp': 1728703800,
#   'slug': 'los-angeles-clippers-portland-trail-blazers',
#   'finalResultOnly': True,
#   'feedLocked': True,
#   'isEditor': False},
#  {'officials': [],
#   'tournament': {'name': 'Euroleague',
#    'slug': 'euroleague',
#    'category': {'name': 'International',
#     'slug': 'international',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'id': 103,
#     'country': {},
#     'flag': 'international'},
#    'uniqueTournament': {'name': 'Euroleague',
#     'slug': 'euroleague',
#     'category': {'name': 'International',
#      'slug': 'international',
#      'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#      'id': 103,
#      'country': {},
#      'flag': 'international'},
#     'userCount': 63470,
#     'hasPerformanceGraphFeature': False,
#     'id': 138,
#     'hasEventPlayerStatistics': False,
#     'hasBoxScore': False,
#     'displayInverseHomeAwayTeams': False},
#    'priority': 130,
#    'id': 42527},
#   'season': {'name': 'Euroleague 24/25',
#    'year': '24/25',
#    'editor': False,
#    'id': 63971},
#   'roundInfo': {'round': 2},
#   'customId': 'ovpspvb',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 2,
#   'homeTeam': {'name': 'Anadolu Efes',
#    'slug': 'anadolu-efes',
#    'shortName': 'Anadolu Efes',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 12522,
#    'nameCode': 'EFS',
#    'disabled': True,
#    'national': True,
#    'type': 0,
#    'id': 3515,
#    'country': {'alpha2': 'TR',
#     'alpha3': 'TUR',
#     'name': 'Türkiye',
#     'slug': 'turkiye'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ru': 'Анадолу Эфес'},
#     'shortNameTranslation': {}}},
#   'awayTeam': {'name': 'Fenerbahçe Beko',
#    'slug': 'fenerbahce-beko',
#    'shortName': 'Fenerbahçe',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 32431,
#    'nameCode': 'FBB',
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 3514,
#    'country': {'alpha2': 'TR',
#     'alpha3': 'TUR',
#     'name': 'Türkiye',
#     'slug': 'turkiye'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ru': 'Фенербахче'},
#     'shortNameTranslation': {}}},
#   'homeScore': {'current': 79,
#    'display': 78,
#    'period1': 22,
#    'period2': 17,
#    'period3': 15,
#    'period4': 28,
#    'normaltime': 78},
#   'awayScore': {'current': 84,
#    'display': 84,
#    'period1': 28,
#    'period2': 19,
#    'period3': 15,
#    'period4': 24,
#    'normaltime': 83},
#   'time': {'played': 2400,
#    'periodLength': 601,
#    'overtimeLength': 300,
#    'totalPeriodCount': 4,
#    'currentPeriodStartTimestamp': 1728588834},
#   'changes': {'changes': ['status.code',
#     'status.description',
#     'status.type',
#     'homeScore.normaltime',
#     'awayScore.normaltime',
#     'time.currentPeriodStart'],
#    'changeTimestamp': 1728588843},
#   'hasGlobalHighlights': False,
#   'hasEventPlayerStatistics': True,
#   'crowdsourcingDataDisplayEnabled': True,
#   'id': 12544777,
#   'periods': {'current': 'Score',
#    'period1': '1st quarter',
#    'period2': '2nd quarter',
#    'period3': '3rd quarter',
#    'period4': '4th quarter',
#    'overtime': 'Overtime'},
#   'startTimestamp': 1728575100,
#   'slug': 'anadolu-efes-fenerbahce-beko',
#   'finalResultOnly': True,
#   'feedLocked': False,
#   'isEditor': False},
#  {'officials': [],
#   'tournament': {'name': 'Euroleague',
#    'slug': 'euroleague',
#    'category': {'name': 'International',
#     'slug': 'international',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'id': 103,
#     'country': {},
#     'flag': 'international'},
#    'uniqueTournament': {'name': 'Euroleague',
#     'slug': 'euroleague',
#     'category': {'name': 'International',
#      'slug': 'international',
#      'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#      'id': 103,
#      'country': {},
#      'flag': 'international'},
#     'userCount': 63470,
#     'hasPerformanceGraphFeature': True,
#     'id': 138,
#     'hasEventPlayerStatistics': True,
#     'hasBoxScore': True,
#     'displayInverseHomeAwayTeams': False},
#    'priority': 130,
#    'id': 42527},
#   'season': {'name': 'Euroleague 24/25',
#    'year': '24/25',
#    'editor': True,
#    'id': 63971},
#   'roundInfo': {'round': 2},
#   'customId': 'Lvfswmc',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 1,
#   'homeTeam': {'name': 'LDLC ASVEL Lyon-Villeurbanne',
#    'slug': 'ldlc-asvel-lyon-villeurbanne',
#    'shortName': 'ASVEL',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 7024,
#    'nameCode': 'ASV',
#    'disabled': True,
#    'national': True,
#    'type': 0,
#    'id': 3536,
#    'country': {'alpha2': 'FR',
#     'alpha3': 'FRA',
#     'name': 'France',
#     'slug': 'france'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ru': 'Асвел Вильербанн'},
#     'shortNameTranslation': {}}},
#   'awayTeam': {'name': 'Virtus Segafredo Bologna',
#    'slug': 'virtus-segafredo-bologna',
#    'shortName': 'V. Bologna',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 12813,
#    'nameCode': 'VIB',
#    'disabled': True,
#    'national': True,
#    'type': 0,
#    'id': 5621,
#    'country': {'alpha2': 'IT',
#     'alpha3': 'ITA',
#     'name': 'Italy',
#     'slug': 'italy'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ru': 'Виртус Болонья'},
#     'shortNameTranslation': {}}},
#   'homeScore': {'current': 88,
#    'display': 87,
#    'period1': 39,
#    'period2': 19,
#    'period3': 17,
#    'period4': 15,
#    'normaltime': 87},
#   'awayScore': {'current': 86,
#    'display': 85,
#    'period1': 28,
#    'period2': 23,
#    'period3': 21,
#    'period4': 16,
#    'normaltime': 86},
#   'time': {'played': 2400,
#    'periodLength': 600,
#    'overtimeLength': 300,
#    'totalPeriodCount': 4,
#    'currentPeriodStartTimestamp': 1728590558},
#   'changes': {'changes': ['time.currentPeriodStart',
#     'status.code',
#     'status.description',
#     'status.type',
#     'homeScore.normaltime',
#     'awayScore.normaltime',
#     'time.played'],
#    'changeTimestamp': 1728590563},
#   'hasGlobalHighlights': False,
#   'hasEventPlayerStatistics': True,
#   'crowdsourcingDataDisplayEnabled': True,
#   'id': 12544773,
#   'periods': {'current': 'Score',
#    'period1': '1st quarter',
#    'period2': '2nd quarter',
#    'period3': '3rd quarter',
#    'period4': '4th quarter',
#    'overtime': 'Overtime'},
#   'startTimestamp': 1728580500,
#   'slug': 'virtus-segafredo-bologna-ldlc-asvel-lyon-villeurbanne',
#   'finalResultOnly': True,
#   'feedLocked': True,
#   'isEditor': True},
#  {'officials': [],
#   'tournament': {'name': 'Euroleague',
#    'slug': 'euroleague',
#    'category': {'name': 'International',
#     'slug': 'international',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'id': 103,
#     'country': {},
#     'flag': 'international'},
#    'uniqueTournament': {'name': 'Euroleague',
#     'slug': 'euroleague',
#     'category': {'name': 'International',
#      'slug': 'international',
#      'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#      'id': 103,
#      'country': {},
#      'flag': 'international'},
#     'userCount': 63470,
#     'hasPerformanceGraphFeature': True,
#     'id': 138,
#     'hasEventPlayerStatistics': False,
#     'hasBoxScore': True,
#     'displayInverseHomeAwayTeams': True},
#    'priority': 130,
#    'id': 42527},
#   'season': {'name': 'Euroleague 24/25',
#    'year': '24/25',
#    'editor': True,
#    'id': 63971},
#   'roundInfo': {'round': 2},
#   'customId': 'ivbxwwk',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 1,
#   'homeTeam': {'name': 'Panathinaikos BC',
#    'slug': 'panathinaikos-bc',
#    'shortName': 'Panathinaikos',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 49105,
#    'nameCode': 'PAN',
#    'disabled': True,
#    'national': False,
#    'type': 0,
#    'id': 3508,
#    'country': {'alpha2': 'GR',
#     'alpha3': 'GRC',
#     'name': 'Greece',
#     'slug': 'greece'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'پاناتينايكوس',
#      'ru': 'Панатинайкос'},
#     'shortNameTranslation': {}}},
#   'awayTeam': {'name': 'Bayern München',
#    'slug': 'bayern-munchen',
#    'shortName': 'Bayern',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 15159,
#    'nameCode': 'BAY',
#    'disabled': True,
#    'national': True,
#    'type': 0,
#    'id': 26071,
#    'country': {'alpha2': 'DE',
#     'alpha3': 'DEU',
#     'name': 'Germany',
#     'slug': 'germany'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ru': 'Бавария Мюнхен'},
#     'shortNameTranslation': {}}},
#   'homeScore': {'current': 94,
#    'display': 94,
#    'period1': 25,
#    'period2': 23,
#    'period3': 19,
#    'period4': 28,
#    'normaltime': 95},
#   'awayScore': {'current': 79,
#    'display': 79,
#    'period1': 17,
#    'period2': 18,
#    'period3': 24,
#    'period4': 22,
#    'normaltime': 80},
#   'time': {'played': 2400,
#    'periodLength': 601,
#    'overtimeLength': 300,
#    'totalPeriodCount': 4,
#    'currentPeriodStartTimestamp': 1728590511},
#   'changes': {'changes': ['time.currentPeriodStart',
#     'status.code',
#     'status.description',
#     'status.type',
#     'homeScore.normaltime',
#     'awayScore.normaltime'],
#    'changeTimestamp': 1728590518},
#   'hasGlobalHighlights': True,
#   'hasEventPlayerStatistics': True,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12544778,
#   'periods': {'current': 'Score',
#    'period1': '1st quarter',
#    'period2': '2nd quarter',
#    'period3': '3rd quarter',
#    'period4': '4th quarter',
#    'overtime': 'Overtime'},
#   'startTimestamp': 1728581400,
#   'slug': 'bayern-munchen-panathinaikos-bc',
#   'finalResultOnly': True,
#   'feedLocked': False,
#   'isEditor': False},
#  {'officials': [],
#   'tournament': {'name': 'Euroleague',
#    'slug': 'euroleague',
#    'category': {'name': 'International',
#     'slug': 'international',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'id': 103,
#     'country': {},
#     'flag': 'international'},
#    'uniqueTournament': {'name': 'Euroleague',
#     'slug': 'euroleague',
#     'category': {'name': 'International',
#      'slug': 'international',
#      'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#      'id': 103,
#      'country': {},
#      'flag': 'international'},
#     'userCount': 63470,
#     'hasPerformanceGraphFeature': False,
#     'id': 138,
#     'hasEventPlayerStatistics': False,
#     'hasBoxScore': True,
#     'displayInverseHomeAwayTeams': True},
#    'priority': 130,
#    'id': 42527},
#   'season': {'name': 'Euroleague 24/25',
#    'year': '24/25',
#    'editor': True,
#    'id': 63971},
#   'roundInfo': {'round': 2},
#   'customId': 'PvbsMHc',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 1,
#   'homeTeam': {'name': 'Real Madrid',
#    'slug': 'real-madrid',
#    'shortName': 'Real Madrid',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 87244,
#    'nameCode': 'RMA',
# ...
#    'userCount': 358,
#    'nameCode': 'FEN',
#    'national': True,
#    'type': 0,
#    'id': 398645,
#    'country': {'alpha2': 'TR',
#     'alpha3': 'TUR',
#     'name': 'Türkiye',
#     'slug': 'turkiye'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'}},
#   'homeScore': {},
#   'awayScore': {},
#   'time': {},
#   'changes': {'changes': ['status.code', 'status.description', 'status.type'],
#    'changeTimestamp': 1726059052},
#   'hasGlobalHighlights': True,
#   'crowdsourcingDataDisplayEnabled': True,
#   'id': 12736211,
#   'periods': {'current': 'Score',
#    'period1': '1st quarter',
#    'period2': '2nd quarter',
#    'period3': '3rd quarter',
#    'period4': '4th quarter',
#    'overtime': 'Overtime'},
#   'startTimestamp': 1728664200,
#   'slug': 'fenerbahce-koleji-bornova-belediye',
#   'finalResultOnly': True,
#   'feedLocked': True,
#   'isEditor': False},
#  {'officials': [],
#   'tournament': {'name': 'Liga de Ascenso, Playoffs',
#    'slug': 'el-metro-playoffs',
#    'category': {'name': 'Uruguay',
#     'slug': 'uruguay',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'id': 549,
#     'country': {'alpha2': 'UY',
#      'alpha3': 'URY',
#      'name': 'Uruguay',
#      'slug': 'uruguay'},
#     'flag': 'uruguay',
#     'alpha2': 'UY'},
#    'uniqueTournament': {'name': 'El Metro',
#     'slug': 'el-metro',
#     'category': {'name': 'Uruguay',
#      'slug': 'uruguay',
#      'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#      'id': 549,
#      'country': {'alpha2': 'UY',
#       'alpha3': 'URY',
#       'name': 'Uruguay',
#       'slug': 'uruguay'},
#      'flag': 'uruguay',
#      'alpha2': 'UY'},
#     'userCount': 714,
#     'id': 13647,
#     'hasEventPlayerStatistics': True,
#     'hasBoxScore': False,
#     'displayInverseHomeAwayTeams': True},
#    'priority': 0,
#    'id': 75219},
#   'season': {'name': 'Liga de Ascenso 2024',
#    'year': '2024',
#    'editor': True,
#    'id': 60595},
#   'roundInfo': {'round': 28, 'name': 'Semifinals', 'cupRoundType': 2},
#   'customId': 'czVbsjybc',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 1,
#   'homeTeam': {'name': 'Goes',
#    'slug': 'goes',
#    'shortName': 'Goes',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 453,
#    'nameCode': 'GOE',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 238702,
#    'country': {'alpha2': 'UY',
#     'alpha3': 'URY',
#     'name': 'Uruguay',
#     'slug': 'uruguay'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'},
#    'fieldTranslations': {'nameTranslation': {'ar': 'نادي غوس'},
#     'shortNameTranslation': {}}},
#   'awayTeam': {'name': 'Capitol',
#    'slug': 'capitol',
#    'shortName': 'Capitol',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 308,
#    'nameCode': 'CAP',
#    'national': False,
#    'type': 0,
#    'id': 288659,
#    'country': {'alpha2': 'UY',
#     'alpha3': 'URY',
#     'name': 'Uruguay',
#     'slug': 'uruguay'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'}},
#   'homeScore': {'current': 90,
#    'display': 91,
#    'period1': 30,
#    'period2': 21,
#    'period3': 23,
#    'period4': 19,
#    'normaltime': 91},
#   'awayScore': {'current': 86,
#    'display': 86,
#    'period1': 20,
#    'period2': 28,
#    'period3': 17,
#    'period4': 22,
#    'normaltime': 85},
#   'time': {'played': 0,
#    'periodLength': 601,
#    'overtimeLength': 300,
#    'totalPeriodCount': 4},
#   'changes': {'changes': ['status.code',
#     'status.description',
#     'status.type',
#     'homeScore.normaltime',
#     'awayScore.current',
#     'awayScore.display',
#     'awayScore.period4',
#     'awayScore.normaltime',
#     'time.played'],
#    'changeTimestamp': 1728692614},
#   'hasGlobalHighlights': False,
#   'hasEventPlayerStatistics': True,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12962906,
#   'periods': {'current': 'Score',
#    'period1': '1st quarter',
#    'period2': '2nd quarter',
#    'period3': '3rd quarter',
#    'period4': '4th quarter',
#    'overtime': 'Overtime'},
#   'startTimestamp': 1728680400,
#   'slug': 'capitol-goes',
#   'finalResultOnly': False,
#   'feedLocked': False,
#   'isEditor': False},
#  {'officials': [],
#   'tournament': {'name': 'Euroleague 2K/Euroliga Virtual',
#    'slug': 'wallex-euroleague',
#    'category': {'name': 'Virtual Basketball',
#     'slug': 'virtual-basketball',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'id': 1215,
#     'country': {},
#     'flag': 'virtual-basketball'},
#    'uniqueTournament': {'name': 'Euroleague 2K',
#     'slug': 'wallex-euroleague',
#     'category': {'name': 'Virtual Basketball',
#      'slug': 'virtual-basketball',
#      'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#      'id': 1215,
#      'country': {},
#      'flag': 'virtual-basketball'},
#     'userCount': 70,
#     'hasPerformanceGraphFeature': False,
#     'id': 23100,
#     'hasEventPlayerStatistics': True,
#     'displayInverseHomeAwayTeams': True},
#    'priority': 0,
#    'id': 136477},
#   'season': {'name': '2K25 Season 1',
#    'year': '2K25 Season 1',
#    'editor': True,
#    'id': 64630},
#   'roundInfo': {'round': 1},
#   'customId': 'PFxeszkUf',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 1,
#   'homeTeam': {'name': 'Baskonia Vitoria-Gasteiz (eSport)',
#    'slug': 'baskonia-vitoria-gasteiz-esport',
#    'shortName': 'Baskonia',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 7,
#    'nameCode': 'BVE',
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 556540,
#    'country': {'alpha2': 'ES',
#     'alpha3': 'ESP',
#     'name': 'Spain',
#     'slug': 'spain'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'}},
#   'awayTeam': {'name': 'Partizan Mozzart Bet Belgrade (eSport)',
#    'slug': 'partizan-mozzartbet-belgrade-e',
#    'shortName': 'Partizan Mozzartbet',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 29,
#    'nameCode': 'PMB',
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 735724,
#    'country': {'alpha2': 'RS',
#     'alpha3': 'SRB',
#     'name': 'Serbia',
#     'slug': 'serbia'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'}},
#   'homeScore': {'current': 85,
#    'display': 85,
#    'period1': 26,
#    'period2': 22,
#    'period3': 15,
#    'period4': 24,
#    'normaltime': 86},
#   'awayScore': {'current': 84,
#    'display': 84,
#    'period1': 16,
#    'period2': 16,
#    'period3': 30,
#    'period4': 25,
#    'normaltime': 84},
#   'coverage': -1,
#   'time': {},
#   'changes': {'changeTimestamp': 0},
#   'hasGlobalHighlights': True,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12658016,
#   'periods': {'current': 'Score',
#    'period1': '1st quarter',
#    'period2': '2nd quarter',
#    'period3': '3rd quarter',
#    'period4': '4th quarter',
#    'overtime': 'Overtime'},
#   'startTimestamp': 1728720937,
#   'slug': 'partizan-mozzart-bet-belgrade-esport-baskonia-vitoria-gasteiz-esport',
#   'finalResultOnly': False,
#   'feedLocked': False,
#   'isEditor': False},
#  {'officials': [],
#   'tournament': {'name': 'Eurocup 2K/Virtual EuroCup - Group B',
#    'slug': 'amigozzz-eurocup-group-b',
#    'category': {'name': 'Virtual Basketball',
#     'slug': 'virtual-basketball',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'id': 1215,
#     'country': {},
#     'flag': 'virtual-basketball'},
#    'uniqueTournament': {'name': 'EuroCup 2K',
#     'slug': 'amigozzz-eurocup',
#     'category': {'name': 'Virtual Basketball',
#      'slug': 'virtual-basketball',
#      'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#      'id': 1215,
#      'country': {},
#      'flag': 'virtual-basketball'},
#     'userCount': 19,
#     'hasPerformanceGraphFeature': True,
#     'id': 23101,
#     'hasEventPlayerStatistics': False,
#     'displayInverseHomeAwayTeams': False},
#    'priority': 0,
#    'id': 136480},
#   'season': {'name': '2k25 Season 1',
#    'year': '2k25 Season 1',
#    'editor': False,
#    'id': 64631},
#   'roundInfo': {'round': 6},
#   'customId': 'mGxeboGxe',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 2,
#   'homeTeam': {'name': 'U-BT Cluj-Napoca (eSport)',
#    'slug': 'u-bt-cluj-napoca-e',
#    'shortName': 'U-BT Cluj',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 1,
#    'nameCode': 'UCE',
#    'disabled': False,
#    'national': False,
#    'type': 0,
#    'id': 556562,
#    'country': {'alpha2': 'RO',
#     'alpha3': 'ROU',
#     'name': 'Romania',
#     'slug': 'romania'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'}},
#   'awayTeam': {'name': 'Hapoel Bank Yahav Jerusalem (eSport)',
#    'slug': 'hapoel-bank-yahav-jerusalem-viktor-vladov',
#    'shortName': 'Hapoel Jerusalem',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 0,
#    'nameCode': 'HBY',
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 556564,
#    'country': {'alpha2': 'IL',
#     'alpha3': 'ISR',
#     'name': 'Israel',
#     'slug': 'israel'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'}},
#   'homeScore': {'current': 49,
#    'display': 48,
#    'period1': 16,
#    'period2': 18,
#    'period3': 7,
#    'period4': 9,
#    'normaltime': 49},
#   'awayScore': {'current': 66,
#    'display': 65,
#    'period1': 20,
#    'period2': 18,
#    'period3': 17,
#    'period4': 12,
#    'normaltime': 66},
#   'coverage': -1,
#   'time': {},
#   'changes': {'changeTimestamp': 0},
#   'hasGlobalHighlights': False,
#   'crowdsourcingDataDisplayEnabled': True,
#   'id': 12700922,
#   'periods': {'current': 'Score',
#    'period1': '1st quarter',
#    'period2': '2nd quarter',
#    'period3': '3rd quarter',
#    'period4': '4th quarter',
#    'overtime': 'Overtime'},
#   'startTimestamp': 1728589500,
#   'slug': 'hapoel-bank-yahav-jerusalem-esport-u-bt-cluj-napoca-esport',
#   'finalResultOnly': False,
#   'feedLocked': True,
#   'isEditor': False},
#  {'officials': [],
#   'tournament': {'name': 'Eurocup 2K/Virtual EuroCup - Group B',
#    'slug': 'amigozzz-eurocup-group-b',
#    'category': {'name': 'Virtual Basketball',
#     'slug': 'virtual-basketball',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'id': 1215,
#     'country': {},
#     'flag': 'virtual-basketball'},
#    'uniqueTournament': {'name': 'EuroCup 2K',
#     'slug': 'amigozzz-eurocup',
#     'category': {'name': 'Virtual Basketball',
#      'slug': 'virtual-basketball',
#      'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#      'id': 1215,
#      'country': {},
#      'flag': 'virtual-basketball'},
#     'userCount': 19,
#     'hasPerformanceGraphFeature': True,
#     'id': 23101,
#     'hasEventPlayerStatistics': True,
#     'displayInverseHomeAwayTeams': True},
#    'priority': 0,
#    'id': 136480},
#   'season': {'name': '2k25 Season 1',
#    'year': '2k25 Season 1',
#    'editor': True,
#    'id': 64631},
#   'roundInfo': {'round': 17},
#   'customId': 'mGfesoGxe',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 1,
#   'homeTeam': {'name': 'Hapoel Bank Yahav Jerusalem (eSport)',
#    'slug': 'hapoel-bank-yahav-jerusalem-viktor-vladov',
#    'shortName': 'Hapoel Jerusalem',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 0,
#    'nameCode': 'HBY',
#    'disabled': True,
#    'national': False,
#    'type': 0,
#    'id': 556564,
#    'country': {'alpha2': 'IL',
#     'alpha3': 'ISR',
#     'name': 'Israel',
#     'slug': 'israel'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'}},
#   'awayTeam': {'name': 'U-BT Cluj-Napoca (eSport)',
#    'slug': 'u-bt-cluj-napoca-e',
#    'shortName': 'U-BT Cluj',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 1,
#    'nameCode': 'UCE',
#    'disabled': True,
#    'national': False,
#    'type': 0,
#    'id': 556562,
#    'country': {'alpha2': 'RO',
#     'alpha3': 'ROU',
#     'name': 'Romania',
#     'slug': 'romania'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'}},
#   'homeScore': {'current': 74,
#    'display': 73,
#    'period1': 21,
#    'period2': 20,
#    'period3': 21,
#    'period4': 13,
#    'normaltime': 73},
#   'awayScore': {'current': 50,
#    'display': 51,
#    'period1': 17,
#    'period2': 17,
#    'period3': 13,
#    'period4': 6,
#    'normaltime': 51},
#   'coverage': -1,
#   'time': {},
#   'changes': {'changeTimestamp': 0},
#   'hasGlobalHighlights': False,
#   'crowdsourcingDataDisplayEnabled': True,
#   'id': 12701012,
#   'periods': {'current': 'Score',
#    'period1': '1st quarter',
#    'period2': '2nd quarter',
#    'period3': '3rd quarter',
#    'period4': '4th quarter',
#    'overtime': 'Overtime'},
#   'startTimestamp': 1728595800,
#   'slug': 'hapoel-bank-yahav-jerusalem-esport-u-bt-cluj-napoca-esport',
#   'finalResultOnly': False,
#   'feedLocked': True,
#   'isEditor': False},
#  {'officials': [],
#   'tournament': {'name': 'Eurocup 2K/Virtual EuroCup - Group B',
#    'slug': 'amigozzz-eurocup-group-b',
#    'category': {'name': 'Virtual Basketball',
#     'slug': 'virtual-basketball',
#     'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#     'id': 1215,
#     'country': {},
#     'flag': 'virtual-basketball'},
#    'uniqueTournament': {'name': 'EuroCup 2K',
#     'slug': 'amigozzz-eurocup',
#     'category': {'name': 'Virtual Basketball',
#      'slug': 'virtual-basketball',
#      'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#      'id': 1215,
#      'country': {},
#      'flag': 'virtual-basketball'},
#     'userCount': 19,
#     'hasPerformanceGraphFeature': True,
#     'id': 23101,
#     'hasEventPlayerStatistics': False,
#     'displayInverseHomeAwayTeams': False},
#    'priority': 0,
#    'id': 136480},
#   'season': {'name': '2k25 Season 1',
#    'year': '2k25 Season 1',
#    'editor': False,
#    'id': 64631},
#   'roundInfo': {'round': 11},
#   'customId': 'mGxesrGle',
#   'status': {'code': 100, 'description': 'Ended', 'type': 'finished'},
#   'winnerCode': 1,
#   'homeTeam': {'name': 'Aris Midea Thessaloniki (eSport)',
#    'slug': 'aris-midea-thessaloniki-e',
#    'shortName': 'Aris Midea',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 3,
#    'nameCode': 'AMT',
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 556567,
#    'country': {'alpha2': 'GR',
#     'alpha3': 'GRC',
#     'name': 'Greece',
#     'slug': 'greece'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'}},
#   'awayTeam': {'name': 'U-BT Cluj-Napoca (eSport)',
#    'slug': 'u-bt-cluj-napoca-e',
#    'shortName': 'U-BT Cluj',
#    'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#    'userCount': 1,
#    'nameCode': 'UCE',
#    'disabled': False,
#    'national': True,
#    'type': 0,
#    'id': 556562,
#    'country': {'alpha2': 'RO',
#     'alpha3': 'ROU',
#     'name': 'Romania',
#     'slug': 'romania'},
#    'subTeams': [],
#    'teamColors': {'primary': '#374df5',
#     'secondary': '#374df5',
#     'text': '#ffffff'}},
#   'homeScore': {'current': 68,
#    'display': 69,
#    'period1': 11,
#    'period2': 19,
#    'period3': 21,
#    'period4': 20,
#    'normaltime': 68},
#   'awayScore': {'current': 46,
#    'display': 46,
#    'period1': 9,
#    'period2': 11,
#    'period3': 17,
#    'period4': 10,
#    'normaltime': 45},
#   'coverage': -1,
#   'time': {},
#   'changes': {'changeTimestamp': 0},
#   'hasGlobalHighlights': True,
#   'crowdsourcingDataDisplayEnabled': False,
#   'id': 12700970,
#   'periods': {'current': 'Score',
#    'period1': '1st quarter',
#    'period2': '2nd quarter',
#    'period3': '3rd quarter',
#    'period4': '4th quarter',
#    'overtime': 'Overtime'},
#   'startTimestamp': 1728680400,
#   'slug': 'aris-midea-thessaloniki-esport-u-bt-cluj-napoca-esport',
#   'finalResultOnly': False,
#   'feedLocked': False,
#   'isEditor': True}]

# %%
type(matches)
# Out:
# list

# %%
# Ce qui nous intéresse ce sont les matchs disponible pour lesquels on a les informations importantes
# Pour continuer ce DOJO, vous aurez besoin de l'ID du match que vous allez choisir pour analyser
# ICI on vous donne la façon d'accéder aux matchs et trouver les noms des équipes
print("Matchs disponibles :")
for match in matches:
    print(f"Match ID: {match['id']}, {match['homeTeam']['name']} vs {match['awayTeam']['name']}")
# Out:
# Matchs disponibles :
# Match ID: 12731839, Cleveland Cavaliers vs Indiana Pacers
# Match ID: 12731844, Dallas Mavericks vs Utah Jazz
# Match ID: 12731842, Memphis Grizzlies vs Charlotte Hornets
# Match ID: 12731845, Milwaukee Bucks vs Los Angeles Lakers
# Match ID: 12731843, Oklahoma City Thunder vs New Zealand Breakers
# Match ID: 12731848, Minnesota Timberwolves vs Philadelphia 76ers
# Match ID: 12731846, Orlando Magic vs New Orleans Pelicans
# Match ID: 12731847, Washington Wizards vs Toronto Raptors
# Match ID: 12731852, Golden State Warriors vs Sacramento Kings
# Match ID: 12731849, Phoenix Suns vs Detroit Pistons
# Match ID: 12946619, FCC UAV Basketball Arad vs CS Agronomia Bucuresti
# Match ID: 12929887, ACS Stars 2012 Iasi vs CS Municipal Focșani 2007
# Match ID: 12929890, CS Targu Mures University vs CSS VSK Gheorgheni
# Match ID: 12795205, Spartak Vidnoje vs Runa Moscow
# Match ID: 12795204, Dinamo-Guvd Novosibirsk vs UMMC Ekaterinburg
# Match ID: 12795206, Yenisey Krasnoyarsk BC vs Nika Syktyvkar
# Match ID: 12795203, Neftyanik Omsk Oblast vs Dynamo Moscow
# Match ID: 12795207, Dynamo Kursk vs Nadezhda Orenburg
# Match ID: 12795212, MBA Moscow vs BC Samara
# Match ID: 12923657, KK Zemun vs OKK Ivanjica
# Match ID: 12923622, KK Dunav Stari Banovci vs KK Proleter Naftagas Zrenjanin
# Match ID: 12909808, KK Akademik Srbobran vs KK Star
# Match ID: 12697729, KK Ilirija vs Terme Olimia Podcetrtek
# Match ID: 12697727, Helios Domžale vs Triglav Elektro Gorenjska Prodaja
# Match ID: 12948875, Mpumalanga Rhinos vs Tshwane Suns
# Match ID: 12966484, Ulsan Hyundai Mobis Phoebus vs Wonju DB Promy
# Match ID: 12966480, Daegu KOGAS Pegasus vs Suwon KT Sonicboom
# Match ID: 12634906, Grupo Ureta Tizona Burgos vs Movistar Estudiantes
# Match ID: 12634907, TAU Castelló vs CB Zamora
# Match ID: 12506983, BC Luleå vs Uppsala Basket
# Match ID: 12506986, Borås Basket vs Hogsbo Basket
# Match ID: 12506988, Jämtland Basket vs Umeå BSKT
# Match ID: 12743176, Djurgården Basket vs Wetterbygden Stars
# Match ID: 12811996, Baden Basket 54 vs Helios VS Basket
# Match ID: 12789828, Bernex Basket vs Villars Basket
# Match ID: 12789827, Centre National du Basket Suisse vs BC Allschwil
# Match ID: 12735831, Emlak Konut SK vs Nesibe Aydin
# Match ID: 12806575, Trabzonspor BK vs Final Genclik
# Match ID: 12736224, Kapakli Spor vs Bordo BK
# Match ID: 12736213, MKE Ankaragücü vs Konya Basket
# Match ID: 12736211, Bornova Belediye vs Fenerbahce Koleji
# Match ID: 12962906, Goes vs Capitol
# Match ID: 12658016, Baskonia Vitoria-Gasteiz (eSport) vs Partizan Mozzart Bet Belgrade (eSport)
# Match ID: 12700922, U-BT Cluj-Napoca (eSport) vs Hapoel Bank Yahav Jerusalem (eSport)
# Match ID: 12701012, Hapoel Bank Yahav Jerusalem (eSport) vs U-BT Cluj-Napoca (eSport)
# Match ID: 12700970, Aris Midea Thessaloniki (eSport) vs U-BT Cluj-Napoca (eSport)

# %% [markdown]
# ## Étape 2 : Sélectionner un match et récupérer les id et noms des joueurs

# %%
# Saisir un ID au hasard ou un match qui est intéressant pour vous
match_id = input("Entrez l'ID du match : ")

# On construit l'URL pour les compositions
url_lineups = f'https://api.sofascore.com/api/v1/event/{match_id}/lineups'

# Fais une requête GET
response = requests.get(url_lineups)

# Récupére les données des joueurs des deux équipes
data = response.json()
data
# Out:
# Entrez l'ID du match : 12731845
# {'confirmed': False,
#  'home': {'players': [{'player': {'name': 'Bobby Portis',
#      'firstName': 'Bobby',
#      'lastName': 'Portis',
#      'slug': 'portis-bobby',
#      'shortName': 'B. Portis',
#      'position': 'F',
#      'jerseyNumber': '9',
#      'height': 208,
#      'userCount': 1574,
#      'id': 817329,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 792374400,
#      'fieldTranslations': {'nameTranslation': {'ar': 'بوبي بورتيس'},
#       'shortNameTranslation': {'ar': 'ب. بورتيس'}}},
#     'teamId': 3410,
#     'shirtNumber': 9,
#     'jerseyNumber': '9',
#     'position': 'F',
#     'substitute': True,
#     'statistics': {'secondsPlayed': 1430,
#      'points': 4,
#      'twoPointsMade': 2,
#      'twoPointAttempts': 6,
#      'threePointsMade': 6,
#      'threePointAttempts': 4,
#      'freeThrowsMade': 2,
#      'freeThrowAttempts': 0,
#      'fieldGoalsMade': 14,
#      'fieldGoalAttempts': 8,
#      'rebounds': 0,
#      'defensiveRebounds': 0,
#      'offensiveRebounds': 0,
#      'turnovers': 0,
#      'blocks': 0,
#      'personalFouls': 0,
#      'assists': 0,
#      'steals': 0,
#      'plusMinus': 4,
#      'fieldGoalPct': 10}},
#    {'player': {'name': 'Pat Connaughton',
#      'firstName': 'Pat',
#      'lastName': 'Connaughton',
#      'slug': 'connaughton-pat',
#      'shortName': 'P. Connaughton',
#      'position': 'G',
#      'jerseyNumber': '24',
#      'height': 196,
#      'userCount': 419,
#      'id': 817039,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 726278400,
#      'fieldTranslations': {'nameTranslation': {'ar': 'بات كونوتون'},
#       'shortNameTranslation': {'ar': 'ب. كونوتون'}}},
#     'teamId': 3410,
#     'shirtNumber': 24,
#     'jerseyNumber': '24',
#     'position': 'G',
#     'substitute': True,
#     'statistics': {'secondsPlayed': 702,
#      'points': 4,
#      'twoPointsMade': 0,
#      'twoPointAttempts': 0,
#      'threePointsMade': 0,
#      'threePointAttempts': 0,
#      'freeThrowsMade': 0,
#      'freeThrowAttempts': 0,
#      'fieldGoalsMade': 2,
#      'fieldGoalAttempts': 0,
#      'rebounds': 2,
#      'defensiveRebounds': 0,
#      'offensiveRebounds': 0,
#      'turnovers': 0,
#      'blocks': 0,
#      'personalFouls': 0,
#      'assists': 2,
#      'steals': 0,
#      'plusMinus': 0,
#      'fieldGoalPct': 122}},
#    {'player': {'name': 'AJ Johnson',
#      'slug': 'johnson-aj',
#      'shortName': 'A. Johnson',
#      'position': 'G',
#      'jerseyNumber': '77',
#      'height': 196,
#      'userCount': 114,
#      'id': 1540637,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 1101859200},
#     'teamId': 3410,
#     'position': 'G',
#     'substitute': True,
#     'statistics': {'secondsPlayed': 500,
#      'points': 20,
#      'twoPointsMade': 2,
#      'twoPointAttempts': 2,
#      'threePointsMade': 4,
#      'threePointAttempts': 2,
#      'freeThrowsMade': 0,
#      'freeThrowAttempts': 0,
#      'fieldGoalsMade': 4,
#      'fieldGoalAttempts': 10,
#      'rebounds': 0,
#      'defensiveRebounds': 2,
#      'offensiveRebounds': 0,
#      'turnovers': 0,
#      'blocks': 0,
#      'personalFouls': 0,
#      'assists': 4,
#      'steals': 0,
#      'plusMinus': 2,
#      'fieldGoalPct': 18}},
#    {'player': {'name': 'AJ Green',
#      'firstName': 'AJ',
#      'lastName': 'Green',
#      'slug': 'green-aj',
#      'shortName': 'A. Green',
#      'position': 'G',
#      'jerseyNumber': '20',
#      'height': 193,
#      'userCount': 208,
#      'id': 1179862,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 938390400,
#      'fieldTranslations': {'nameTranslation': {'ar': 'أي جاي غرين'},
#       'shortNameTranslation': {'ar': 'أ. ج. غرين'}}},
#     'teamId': 3410,
#     'shirtNumber': 20,
#     'jerseyNumber': '20',
#     'position': 'G',
#     'substitute': False,
#     'statistics': {'secondsPlayed': 1166,
#      'points': 2,
#      'twoPointsMade': 0,
#      'twoPointAttempts': 0,
#      'threePointsMade': 0,
#      'threePointAttempts': 4,
#      'freeThrowsMade': 0,
#      'freeThrowAttempts': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalAttempts': 0,
#      'rebounds': 0,
#      'defensiveRebounds': 0,
#      'offensiveRebounds': 0,
#      'turnovers': 2,
#      'blocks': 0,
#      'personalFouls': 0,
#      'assists': 0,
#      'steals': 0,
#      'plusMinus': 6,
#      'fieldGoalPct': 14}},
#    {'player': {'name': 'MarJon Beauchamp',
#      'firstName': 'MarJon',
#      'lastName': 'Beauchamp',
#      'slug': 'beauchamp-marjon',
#      'shortName': 'M. Beauchamp',
#      'position': 'F',
#      'jerseyNumber': '3',
#      'height': 201,
#      'userCount': 253,
#      'id': 1206073,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 971308800,
#      'fieldTranslations': {'nameTranslation': {'ar': 'مارجون بوشامب'},
#       'shortNameTranslation': {'ar': 'م. بوشامب'}}},
#     'teamId': 3410,
#     'shirtNumber': 3,
#     'jerseyNumber': '3',
#     'position': 'F',
#     'substitute': False,
#     'statistics': {'secondsPlayed': 1426,
#      'points': 0,
#      'twoPointsMade': 2,
#      'twoPointAttempts': 2,
#      'threePointsMade': 0,
#      'threePointAttempts': 0,
#      'freeThrowsMade': 0,
#      'freeThrowAttempts': 0,
#      'fieldGoalsMade': 2,
#      'fieldGoalAttempts': 0,
#      'rebounds': 2,
#      'defensiveRebounds': 0,
#      'offensiveRebounds': 0,
#      'turnovers': 0,
#      'blocks': 0,
#      'personalFouls': 0,
#      'assists': 6,
#      'steals': 0,
#      'plusMinus': 0,
#      'fieldGoalPct': 24}},
#    {'player': {'name': 'Stanley Umude',
#      'firstName': 'Stanley',
#      'lastName': 'Umude',
#      'slug': 'stanley-umude',
#      'shortName': 'S. Umude',
#      'position': 'G',
#      'jerseyNumber': '17',
#      'height': 198,
#      'userCount': 49,
#      'id': 1178570,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 923875200,
#      'fieldTranslations': {'nameTranslation': {'ar': 'ستانلي أومود'},
#       'shortNameTranslation': {'ar': 'س. أومود'}}},
#     'teamId': 3410,
#     'shirtNumber': 17,
#     'jerseyNumber': '17',
#     'position': 'G',
#     'substitute': False,
#     'statistics': {'secondsPlayed': 212,
#      'points': 0,
#      'twoPointsMade': 0,
#      'twoPointAttempts': 0,
#      'threePointsMade': 0,
#      'threePointAttempts': 0,
#      'freeThrowsMade': 0,
#      'freeThrowAttempts': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalAttempts': 0,
#      'rebounds': 2,
#      'defensiveRebounds': 0,
#      'offensiveRebounds': 0,
#      'turnovers': 0,
#      'blocks': 0,
#      'personalFouls': 0,
#      'assists': 0,
#      'steals': 0,
#      'plusMinus': 0,
#      'fieldGoalPct': 0}},
#    {'player': {'name': 'Tyler Smith',
#      'firstName': 'Tyler Smith',
#      'slug': 'smith-tyler',
#      'shortName': 'T. Smith',
#      'position': 'F',
#      'jerseyNumber': '21',
#      'height': 206,
#      'userCount': 68,
#      'id': 1629480,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 1099353600},
#     'teamId': 3410,
#     'shirtNumber': 21,
#     'jerseyNumber': '21',
#     'position': 'F',
#     'substitute': False,
#     'statistics': {'secondsPlayed': 1974,
#      'points': 2,
#      'twoPointsMade': 0,
#      'twoPointAttempts': 0,
#      'threePointsMade': 0,
#      'threePointAttempts': 4,
#      'freeThrowsMade': 0,
#      'freeThrowAttempts': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalAttempts': 6,
#      'rebounds': 8,
#      'defensiveRebounds': 0,
#      'offensiveRebounds': 0,
#      'turnovers': 2,
#      'blocks': 0,
#      'personalFouls': 0,
#      'assists': 0,
#      'steals': 2,
#      'plusMinus': 0,
#      'fieldGoalPct': 4}},
#    {'player': {'name': 'Taurean Prince',
#      'firstName': 'Taurean',
#      'lastName': 'Prince',
#      'slug': 'taurean-prince',
#      'shortName': 'T. Prince',
#      'position': 'F',
#      'jerseyNumber': '12',
#      'height': 198,
#      'userCount': 733,
#      'id': 846893,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 764294400,
#      'fieldTranslations': {'nameTranslation': {'ar': 'توريان برينس'},
#       'shortNameTranslation': {'ar': 'ت. برينس'}}},
#     'teamId': 3410,
#     'shirtNumber': 12,
#     'jerseyNumber': '12',
#     'position': 'F',
#     'substitute': False,
#     'statistics': {'secondsPlayed': 10,
#      'points': 0,
#      'twoPointsMade': 0,
#      'twoPointAttempts': 0,
#      'threePointsMade': 0,
#      'threePointAttempts': 0,
#      'freeThrowsMade': 0,
#      'freeThrowAttempts': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalAttempts': 2,
#      'rebounds': 2,
#      'defensiveRebounds': 0,
#      'offensiveRebounds': 0,
#      'turnovers': 0,
#      'blocks': 0,
#      'personalFouls': 0,
#      'assists': 2,
#      'steals': 0,
#      'plusMinus': 0,
#      'fieldGoalPct': 46}},
#    {'player': {'name': 'Damian Lillard',
#      'firstName': 'Damian',
#      'lastName': 'Lillard',
#      'slug': 'lillard-damian',
#      'shortName': 'D. Lillard',
#      'position': 'G',
#      'jerseyNumber': '0',
#      'height': 188,
#      'userCount': 17937,
#      'id': 817232,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 648000000,
#      'fieldTranslations': {'nameTranslation': {'ar': 'داميان ليلارد'},
#       'shortNameTranslation': {'ar': 'د. ليلارد'}}},
#     'teamId': 3410,
#     'shirtNumber': 0,
#     'jerseyNumber': '0',
#     'position': 'G',
#     'substitute': False,
#     'statistics': {'secondsPlayed': 2088,
#      'points': 10,
#      'twoPointsMade': 0,
#      'twoPointAttempts': 0,
#      'threePointsMade': 0,
#      'threePointAttempts': 2,
#      'freeThrowsMade': 4,
#      'freeThrowAttempts': 4,
#      'fieldGoalsMade': 2,
#      'fieldGoalAttempts': 6,
#      'rebounds': 4,
#      'defensiveRebounds': 6,
#      'offensiveRebounds': 0,
#      'turnovers': 0,
#      'blocks': 0,
#      'personalFouls': 0,
#      'assists': 4,
#      'steals': 0,
#      'plusMinus': 0,
#      'fieldGoalPct': 38}}],
#   'supportStaff': [],
#   'playerColor': {'primary': '000000',
#    'number': 'eee1c6',
#    'outline': '00471b',
#    'fancyNumber': '222226'},
#   'goalkeeperColor': {'primary': '000000',
#    'number': '000000',
#    'outline': 'fafb00',
#    'fancyNumber': '222226'}},
#  'away': {'players': [{'player': {'name': 'Jaxson Hayes',
#      'firstName': 'Jaxson',
#      'lastName': 'Hayes ',
#      'slug': 'jaxson-hayes',
#      'shortName': 'J. Hayes',
#      'position': 'CF',
#      'jerseyNumber': '11',
#      'height': 213,
#      'userCount': 478,
#      'id': 987100,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 959040000,
#      'fieldTranslations': {'nameTranslation': {'ar': 'جاكسون هايس'},
#       'shortNameTranslation': {'ar': 'ج. هايس'}}},
#     'teamId': 3427,
#     'shirtNumber': 11,
#     'jerseyNumber': '11',
#     'position': 'CF',
#     'substitute': True,
#     'statistics': {'secondsPlayed': 1354,
#      'points': 6,
#      'twoPointsMade': 4,
#      'twoPointAttempts': 2,
#      'threePointsMade': 0,
#      'threePointAttempts': 0,
#      'freeThrowsMade': 0,
#      'freeThrowAttempts': 0,
#      'fieldGoalsMade': 2,
#      'fieldGoalAttempts': 6,
#      'rebounds': 2,
#      'defensiveRebounds': 0,
#      'offensiveRebounds': 0,
#      'turnovers': 0,
#      'blocks': 0,
#      'personalFouls': 0,
#      'assists': 2,
#      'steals': 0,
#      'plusMinus': 0,
#      'fieldGoalPct': 132}},
#    {'player': {'name': 'Quincy Olivari',
#      'firstName': '',
#      'lastName': '',
#      'slug': 'olivari-quincy',
#      'shortName': 'Q. Olivari',
#      'position': 'G',
#      'jerseyNumber': '41',
#      'height': 191,
#      'userCount': 134,
#      'id': 1184925,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 990921600},
#     'teamId': 3427,
#     'shirtNumber': 41,
#     'jerseyNumber': '41',
#     'position': 'G',
#     'substitute': False,
#     'statistics': {'secondsPlayed': 704,
#      'points': 8,
#      'twoPointsMade': 0,
#      'twoPointAttempts': 2,
#      'threePointsMade': 0,
#      'threePointAttempts': 2,
#      'freeThrowsMade': 0,
#      'freeThrowAttempts': 0,
#      'fieldGoalsMade': 2,
#      'fieldGoalAttempts': 0,
#      'rebounds': 8,
#      'defensiveRebounds': 4,
#      'offensiveRebounds': 0,
#      'turnovers': 0,
#      'blocks': 0,
#      'personalFouls': 0,
#      'assists': 0,
#      'steals': 0,
#      'plusMinus': 30,
#      'fieldGoalPct': 66}},
#    {'player': {'name': 'Armel Traore',
#      'firstName': 'Armel',
#      'lastName': 'Traore',
#      'slug': 'traore-armel',
#      'shortName': 'A. Traore',
#      'position': 'F',
#      'jerseyNumber': '94',
#      'height': 205,
#      'userCount': 225,
#      'id': 1144675,
#      'country': {'alpha2': 'FR',
#       'alpha3': 'FRA',
#       'name': 'France',
#       'slug': 'france'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 1043280000},
#     'teamId': 3427,
#     'shirtNumber': 94,
#     'jerseyNumber': '94',
#     'position': 'F',
#     'substitute': False,
#     'statistics': {'secondsPlayed': 370,
#      'points': 6,
#      'twoPointsMade': 0,
#      'twoPointAttempts': 2,
#      'threePointsMade': 0,
#      'threePointAttempts': 0,
#      'freeThrowsMade': 0,
#      'freeThrowAttempts': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalAttempts': 6,
#      'rebounds': 4,
#      'defensiveRebounds': 0,
#      'offensiveRebounds': 2,
#      'turnovers': 2,
#      'blocks': 0,
#      'personalFouls': 0,
#      'assists': 0,
#      'steals': 0,
#      'plusMinus': 28,
#      'fieldGoalPct': 0}},
#    {'player': {'name': 'Colin Castleton',
#      'slug': 'castleton-colin',
#      'shortName': 'C. Castleton',
#      'position': 'C',
#      'jerseyNumber': '8',
#      'height': 208,
#      'userCount': 144,
#      'id': 1179398,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 959212800,
#      'fieldTranslations': {'nameTranslation': {'ar': 'كولن كاستليتون'},
#       'shortNameTranslation': {'ar': 'ك. كاستليتون'}}},
#     'teamId': 3415,
#     'shirtNumber': 14,
#     'jerseyNumber': '14',
#     'position': 'C',
#     'substitute': False,
#     'statistics': {'secondsPlayed': 0,
#      'points': 4,
#      'twoPointsMade': 0,
#      'twoPointAttempts': 0,
#      'threePointsMade': 0,
#      'threePointAttempts': 0,
#      'freeThrowsMade': 0,
#      'freeThrowAttempts': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalAttempts': 0,
#      'rebounds': 8,
#      'defensiveRebounds': 2,
#      'offensiveRebounds': 0,
#      'turnovers': 0,
#      'blocks': 0,
#      'personalFouls': 0,
#      'assists': 6,
#      'steals': 0,
#      'plusMinus': 10,
#      'fieldGoalPct': 138}},
#    {'player': {'name': 'Jordan Goodwin',
#      'firstName': 'Jordan',
#      'lastName': 'Goodwin ',
#      'slug': 'goodwin-jordan',
#      'shortName': 'J. Goodwin',
#      'position': 'G',
#      'height': 191,
#      'userCount': 123,
#      'id': 1134112,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 909100800,
#      'fieldTranslations': {'nameTranslation': {'ar': 'جوردن غودوين'},
#       'shortNameTranslation': {'ar': 'ج. غودوين'}}},
#     'teamId': 3427,
#     'shirtNumber': 30,
#     'jerseyNumber': '30',
#     'position': 'G',
#     'substitute': True,
#     'statistics': {'secondsPlayed': 432,
#      'points': 0,
#      'twoPointsMade': 0,
#      'twoPointAttempts': 0,
#      'threePointsMade': 0,
#      'threePointAttempts': 0,
#      'freeThrowsMade': 0,
#      'freeThrowAttempts': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalAttempts': 0,
#      'rebounds': 0,
#      'defensiveRebounds': 2,
#      'offensiveRebounds': 2,
#      'turnovers': 0,
#      'blocks': 0,
#      'personalFouls': 0,
#      'assists': 0,
#      'steals': 0,
#      'plusMinus': 0,
#      'fieldGoalPct': 0}},
#    {'player': {'name': 'Maxwell Lewis',
#      'firstName': '',
#      'lastName': '',
#      'slug': 'lewis-maxwell',
#      'shortName': 'M. Lewis',
#      'position': 'F',
#      'jerseyNumber': '20',
#      'height': 201,
#      'userCount': 181,
#      'id': 1181769,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 1027728000,
#      'fieldTranslations': {'nameTranslation': {'ar': 'ماكسويل لويس'},
#       'shortNameTranslation': {'ar': 'م. لويس'}}},
#     'teamId': 3427,
#     'shirtNumber': 20,
#     'jerseyNumber': '20',
#     'position': 'F',
#     'substitute': False,
#     'statistics': {'secondsPlayed': 432,
#      'points': 0,
#      'twoPointsMade': 0,
#      'twoPointAttempts': 2,
#      'threePointsMade': 0,
#      'threePointAttempts': 0,
#      'freeThrowsMade': 2,
#      'freeThrowAttempts': 2,
#      'fieldGoalsMade': 0,
#      'fieldGoalAttempts': 4,
#      'rebounds': 0,
#      'defensiveRebounds': 0,
#      'offensiveRebounds': 0,
#      'turnovers': 0,
#      'blocks': 0,
#      'personalFouls': 0,
#      'assists': 0,
#      'steals': 0,
#      'plusMinus': 16,
#      'fieldGoalPct': 86}},
#    {'player': {'name': "D'Angelo Russell",
#      'firstName': "D'Angelo",
#      'lastName': 'Russell ',
#      'slug': 'dangelo-russell',
#      'shortName': 'D. Russell',
#      'position': 'G',
#      'jerseyNumber': '1',
#      'height': 191,
#      'userCount': 4670,
#      'id': 817357,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 825033600,
#      'fieldTranslations': {'nameTranslation': {'ar': 'دي أنجلو راسل'},
#       'shortNameTranslation': {'ar': 'د. أ. راسل'}}},
#     'teamId': 3427,
#     'shirtNumber': 1,
#     'jerseyNumber': '1',
#     'position': 'G',
#     'substitute': False,
#     'statistics': {'secondsPlayed': 408,
#      'points': 0,
#      'twoPointsMade': 0,
#      'twoPointAttempts': 6,
#      'threePointsMade': 0,
#      'threePointAttempts': 4,
#      'freeThrowsMade': 0,
#      'freeThrowAttempts': 0,
#      'fieldGoalsMade': 0,
#      'fieldGoalAttempts': 8,
#      'rebounds': 0,
#      'defensiveRebounds': 0,
#      'offensiveRebounds': 0,
#      'turnovers': 2,
#      'blocks': 0,
#      'personalFouls': 0,
#      'assists': 6,
#      'steals': 0,
#      'plusMinus': 6,
#      'fieldGoalPct': 48}},
#    {'player': {'name': 'LeBron James',
#      'firstName': 'LeBron',
#      'lastName': 'James',
#      'slug': 'lebron-james',
#      'shortName': 'L. James',
#      'position': 'F',
#      'jerseyNumber': '23',
#      'height': 206,
#      'userCount': 103072,
#      'id': 817181,
#      'country': {'alpha2': 'US',
#       'alpha3': 'USA',
#       'name': 'USA',
#       'slug': 'usa'},
#      'marketValueCurrency': 'EUR',
#      'dateOfBirthTimestamp': 473212800,
#      'fieldTranslations': {'nameTranslation': {'ar': 'ليبرون جيمس'},
#       'shortNameTranslation': {'ar': 'ل. جيمس'}}},
#     'teamId': 3427,
#     'shirtNumber': 23,
#     'jerseyNumber': '23',
#     'position': 'F',
#     'substitute': False,
#     'statistics': {'secondsPlayed': 1192,
#      'points': 20,
#      'twoPointsMade': 2,
#      'twoPointAttempts': 4,
#      'threePointsMade': 2,
#      'threePointAttempts': 4,
#      'freeThrowsMade': 0,
#      'freeThrowAttempts': 2,
#      'fieldGoalsMade': 0,
#      'fieldGoalAttempts': 6,
#      'rebounds': 4,
#      'defensiveRebounds': 4,
#      'offensiveRebounds': 0,
#      'turnovers': 0,
#      'blocks': 0,
#      'personalFouls': 0,
#      'assists': 0,
#      'steals': 0,
#      'plusMinus': 4,
#      'fieldGoalPct': 16}}],
#   'supportStaff': [],
#   'playerColor': {'primary': '000000',
#    'number': '222226',
#    'outline': 'fdb927',
#    'fancyNumber': '222226'},
#   'goalkeeperColor': {'primary': '000000',
#    'number': '000000',
#    'outline': 'fafb00',
#    'fancyNumber': '222226'}}}

# %%
# Sachant que :
              # - data.get('home', {}) : Récupère les données liées à l'équipe à domicile.
              # - .get('players', []) : Récupère la liste des joueurs, ou une liste vide si elle n'existe pas.

# Regarde comment fonctionne la fonction get  dans l'exemple suivant


# Extrais les joueurs de l'équipe à domicile à partir des données récupérées
home_players = data.get('home', {}).get('players', [])

type(home_players)

# Utilise la fonction get pour récupérer les informations qu'on te demande dans la cellule suivante
# Out:
# list

# %%
home_players[0]
# Out:
# {'player': {'name': 'Bobby Portis',
#   'firstName': 'Bobby',
#   'lastName': 'Portis',
#   'slug': 'portis-bobby',
#   'shortName': 'B. Portis',
#   'position': 'F',
#   'jerseyNumber': '9',
#   'height': 208,
#   'userCount': 1574,
#   'id': 817329,
#   'country': {'alpha2': 'US', 'alpha3': 'USA', 'name': 'USA', 'slug': 'usa'},
#   'marketValueCurrency': 'EUR',
#   'dateOfBirthTimestamp': 792374400,
#   'fieldTranslations': {'nameTranslation': {'ar': 'بوبي بورتيس'},
#    'shortNameTranslation': {'ar': 'ب. بورتيس'}}},
#  'teamId': 3410,
#  'shirtNumber': 9,
#  'jerseyNumber': '9',
#  'position': 'F',
#  'substitute': True,
#  'statistics': {'secondsPlayed': 1430,
#   'points': 4,
#   'twoPointsMade': 2,
#   'twoPointAttempts': 6,
#   'threePointsMade': 6,
#   'threePointAttempts': 4,
#   'freeThrowsMade': 2,
#   'freeThrowAttempts': 0,
#   'fieldGoalsMade': 14,
#   'fieldGoalAttempts': 8,
#   'rebounds': 0,
#   'defensiveRebounds': 0,
#   'offensiveRebounds': 0,
#   'turnovers': 0,
#   'blocks': 0,
#   'personalFouls': 0,
#   'assists': 0,
#   'steals': 0,
#   'plusMinus': 4,
#   'fieldGoalPct': 10}}

# %%
# Extrais les joueurs de l'équipe à l'extérieur de manière similaire

away_players = data.get('away', {}).get('players', [])

type(away_players)
# Out:
# list

# %%
# Afficher les joueurs de l'équipe à domicile
# - Utilisez une boucle pour parcourir la liste des joueurs(away_players).
# - Accédez à chaque joueur pour afficher son ID et son nom.

# Indice : Essaye de faire pour un seul joueur avant de faire ta boucle

print("Joueurs de l'équipe à domicile :")

for player in home_players:
    # f-string pour afficher clairement l'ID et le nom de chaque joueur
    print(f"ID: {player['player']['id']}, Nom: {player['player']['name']}")
# Out:
# Joueurs de l'équipe à domicile :
# ID: 817329, Nom: Bobby Portis
# ID: 817039, Nom: Pat Connaughton
# ID: 1540637, Nom: AJ Johnson
# ID: 1179862, Nom: AJ Green
# ID: 1206073, Nom: MarJon Beauchamp
# ID: 1178570, Nom: Stanley Umude
# ID: 1629480, Nom: Tyler Smith
# ID: 846893, Nom: Taurean Prince
# ID: 817232, Nom: Damian Lillard

# %%
# Afficher les joueurs de l'équipe à l'exterieur
# - Utilisez une boucle pour parcourir la liste des joueurs(home_players).
# - Accédez à chaque joueur pour afficher son ID et son nom.

# Indice : Essaye de faire pour un seul joueur avant de faire ta boucle

print("Joueurs de l'équipe à l'exterieur :")

for player in away_players:
    # f-string pour afficher clairement l'ID et le nom de chaque joueur
    print(f"ID: {player['player']['id']}, Nom: {player['player']['name']}")
# Out:
# Joueurs de l'équipe à l'exterieur :
# ID: 987100, Nom: Jaxson Hayes
# ID: 1184925, Nom: Quincy Olivari
# ID: 1144675, Nom: Armel Traore
# ID: 1179398, Nom: Colin Castleton
# ID: 1134112, Nom: Jordan Goodwin
# ID: 1181769, Nom: Maxwell Lewis
# ID: 817357, Nom: D'Angelo Russell
# ID: 817181, Nom: LeBron James

# %% [markdown]
# ## Étape 3 : Récupérer les statistiques pour un seul joueur

# %%
# Saisir l'ID du joueur sélectionné
player_id = input('Entrez l\'ID du joueur : ')

# Construire l'URL pour les statistiques
url_stats = f'https://api.sofascore.com/api/v1/event/{match_id}/player/{player_id}/statistics'

# Fais une requête GET
response = requests.get(url_stats)

# Récupére les statistiques du joueur pendant le match que t'avait déjà choisi
stats = response.json()
stats
# Out:
# Entrez l'ID du joueur : 817357
# {'player': {'name': "D'Angelo Russell",
#   'firstName': "D'Angelo",
#   'lastName': 'Russell ',
#   'slug': 'dangelo-russell',
#   'shortName': 'D. Russell',
#   'position': 'G',
#   'jerseyNumber': '1',
#   'height': 191,
#   'userCount': 4670,
#   'id': 817357,
#   'marketValueCurrency': 'EUR',
#   'dateOfBirthTimestamp': 825033600,
#   'fieldTranslations': {'nameTranslation': {'ar': 'دي أنجلو راسل'},
#    'shortNameTranslation': {'ar': 'د. أ. راسل'}}},
#  'team': {'name': 'Los Angeles Lakers',
#   'slug': 'los-angeles-lakers',
#   'shortName': 'Lakers',
#   'gender': 'M',
#   'sport': {'name': 'Basketball', 'slug': 'basketball', 'id': 2},
#   'userCount': 211333,
#   'nameCode': 'LAL',
#   'disabled': False,
#   'national': True,
#   'type': 0,
#   'id': 3427,
#   'teamColors': {'primary': '#fdb927',
#    'secondary': '#552582',
#    'text': '#552582'},
#   'fieldTranslations': {'nameTranslation': {'ar': 'لوس انجلس لايكرس',
#     'ru': 'Лос-Анджелес Лейкерс'},
#    'shortNameTranslation': {}}},
#  'statistics': {'secondsPlayed': 190,
#   'points': 4,
#   'twoPointsMade': 4,
#   'twoPointAttempts': 0,
#   'threePointsMade': 0,
#   'threePointAttempts': 0,
#   'freeThrowsMade': 0,
#   'freeThrowAttempts': 0,
#   'fieldGoalsMade': 4,
#   'fieldGoalAttempts': 8,
#   'rebounds': 0,
#   'defensiveRebounds': 0,
#   'offensiveRebounds': 0,
#   'turnovers': 0,
#   'blocks': 0,
#   'personalFouls': 0,
#   'assists': 8,
#   'steals': 0,
#   'plusMinus': 6,
#   'fieldGoalPct': 0},
#  'position': 'G',
#  'periods': [{'period': '1Q',
#    'statistics': {'secondsPlayed': 750,
#     'points': 2,
#     'twoPointsMade': 0,
#     'twoPointAttempts': 2,
#     'threePointsMade': 0,
#     'threePointAttempts': 0,
#     'freeThrowsMade': 0,
#     'freeThrowAttempts': 0,
#     'fieldGoalsMade': 0,
#     'fieldGoalAttempts': 0,
#     'rebounds': 0,
#     'defensiveRebounds': 0,
#     'offensiveRebounds': 0,
#     'turnovers': 2,
#     'blocks': 0,
#     'personalFouls': 0,
#     'assists': 0,
#     'steals': 0,
#     'plusMinus': 2,
#     'fieldGoalPct': 18}},
#   {'period': '2Q',
#    'statistics': {'secondsPlayed': 18,
#     'points': 2,
#     'twoPointsMade': 0,
#     'twoPointAttempts': 0,
#     'threePointsMade': 0,
#     'threePointAttempts': 0,
#     'freeThrowsMade': 0,
#     'freeThrowAttempts': 0,
#     'fieldGoalsMade': 0,
#     'fieldGoalAttempts': 6,
#     'rebounds': 0,
#     'defensiveRebounds': 0,
#     'offensiveRebounds': 0,
#     'turnovers': 0,
#     'blocks': 0,
#     'personalFouls': 0,
#     'assists': 2,
#     'steals': 0,
#     'plusMinus': 0,
#     'fieldGoalPct': 44}},
#   {'period': '3Q',
#    'statistics': {'secondsPlayed': 622,
#     'points': 0,
#     'twoPointsMade': 0,
#     'twoPointAttempts': 0,
#     'threePointsMade': 0,
#     'threePointAttempts': 2,
#     'freeThrowsMade': 0,
#     'freeThrowAttempts': 0,
#     'fieldGoalsMade': 0,
#     'fieldGoalAttempts': 0,
#     'rebounds': 0,
#     'defensiveRebounds': 0,
#     'offensiveRebounds': 0,
#     'turnovers': 0,
#     'blocks': 0,
#     'personalFouls': 0,
#     'assists': 0,
#     'steals': 0,
#     'plusMinus': 4,
#     'fieldGoalPct': 32}},
#   {'period': '4Q'}]}

# %%
# Utilise json_normalize pour définir ta DataFrame en récupérent les 'statistics'
# On ne veut que charger les données 'statistics' dans le JSON 'stats'
df_stats = pd.json_normalize(stats['statistics'])
print("Statistiques du joueur :")
df_stats
# Out:
# Statistiques du joueur :
#    secondsPlayed  points  twoPointsMade  twoPointAttempts  threePointsMade  \
# 0            190       4              4                 0                0
#
#    threePointAttempts  freeThrowsMade  freeThrowAttempts  fieldGoalsMade  \
# 0                   0               0                  0               4
#
#    fieldGoalAttempts  rebounds  defensiveRebounds  offensiveRebounds  \
# 0                  8         0                  0                  0
#
#    turnovers  blocks  personalFouls  assists  steals  plusMinus  fieldGoalPct
# 0          0       0              0        8       0          6             0

# %%
# Transporse ta dataframe vu qu'elle sur une ligne
df_stats = df_stats.T
df_stats
# Out:
#                       0
# secondsPlayed       190
# points                4
# twoPointsMade         4
# twoPointAttempts      0
# threePointsMade       0
# threePointAttempts    0
# freeThrowsMade        0
# freeThrowAttempts     0
# fieldGoalsMade        4
# fieldGoalAttempts     8
# rebounds              0
# defensiveRebounds     0
# offensiveRebounds     0
# turnovers             0
# blocks                0
# personalFouls         0
# assists               8
# steals                0
# plusMinus             6
# fieldGoalPct          0

# %% [markdown]
# ## Étape 4 : Visualiser les statistiques du joueur séléctionné pendant le match
# Créez des graphiques pour comparer et analyser les statistiques.

# %%
# Visualisation des statistiques
# Crée un bar plot qui permet de représenter toutes les statistiques présentes dans la df du joueur pendant le match

fig = px.bar(df_stats, x=df_stats.index, y=0, title='Statistiques du joueur', labels={'x': 'Statistiques', 'y': 'Valeur'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ea06a687-7e24-4c44-96df-174b8bef3d02" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ea06a687-7e24-4c44-96df-174b8bef3d02")) {                    Plotly.newPlot(                        "ea06a687-7e24-4c44-96df-174b8bef3d02",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}\u003cbr\u003e0=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["secondsPlayed","points","twoPointsMade","twoPointAttempts","threePointsMade","threePointAttempts","freeThrowsMade","freeThrowAttempts","fieldGoalsMade","fieldGoalAttempts","rebounds","defensiveRebounds","offensiveRebounds","turnovers","blocks","personalFouls","assists","steals","plusMinus","fieldGoalPct"],"xaxis":"x","y":[190,4,4,0,0,0,0,0,4,8,0,0,0,0,0,0,8,0,6,0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewid ...

# %% [markdown]
# # Partie 2 : Focus sur le match
# Cette partie nous permettra récupérer, visualiser et comparer les statistiques des joueurs pendant le match que t'avez séelectionné au préalable
#
# Rappel :
#
# Tu as déjà stocké les informations des joueurs dans les deux listes `home_players` et `away_players`
#
# Tu sais maintenant comment récupérer les statistiques d'un joueur
#
#
# On aura besoin de faire une boucle pour récupérer l'ID, le nom et les stats de tous les joueurs pendant un match

# %% [markdown]
# ## Étape 1 : Avant de faire ta boucle essaye de récupérer ces informations pour le joueur que t'as regardé ces stats juste avant

# %%
# Récupère l'id et le nom du premier joueur dans la composition home_players

player = home_players[0]

player_id = player['player']['id']
player_name = player['player']['name']

print(player_id)
print(player_name)
# Out:
# 817329
# Bobby Portis

# %%
# Crées une liste players_stats vide

players_stats = []

# Maintenant que tu as récupéré le player_id, récupére les statistics de ce joueur
# Fais une requete GET comme tu as fais en haut pour les statistics
url_stats = f'https://api.sofascore.com/api/v1/event/{match_id}/player/{player_id}/statistics'
response = requests.get(url_stats)

stats = response.json()

# Mets tes résultats dans une variables player_stats
player_stats = stats['statistics']

# Ajoute la variable player_stats dans ta liste players_stats
players_stats.append(player_stats)

# %%
players_stats
# Out:
# [{'secondsPlayed': 1464,
#   'points': 36,
#   'twoPointsMade': 0,
#   'twoPointAttempts': 2,
#   'threePointsMade': 6,
#   'threePointAttempts': 6,
#   'freeThrowsMade': 2,
#   'freeThrowAttempts': 2,
#   'fieldGoalsMade': 6,
#   'fieldGoalAttempts': 12,
#   'rebounds': 0,
#   'defensiveRebounds': 0,
#   'offensiveRebounds': 0,
#   'turnovers': 0,
#   'blocks': 0,
#   'personalFouls': 0,
#   'assists': 0,
#   'steals': 0,
#   'plusMinus': 12,
#   'fieldGoalPct': 126}]

# %%
player_stats
# Out:
# {'secondsPlayed': 1464,
#  'points': 36,
#  'twoPointsMade': 0,
#  'twoPointAttempts': 2,
#  'threePointsMade': 6,
#  'threePointAttempts': 6,
#  'freeThrowsMade': 2,
#  'freeThrowAttempts': 2,
#  'fieldGoalsMade': 6,
#  'fieldGoalAttempts': 12,
#  'rebounds': 0,
#  'defensiveRebounds': 0,
#  'offensiveRebounds': 0,
#  'turnovers': 0,
#  'blocks': 0,
#  'personalFouls': 0,
#  'assists': 0,
#  'steals': 0,
#  'plusMinus': 12,
#  'fieldGoalPct': 126,
#  'name': 'Bobby Portis'}

# %%
# Rajoute un élément dictionnaire à la liste 'player_stats' avec la clé 'name' et la valeur qui est le nom de ton joueur 'player_name'

player_stats['name'] = player_name

# %%
player_stats
# Out:
# {'secondsPlayed': 1464,
#  'points': 36,
#  'twoPointsMade': 0,
#  'twoPointAttempts': 2,
#  'threePointsMade': 6,
#  'threePointAttempts': 6,
#  'freeThrowsMade': 2,
#  'freeThrowAttempts': 2,
#  'fieldGoalsMade': 6,
#  'fieldGoalAttempts': 12,
#  'rebounds': 0,
#  'defensiveRebounds': 0,
#  'offensiveRebounds': 0,
#  'turnovers': 0,
#  'blocks': 0,
#  'personalFouls': 0,
#  'assists': 0,
#  'steals': 0,
#  'plusMinus': 12,
#  'fieldGoalPct': 126,
#  'name': 'Bobby Portis',
#  'team': 'Home'}

# %%
# Rajoute un élément dictionnaire à la liste 'player_stats' avec la clé 'team' et la valeur qui est soit 'Home' soit 'away' selon la présence du joueur dans les listes home_players ou away_players

if player in home_players:
    player_stats['team'] = 'Home'
else:
    player_stats['team'] = 'Away'

# %%
# On regarde la liste players_stats sous forme de data frame, vérifie que les colonnes (id, name) et les colonnes statistiques sont bien présentes
pd.DataFrame(players_stats)
# Out:
#    secondsPlayed  points  twoPointsMade  twoPointAttempts  threePointsMade  \
# 0           1464      36              0                 2                6
#
#    threePointAttempts  freeThrowsMade  freeThrowAttempts  fieldGoalsMade  \
# 0                   6               2                  2               6
#
#    fieldGoalAttempts  ...  offensiveRebounds  turnovers  blocks  \
# 0                 12  ...                  0          0       0
#
#    personalFouls  assists  steals  plusMinus  fieldGoalPct          name  team
# 0              0        0       0         12           126  Bobby Portis  Home
#
# [1 rows x 22 columns]

# %% [markdown]
# ## Étape 2 : Maintenant que tu as fais pour un joueur. On construit notre boucle en se basant sur le même principe

# %%
# 1 : Récupérer les statistiques de tous les joueurs pour un match

# Rappel : tu as déjà stocker les informations des joueurs dans les deux listes home_players et away_players
# Tu sais maintenant comment récupérer les statistiques d'un joueur
# on aura besoin de faire une boucle pour récupérer les stats de tous les joueurs
# Avant de faire ta boucle essaye de récupérer ces informations pour un joueur
players_stats = []

for player in home_players + away_players:
    player_id = player['player']['id']
    url_stats = f'https://api.sofascore.com/api/v1/event/{match_id}/player/{player_id}/statistics'
    response = requests.get(url_stats)

    stats = response.json()
    player_name = player['player']['name']
    player_stats = stats['statistics']
    player_stats['name'] = player_name
    if player in home_players:
      player_stats['team'] = 'Home'
    else:
      player_stats['team'] = 'Away'
    players_stats.append(player_stats)

# %%
# Étape 2 : Créer un DataFrame pour comparer les joueurs
df_players = pd.DataFrame(players_stats)

# Afficher le tableau des statistiques
df_players
# Out:
#     secondsPlayed  points  twoPointsMade  twoPointAttempts  threePointsMade  \
# 0            1732       0              2                 6                4
# 1            1168       2              2                 2                0
# 2              24      14              2                 0                2
# 3            1310       4              0                 0                0
# 4             468       2              2                 0                0
# 5              82       0              0                 0                0
# 6            1266       2              0                 0                0
# 7             262       2              0                 0                0
# 8             124      10              0                 4                0
# 9             676       2              4                 2                0
# 10            896       0              0                 0                0
# 11            550       4              0                 4                0
# 12            534       6              0                 0                0
# 13            140       0              0                 0                0
# 14            710       8              2                 6                0
# 15            246       2              2                 2                0
# 16             40      10              0                 0                2
#
#     threePointAttempts  freeThrowsMade  freeThrowAttempts  fieldGoalsMade  \
# 0                    4               2                  0               8
# 1                    0               0                  0               2
# 2                    6               0                  0               0
# 3                    2               0                  0               0
# 4                    0               0                  0               2
# 5                    0               0                  0               0
# 6                    2               0                  2               0
# 7                    0               0                  0               0
# 8                    0               2                  0               0
# 9                    0               0                  0               2
# 10                   0               0                  0               0
# 11                   0               0                  0               2
# 12                   0               2                  0               0
# 13                   0               0                  0               0
# 14                   0               2                  2               0
# 15                   4               0                  0               2
# 16                   0               0                  0               0
#
#     fieldGoalAttempts  ...  offensiveRebounds  turnovers  blocks  \
# 0                   2  ...                  0          0       0
# 1                   4  ...                  0          0       0
# 2                   8  ...                  0          2       0
# 3                   6  ...                  0          2       0
# 4                   2  ...                  0          0       0
# 5                   0  ...                  0          0       0
# 6                   4  ...                  0          2       0
# 7                   0  ...                  0          0       0
# 8                  12  ...                  0          2       0
# 9                   4  ...                  0          0       0
# 10                  6  ...                  0          0       0
# 11                  8  ...                  0          0       0
# 12                  0  ...                  0          0       0
# 13                  2  ...                  2          0       0
# 14                  8  ...                  0          0       0
# 15                 12  ...                  0          0       0
# 16                  6  ...                  0          2       0
#
#     personalFouls  assists  steals  plusMinus  fieldGoalPct              name  \
# 0               0        0       0          8            80      Bobby Portis
# 1               0        0       0          0            96   Pat Connaughton
# 2               2        4       0          2            36        AJ Johnson
# 3               0        0       0          0            32          AJ Green
# 4               0        6       0          0            36  MarJon Beauchamp
# 5               0        0       0          0             0     Stanley Umude
# 6               0        0       0          0            32       Tyler Smith
# 7               0        2       0          0            12    Taurean Prince
# 8               0        6       0          2            16    Damian Lillard
# 9               0        0       0          0           122      Jaxson Hayes
# 10              0        0       0         30            58    Quincy Olivari
# 11              0        0       0          6            60      Armel Traore
# 12              0        2       0          4           164   Colin Castleton
# 13              0        0       0          0             0    Jordan Goodwin
# 14              0        0       0         20            98     Maxwell Lewis
# 15              0        2       0         10            40  D'Angelo Russell
# 16              0        2       0          6             8      LeBron James
#
#     team
# 0   Home
# 1   Home
# 2   Home
# 3   Home
# 4   Home
# 5   Home
# 6   Home
# 7   Home
# 8   Home
# 9   Away
# 10  Away
# 11  Away
# 12  Away
# 13  Away
# 14  Away
# 15  Away
# 16  Away
#
# [17 rows x 22 columns]

# %% [markdown]
# ## Étape 3 : Créer des graphiques distincts pour les statistiques

# %% [markdown]
# ### Créer un graphe pour comparer les points par joueurs dans les deux équipes

# %%
# Graphique des points par équipe
fig_points = px.bar(
    df_players,
    x='name',
    y='points',
    color='team',
    title='Comparaison des points par joueur',
    labels={'name': 'Joueur', 'points': 'Points'},
    barmode='group'
)
fig_points.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f84739ae-cd23-4b85-a8e2-5442bd747c77" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f84739ae-cd23-4b85-a8e2-5442bd747c77")) {                    Plotly.newPlot(                        "f84739ae-cd23-4b85-a8e2-5442bd747c77",                        [{"alignmentgroup":"True","hovertemplate":"team=Home\u003cbr\u003eJoueur=%{x}\u003cbr\u003ePoints=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Home","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Home","offsetgroup":"Home","orientation":"v","showlegend":true,"textposition":"auto","x":["Bobby Portis","Pat Connaughton","AJ Johnson","AJ Green","MarJon Beauchamp","Stanley Umude","Tyler Smith","Taurean Prince","Damian Lillard"],"xaxis":"x","y":[0,2,14,4,2,0,2,2,10],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"team=Away\u003cbr\u003eJoueur=%{x}\u003cbr\u003ePoints=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Away","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Away","offsetgroup":"Away","orientation":"v","showlegend":true,"textposition":"auto","x":["Jaxson Hayes","Quincy Olivari","Armel Traore","Colin Castleton","Jordan Goodwin","Maxwell Lewis","D'Angelo Russell","LeBron James"],"xaxis":"x","y":[2,0,4,6,0,8,2,10],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.888888888888 ...

# %% [markdown]
# ### Créer un graphe pour comparer les rebonds par joueurs dans les deux équipes

# %%
# Graphique des rebonds par équipe
fig_rebounds = px.bar(
    df_players,
    x='name',
    y='rebounds',
    color='team',
    title='Comparaison des rebonds par joueur',
    labels={'name': 'Joueur', 'rebounds': 'Rebonds'},
    barmode='group'
)
fig_rebounds.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="433fe1ae-f526-4d14-a223-87b41b2f38a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("433fe1ae-f526-4d14-a223-87b41b2f38a3")) {                    Plotly.newPlot(                        "433fe1ae-f526-4d14-a223-87b41b2f38a3",                        [{"alignmentgroup":"True","hovertemplate":"team=Home\u003cbr\u003eJoueur=%{x}\u003cbr\u003eRebonds=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Home","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Home","offsetgroup":"Home","orientation":"v","showlegend":true,"textposition":"auto","x":["Bobby Portis","Pat Connaughton","AJ Johnson","AJ Green","MarJon Beauchamp","Stanley Umude","Tyler Smith","Taurean Prince","Damian Lillard"],"xaxis":"x","y":[2,0,6,0,2,2,10,0,0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"team=Away\u003cbr\u003eJoueur=%{x}\u003cbr\u003eRebonds=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Away","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Away","offsetgroup":"Away","orientation":"v","showlegend":true,"textposition":"auto","x":["Jaxson Hayes","Quincy Olivari","Armel Traore","Colin Castleton","Jordan Goodwin","Maxwell Lewis","D'Angelo Russell","LeBron James"],"xaxis":"x","y":[4,0,0,10,4,0,0,6],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.88888888888 ...

# %% [markdown]
# ### (Bonus) Créer le même graphe en triant les nombres des rebonds par équipe

# %%
# Trier le DataFrame par la colonne 'rebounds' en ordre décroissant
df_sorted = df_players.sort_values(by='rebounds', ascending=False)

# Créer le graphique avec le DataFrame trié
fig_rebounds = px.bar(
    df_sorted,
    x='name',
    y='rebounds',
    color='team',
    title='Comparaison des rebonds par joueur (trié)',
    labels={'name': 'Joueur', 'rebounds': 'Rebonds'},
    barmode='group'
)
fig_rebounds.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9d5721d1-b5a3-49ca-8642-5baba9b704d0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d5721d1-b5a3-49ca-8642-5baba9b704d0")) {                    Plotly.newPlot(                        "9d5721d1-b5a3-49ca-8642-5baba9b704d0",                        [{"alignmentgroup":"True","hovertemplate":"team=Home\u003cbr\u003eJoueur=%{x}\u003cbr\u003eRebonds=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Home","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Home","offsetgroup":"Home","orientation":"v","showlegend":true,"textposition":"auto","x":["Tyler Smith","AJ Johnson","Bobby Portis","Stanley Umude","MarJon Beauchamp","Taurean Prince","Pat Connaughton","AJ Green","Damian Lillard"],"xaxis":"x","y":[10,6,2,2,2,0,0,0,0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"team=Away\u003cbr\u003eJoueur=%{x}\u003cbr\u003eRebonds=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Away","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Away","offsetgroup":"Away","orientation":"v","showlegend":true,"textposition":"auto","x":["Colin Castleton","LeBron James","Jordan Goodwin","Jaxson Hayes","Quincy Olivari","Armel Traore","Maxwell Lewis","D'Angelo Russell"],"xaxis":"x","y":[10,6,4,4,0,0,0,0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.88888888888 ...

# %% [markdown]
# ### (Bonus) Créer le même graphe en triant les nombres des rebonds globalement

# %%
# Trier le DataFrame par 'rebounds' en ordre décroissant
df_sorted = df_players.sort_values(by='rebounds', ascending=False)

# Créer un graphique tout en forçant l'ordre global par 'rebounds'
fig_rebounds = px.bar(
    df_sorted,
    x='name',
    y='rebounds',
    color='team',  # Garder la couleur par équipe
    title='Comparaison des rebonds par joueur (tri global avec couleurs)',
    labels={'name': 'Joueur', 'rebounds': 'Rebonds'},
    barmode='group',
    category_orders={'name': df_sorted['name'].tolist()}  # Forcer l'ordre des joueurs
)
fig_rebounds.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="20c4b9cc-025d-4999-9c7d-705e7af8528e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("20c4b9cc-025d-4999-9c7d-705e7af8528e")) {                    Plotly.newPlot(                        "20c4b9cc-025d-4999-9c7d-705e7af8528e",                        [{"alignmentgroup":"True","hovertemplate":"team=Home\u003cbr\u003eJoueur=%{x}\u003cbr\u003eRebonds=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Home","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Home","offsetgroup":"Home","orientation":"v","showlegend":true,"textposition":"auto","x":["Tyler Smith","AJ Johnson","Bobby Portis","Stanley Umude","MarJon Beauchamp","Taurean Prince","Pat Connaughton","AJ Green","Damian Lillard"],"xaxis":"x","y":[10,6,2,2,2,0,0,0,0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"team=Away\u003cbr\u003eJoueur=%{x}\u003cbr\u003eRebonds=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Away","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Away","offsetgroup":"Away","orientation":"v","showlegend":true,"textposition":"auto","x":["Colin Castleton","LeBron James","Jordan Goodwin","Jaxson Hayes","Quincy Olivari","Armel Traore","Maxwell Lewis","D'Angelo Russell"],"xaxis":"x","y":[10,6,4,4,0,0,0,0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.88888888888 ...

# %% [markdown]
# ### (Bonus) Faire le même graphe pour les points

# %%
# Trier le DataFrame par 'rebounds' en ordre décroissant
df_sorted = df_players.sort_values(by='points', ascending=False)

# Créer un graphique tout en forçant l'ordre global par 'rebounds'
fig_rebounds = px.bar(
    df_sorted,
    x='name',
    y='points',
    color='team',  # Garder la couleur par équipe
    title='Comparaison des points par joueur (tri global avec couleurs)',
    labels={'name': 'Joueur', 'points': 'Points'},
    barmode='group',
    category_orders={'name': df_sorted['name'].tolist()}  # Forcer l'ordre des joueurs
)
fig_rebounds.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a68c6d09-41ac-475a-a218-92e520ffbae0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a68c6d09-41ac-475a-a218-92e520ffbae0")) {                    Plotly.newPlot(                        "a68c6d09-41ac-475a-a218-92e520ffbae0",                        [{"alignmentgroup":"True","hovertemplate":"team=Home\u003cbr\u003eJoueur=%{x}\u003cbr\u003ePoints=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Home","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Home","offsetgroup":"Home","orientation":"v","showlegend":true,"textposition":"auto","x":["AJ Johnson","Damian Lillard","AJ Green","MarJon Beauchamp","Tyler Smith","Taurean Prince","Pat Connaughton","Stanley Umude","Bobby Portis"],"xaxis":"x","y":[14,10,4,2,2,2,2,0,0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"team=Away\u003cbr\u003eJoueur=%{x}\u003cbr\u003ePoints=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Away","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Away","offsetgroup":"Away","orientation":"v","showlegend":true,"textposition":"auto","x":["LeBron James","Maxwell Lewis","Colin Castleton","Armel Traore","Jaxson Hayes","D'Angelo Russell","Quincy Olivari","Jordan Goodwin"],"xaxis":"x","y":[10,8,6,4,2,2,0,0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.888888888888 ...

# %%
import pandas as pd

# %% [markdown]
# ### Welcome to the Apply Challenge

# %%
link = 'https://raw.githubusercontent.com/chriszapp/datasets/main/books.csv'
books = pd.read_csv(link, nrows = 13)
books.head()
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 1  J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# 2                J.K. Rowling            4.42  0439554896  9780439554893
# 3  J.K. Rowling/Mary GrandPré            4.56  043965548X  9780439655484
# 4  J.K. Rowling/Mary GrandPré            4.78  0439682584  9780439682589
#
#   language_code    num_pages  ratings_count  text_reviews_count  \
# 0           eng          652        2095690               27591
# 1           eng          870        2153167               29221
# 2           eng          352           6333                 244
# 3           eng          435        2339585               36325
# 4           eng         2690          41428                 164
#
#   publication_date        publisher
# 0        9/16/2006  Scholastic Inc.
# 1         9/1/2004  Scholastic Inc.
# 2        11/1/2003       Scholastic
# 3         5/1/2004  Scholastic Inc.
# 4        9/13/2004       Scholastic

# %%
# Firstly, have a look at the dataset
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   bookID              13 non-null     int64
#  1   title               13 non-null     object
#  2   authors             13 non-null     object
#  3   average_rating      13 non-null     float64
#  4   isbn                13 non-null     object
#  5   isbn13              13 non-null     int64
#  6   language_code       13 non-null     object
#  7     num_pages         13 non-null     int64
#  8   ratings_count       13 non-null     int64
#  9   text_reviews_count  13 non-null     int64
#  10  publication_date    13 non-null     object
#  11  publisher           13 non-null     object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 1.3+ KB

# %%
# Mission 1: use apply to create a new column called 'reviews_opinion': if the ratings is between 4.5 and 5, the reviews_opinion is 'very good';
# if the rating is between 4 and 4.5, the reviews_opinion is 'good'; if the rating is between 3 and 4, the reviews_opinions will be 'neutral';
# if the rating is up to 3 the reviews_opinion is going to be 'bad'

# Add your code here

def reviews_opinions(rating):
  if rating >= 4.5 and rating <= 5:
    return 'very good'
  elif rating >= 4 and rating < 4.5:
    return 'good'
  elif rating >= 3 and rating < 4:
    return 'neutral'
  else:
    return 'bad'

books['reviews_opinion'] = books['average_rating'].apply(reviews_opinions)
print(books.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ratings'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-5338b6acec22> in <cell line: 0>()
#       5 # Add your code here
#       6
# ----> 7 books['reviews_opinion'] = books['ratings'].apply(lambda x:'very good' if 4.5 <= x <= 5 else
#       8                                            'good' if 4 <= x < 4.5 else
#       9                                            'neutral' if 3 <= x < 4 else
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'ratings'

# %%
# Mission 2: using apply with a function, create a column with the number of authors per book
# (note that in the column 'authors', each name of the author is divided with the character '/')

# Add your code here

def nombre_auteur(autor):
  return len(autor.split('/'))

books['nombre_auteur'] = books['authors'].apply(nombre_auteur)
print(books.head())
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 1  J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# 2                J.K. Rowling            4.42  0439554896  9780439554893
# 3  J.K. Rowling/Mary GrandPré            4.56  043965548X  9780439655484
# 4  J.K. Rowling/Mary GrandPré            4.78  0439682584  9780439682589
#
#   language_code    num_pages  ratings_count  text_reviews_count  \
# 0           eng          652        2095690               27591
# 1           eng          870        2153167               29221
# 2           eng          352           6333                 244
# 3           eng          435        2339585               36325
# 4           eng         2690          41428                 164
#
#   publication_date        publisher reviews_opinion  nombre_auteur
# 0        9/16/2006  Scholastic Inc.       very good              2
# 1         9/1/2004  Scholastic Inc.            good              2
# 2        11/1/2003       Scholastic            good              1
# 3         5/1/2004  Scholastic Inc.       very good              2
# 4        9/13/2004       Scholastic       very good              2

# %%
# Mission 3: rewrite the same task as Mission 2 using the lamdba function

# Add your code here
books_lambda = books.copy()
books_lambda['number_of_authors'] = books_lambda['authors'].apply(lambda x: len(x.split('/')))
print(books_lambda.head())
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 1  J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# 2                J.K. Rowling            4.42  0439554896  9780439554893
# 3  J.K. Rowling/Mary GrandPré            4.56  043965548X  9780439655484
# 4  J.K. Rowling/Mary GrandPré            4.78  0439682584  9780439682589
#
#   language_code    num_pages  ratings_count  text_reviews_count  \
# 0           eng          652        2095690               27591
# 1           eng          870        2153167               29221
# 2           eng          352           6333                 244
# 3           eng          435        2339585               36325
# 4           eng         2690          41428                 164
#
#   publication_date        publisher reviews_opinion  nombre_auteur  \
# 0        9/16/2006  Scholastic Inc.       very good              2
# 1         9/1/2004  Scholastic Inc.            good              2
# 2        11/1/2003       Scholastic            good              1
# 3         5/1/2004  Scholastic Inc.       very good              2
# 4        9/13/2004       Scholastic       very good              2
#
#    number_of_authors
# 0                  2
# 1                  2
# 2                  1
# 3                  2
# 4                  2

# %%
# Mission 4: create a column 'comment_ration'.
# Use the columns 'ratings_count' and 'text_reviews_count' to calculate the percentage of how many text review per reviews are per book:
# percentage = text / reviews * 100
# Use the mathematical operations between columns

# Add your code here

reviews = books['ratings_count']
text_reviews = books['text_reviews_count']
books['comment_ration'] = (text_reviews / reviews) * 100
print(books.head())
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 1  J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# 2                J.K. Rowling            4.42  0439554896  9780439554893
# 3  J.K. Rowling/Mary GrandPré            4.56  043965548X  9780439655484
# 4  J.K. Rowling/Mary GrandPré            4.78  0439682584  9780439682589
#
#   language_code    num_pages  ratings_count  text_reviews_count  \
# 0           eng          652        2095690               27591
# 1           eng          870        2153167               29221
# 2           eng          352           6333                 244
# 3           eng          435        2339585               36325
# 4           eng         2690          41428                 164
#
#   publication_date        publisher reviews_opinion  nombre_auteur  \
# 0        9/16/2006  Scholastic Inc.       very good              2
# 1         9/1/2004  Scholastic Inc.            good              2
# 2        11/1/2003       Scholastic            good              1
# 3         5/1/2004  Scholastic Inc.       very good              2
# 4        9/13/2004       Scholastic       very good              2
#
#    comment_ration
# 0        1.316559
# 1        1.357117
# 2        3.852834
# 3        1.552626
# 4        0.395868

# %%
# Mission 5: obtain the same result of Mission 4 using apply with a function.
# Try both methods to apply to the whole dataset and apply to selected columns

# Add your code here

def comment_ration(reviews, text_reviews):
  return (text_reviews / reviews) * 100

books['comment_ration'] = books.apply(lambda x: comment_ration(x['ratings_count'], x['text_reviews_count']), axis = 1)
print(books.head())
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 1  J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# 2                J.K. Rowling            4.42  0439554896  9780439554893
# 3  J.K. Rowling/Mary GrandPré            4.56  043965548X  9780439655484
# 4  J.K. Rowling/Mary GrandPré            4.78  0439682584  9780439682589
#
#   language_code    num_pages  ratings_count  text_reviews_count  \
# 0           eng          652        2095690               27591
# 1           eng          870        2153167               29221
# 2           eng          352           6333                 244
# 3           eng          435        2339585               36325
# 4           eng         2690          41428                 164
#
#   publication_date        publisher reviews_opinion  nombre_auteur  \
# 0        9/16/2006  Scholastic Inc.       very good              2
# 1         9/1/2004  Scholastic Inc.            good              2
# 2        11/1/2003       Scholastic            good              1
# 3         5/1/2004  Scholastic Inc.       very good              2
# 4        9/13/2004       Scholastic       very good              2
#
#    comment_ration
# 0        1.316559
# 1        1.357117
# 2        3.852834
# 3        1.552626
# 4        0.395868

# %%
# Mission 6: obtain the same result of Mission 5 using apply lambda
# Try both methods to apply to the whole dataset and apply to selected columns

# Add your code here

def comment_ration(reviews, text_reviews):
  return (text_reviews / reviews) * 100

books['comment_ration'] = books.apply(lambda x: comment_ration(x['ratings_count'], x['text_reviews_count']), axis = 1)
print(books.head())
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 1  J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# 2                J.K. Rowling            4.42  0439554896  9780439554893
# 3  J.K. Rowling/Mary GrandPré            4.56  043965548X  9780439655484
# 4  J.K. Rowling/Mary GrandPré            4.78  0439682584  9780439682589
#
#   language_code    num_pages  ratings_count  text_reviews_count  \
# 0           eng          652        2095690               27591
# 1           eng          870        2153167               29221
# 2           eng          352           6333                 244
# 3           eng          435        2339585               36325
# 4           eng         2690          41428                 164
#
#   publication_date        publisher reviews_opinion  nombre_auteur  \
# 0        9/16/2006  Scholastic Inc.       very good              2
# 1         9/1/2004  Scholastic Inc.            good              2
# 2        11/1/2003       Scholastic            good              1
# 3         5/1/2004  Scholastic Inc.       very good              2
# 4        9/13/2004       Scholastic       very good              2
#
#    comment_ration
# 0        1.316559
# 1        1.357117
# 2        3.852834
# 3        1.552626
# 4        0.395868

# %%
# Mission 7: extract the year from the publication_date column. How many years of publications are recorded in this dataset? Which are them?
# Add your code here

books['publication_date'] = pd.to_datetime(books['publication_date'])
books['year'] = books['publication_date'].dt.year
print(books['year'].value_counts())
sansDoublons = books['publication_date'].unique()

#reponse apres exécution :
print(f"il y a {len(sansDoublons)} années de publication ")
print("sur les années : ",sansDoublons)
# Out:
# year
# 2004    5
# 2005    4
# 2006    1
# 2003    1
# 2002    1
# 1996    1
# Name: count, dtype: int64
# il y a 13 années de publication
# sur les années :  <DatetimeArray>
# ['2006-09-16 00:00:00', '2004-09-01 00:00:00', '2003-11-01 00:00:00',
#  '2004-05-01 00:00:00', '2004-09-13 00:00:00', '2005-04-26 00:00:00',
#  '2005-09-12 00:00:00', '2005-11-01 00:00:00', '2002-04-30 00:00:00',
#  '2004-08-03 00:00:00', '2005-03-23 00:00:00', '1996-01-17 00:00:00',
#  '2004-09-14 00:00:00']
# Length: 13, dtype: datetime64[ns]
